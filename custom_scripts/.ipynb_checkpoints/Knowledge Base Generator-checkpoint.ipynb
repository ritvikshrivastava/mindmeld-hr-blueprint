# %%
import numpy as np
import pandas as pd
import json

# %%
kb = pd.read_csv('core_dataset.csv')
kb
# Out:
#              Employee Name   id State    Zip       DOB  Age     Sex  \
# 0               Brown, Mia    1    MA   1450  11/24/85   32  Female
# 1     LaRotonda, William      2    MA   1460   4/26/84   33    Male
# 2         Steans, Tyrone      3    MA   2703    9/1/86   31    Male
# 3          Howard, Estelle    4    MA   2170   9/16/85   32  Female
# 4              Singh, Nan     5    MA   2330   5/19/88   29  Female
# 5         Smith, Leigh Ann    6    MA   1844   6/14/87   30  Female
# 6      LeBlanc, Brandon  R    7    MA   1460   6/10/84   33    Male
# 7              Quinn, Sean    8    MA   2045   11/6/84   33    Male
# 8        Boutwell, Bonalyn    9    MA   2468    4/4/87   30  Female
# 9        Foster-Baker, Amy   10    MA   2050   4/16/79   38  Female
# 10             King, Janet   11    MA   1902   9/21/54   63  Female
# 11        Zamora, Jennifer   12    MA   2067   8/30/79   38  Female
# 12           Becker, Renee   13    MA   2026    4/4/86   31  Female
# ...

# %%
type(kb['Pay Rate'][3])
# Out:
# numpy.float64

# %%
j_string = kb.to_json()

# %%
json.dumps(json_dict, indent=4)
