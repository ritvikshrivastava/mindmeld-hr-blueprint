# %%
import numpy as np
import pandas as pd
import random
import os

# %% [markdown]
# <h2>Functions</h2>

# %% [markdown]
# <h3>General Functions</h3>

# %%
# Check if a Value is Nan
# param x - Value to check
# return boolean - If it is a Nan
def is_nan(x):
    return (x is np.nan or x != x)

# Check All Values in List are Nan
# param x - List to check
# return boolean - If it is all Nan
def list_is_nan(x):
    for i in x:
        if not is_nan(i): return False
    return True

# %% [markdown]
# <h3>Get Unique Values</h3>

# %%
# Get the Names of Employees in the HR Dataset
# param df (dataframe) - Dataframe with names
# Returns names (list) - Array of names (['First', 'Last'])
def get_names(df):
    names = [df.iloc[:, 0][i] for i in range(df.shape[0] - 1)]
    for i in range(len(names)):
        try:
            full_name = names[i].split(',')
            first = full_name[1].strip().split()[0]
            last = full_name[0]
            names[i] = [first, last]
        except: pass #print("Skipped: " + names[i])
    return names

# Filter to list of unique names
# param names (list) - List of names in the format [['Mia', 'Brown'],[..]]
# return unique (list) - List of names in the format ['Mia Brown', ..]
def filter_names(names):
    unique = [['Michael','Albert'], ['Mia','Brown'], ['Ivan','Rogers'], ['Julia','Soto'],
            ['Amy','Dunn'], ['Nan','Singh']]
    first = [n[0] for n in unique]
    last = [n[1] for n in unique]
    for name in names:
        if((name[0] not in first) and (name[1] not in last)):
            first.append(name[0])
            last.append(name[1])
            unique.append(name)
    return [",".join(name).replace(",", " ") for name in unique]

# Get the Unique Names of Employees in the HR Dataset
# param df (dataframe) - Dataframe with names
# return unique (list) - List of names in the format ['Mia Brown', ..]
def get_uniq_names(df):
    return filter_names(get_names(df))

# Get Unique String Values of a Dataframe Column
# param df (dataframe) - Source Dataframe
# param col_name (str) - Name of Column to get unique values'
# return uniq_arr (arr) - Array of Unique Values
def get_uniq_str(df, col_name):
    return [i.lower().strip() for i in df[col_name].unique()[:-1]]

# Get Unique String Values of a Dataframe Column
# param df (dataframe) - Source Dataframe
# param col_name (str) - Name of Column to get unique values'
# return uniq_arr (arr) - Array of Unique Values
def get_uniq_num(df, col_name):
    return [str(int(i)) for i in df[col_name].unique()[:-1]]

# Generate a Dictionary with Unique Values for Select Columns
# param df (dataframe) - Source Dataframe
# return uniq (dict) - Dictionary that maps entities to unique values
def gen_uniq_dict(df):
    # Get Unique Values of Relevant Columns
    uniq = {}
    # Predefined
    uniq['name'] = get_uniq_names(df)
    uniq['sex'] = ['male', 'female']
    uniq['employment_status'] = ['active', 'voluntarily terminated', 'terminated for a cause',
                          'on a leave of absence' + 'going to start work in the future']
    uniq['performance_score'] = ['fully meet performance expecations', 'are too early to review', 
                         'meet 90-day expectations', 'are exceptional', 'need improvement', 'exeed expecations']
    # Custom Preprocessing
    uniq['state'] = hr_data['State'].unique()[:-1]
    # Standard Preprocessing 
    uniq['age'] = get_uniq_num(hr_data, 'Age')
    uniq['maritaldesc'] = get_uniq_str(hr_data, "MaritalDesc")
    uniq['citizendesc'] = get_uniq_str(hr_data, "CitizenDesc")
    uniq['department'] = get_uniq_str(hr_data, "Department")
    uniq['position'] = get_uniq_str(hr_data, "Position")
    uniq['manager'] = get_uniq_str(hr_data, "Manager Name")
    uniq['employee_source'] = get_uniq_str(hr_data, "Employee Source")
    return uniq

# %% [markdown]
# <h3>Load, Parse and Clean Entity Data</h3>

# %%
# Load entity data frame from CSV
# param path (str) - Path to csv
# return ent_df (dataframe) - Entity Info Dataframe
def load_ent(path):
    df = pd.read_csv('entities.csv').iloc[:, :4]
    ct = 0
    while (ct < len(df) and not list_is_nan(df.iloc[ct, :].values)): ct += 1
    return df.iloc[:ct, :]

# Parse CSV that contains [Entity, Options, Synonyms, Gazetteer]
# param ent_df (dataframe) - Contains the columns listed above
# return ent_dict (dict) - Uncleaned dictionary where the keys are the entities
#                          and the values are [options (arr), synonyms (arr), gazetteer (arr)]
def ent_parse(ent_df):
    ent_dict = {}
    ct = 0
    curr_ent = ''
    while(ct < len(ent_df)):
        row = ent_df.iloc[ct]
        # update curr_ent if new entity
        if(not is_nan(row['Entity'])): 
            curr_ent = row['Entity']
            ent_dict[curr_ent] = [[], [], []]
        # check if options is a list
        if(not is_nan(row['Options']) and row['Options'].count(',') > 2):
            ent_dict[curr_ent][0] = row['Options']
            if(not is_nan(row[3])): ent_dict[curr_ent][2] = row['Gazetteer']
        # single entry in option column
        else:
            ent_dict[curr_ent][0].append(row['Options'])
            ent_dict[curr_ent][1].append(row['Synonyms'])
            ent_dict[curr_ent][2].append(row['Gazetteer'])
        ct += 1
    return ent_dict

# Cleans the gazetteers of the ent dictionary
# param ent_dict (dictionary) - Entity Dictionary
# return ent_dict (dictionary) - Cleaned Entity Dictionary
def clean_options(ent_dict):
    for i in ent_dict.keys():
        old_opt = ent_dict[i][0]
        new_opt = []
        for word in old_opt:
            if(not is_nan(word)):
                new_opt.append(word.replace("'", "").replace(",", ""))
        ent_dict[i][0] = new_opt
    return ent_dict

# Cleans the gazetteers of the ent dictionary
# param ent_dict (dictionary) - Entity Dictionary
# return ent_dict (dictionary) - Cleaned Entity Dictionary
def clean_synonyms(ent_dict):
    for i in ent_dict.keys():
        old_syn = ent_dict[i][1]
        new_syn = []
        if(len(old_syn) != 0):
            for j in old_syn:
                if(not is_nan(j)): new_syn.append([string.strip() for string in j.split(',')])
                else: new_syn.append(j)
        ent_dict[i][1] = new_syn
    return ent_dict

# Cleans the gazetteers of the ent dictionary
# param ent_dict (dictionary) - Entity Dictionary
# return ent_dict (dictionary) - Cleaned Entity Dictionary
def clean_gazetteer(ent_dict):
    for i in ent_dict.keys():
        old_gaz = ent_dict[i][2]
        clean_gaz = []
        if (len(old_gaz) != 0):        
            if (type(old_gaz) is str): clean_gaz = old_gaz.split(',')
            elif(not is_nan(old_gaz[0])): clean_gaz = (old_gaz[0].split(','))
        ent_dict[i][2] = [i.strip() for i in clean_gaz]
    return ent_dict

# Cleans an Entity Dictionary
# ent_dict (dict) - Uncleaned dictionary of parsed entity information
# uniq (dict) - Dictionary that maps entities to unique values
# return cleaned_ent_dict (dict) - Cleaned dictionary
def clean_ent_dict(ent_dict, uniq):
    ent_dict = clean_options(ent_dict)
    ent_dict = clean_synonyms(ent_dict)
    ent_dict = clean_gazetteer(ent_dict)
    ent_dict['name'][0] = uniq['name']
    ent_dict['state'][0] = uniq['state']
    ent_dict['age'][0] = uniq['age']
    ent_dict['manager'][0] = uniq['manager']
    return ent_dict

# Parse and Clean Entity Data
# Parse CSV that contains [Entity, Options, Synonyms, Gazetteer]
# param ent_df (dataframe) - Contains the columns listed above
def parse_clean_ent(ent_df, uniq):
    ent = ent_parse(ent_df)
    return clean_ent_dict(ent, uniq)

# %% [markdown]
# <h3>File Generation</h3>

# %%
# Convert a list into a text file
# param folder (str) - Name of the folder to write the file
# param lines (list) - List of values to write to file
def list_to_txt_file(folder, lines):
    directory = 'entities/' + folder + '/'
    if not os.path.exists(directory): os.makedirs(directory)
    with open(directory + 'gazetteer.txt', 'w+') as filehandle:  
        filehandle.writelines("%s\n" % line for line in lines)

# %%
def whitelist_gen():
    pass

# %%
# Generate a Gazetter List for an Entity
# param ent_dict (dict) - Dictionary that maps entities to options, synonyms, and gazetteer
# param entity (str) - The entity to generate the gazetteer list for
# return gaz (list) - List of gazetteer word relevant to the entity
def gen_gaz_list(ent_dict, entity):
    gaz = []
    gaz.extend(ent_dict[entity][0])
    for syn in ent_dict[entity][1]:
        if(not is_nan(syn)): gaz.extend(syn)
    gaz.extend(ent_dict[entity][2])
    return gaz

# Create Gazetteer Files for Every Entity in an Entity Dictionary
# param ent_dict (dict) - Dictionary that maps entities to options, synonyms, and gazetteer
def gen_gazetteers(ent_dict):
    for entity in ent_dict.keys():
        gaz_list = gen_gaz_list(ent_dict, entity)
        list_to_txt_file(entity, gaz_list)

# %% [markdown]
# <h2>Workflow</h2>

# %% [markdown]
# <h4>Load Data</h4>

# %%
hr_data = pd.read_csv('core_dataset.csv')
#hr_data

# %% [markdown]
# <h4>Create Unique Values Dictionary</h4>

# %%
uniq = gen_uniq_dict(hr_data)

# %% [markdown]
# <h4>Load Entities</h4>

# %%
ent_df = load_ent('entities.csv')
ent_df
# Out:
#                      Entity  \
# 0                      name
# 1                     state
# 2                       zip
# 3                       age
# 4                       sex
# 5                       NaN
# 6               maritaldesc
# 7                       NaN
# 8                       NaN
# 9                       NaN
# 10                      NaN
# 11              citizendesc
# 12                      NaN
# 13                      NaN
# 14                 racedesc
# 15                      NaN
# 16                      NaN
# 17                      NaN
# 18                      NaN
# 19                      NaN
# 20   reason_for_termination
# 21                      NaN
# 22                      NaN
# 23                      NaN
# 24                      NaN
# 25                      NaN
# 26                      NaN
# 27                      NaN
# 28                      NaN
# 29                      NaN
# ..                      ...
# 84                      NaN
# 85                      NaN
# 86                      NaN
# 87                      NaN
# 88                      NaN
# 89                      NaN
# 90                      NaN
# 91                      NaN
# 92                      NaN
# 93        performance_score
# 94                      NaN
# 95                      NaN
# 96                      NaN
# 97                      NaN
# 98                      NaN
# 99                      NaN
# 100                   money
# 101              comparator
# 102                     NaN
# 103                     NaN
# 104               date_time
# 105                     NaN
# 106                     NaN
# 107                function
# 108                     NaN
# 109                     NaN
# 110                 extreme
# 111                     NaN
# 112       employment_action
# 113                     NaN
#
#                                                Options  \
# 0    ['Mia', 'Brown'], ['William', 'LaRotonda'], ['...
# 1    MA', 'TX', 'CT', 'VA', 'VT', 'CA', 'WA', 'NH',...
# 2                                                  NaN
# 3    32', '33', '31', '29', '30', '38', '63', '46',...
# 4                                                 male
# 5                                               female
# 6                                              married
# 7                                             divorced
# 8                                               single
# 9                                            separated
# 10                                             widowed
# 11                                          us citizen
# 12                                 eligible noncitizen
# 13                                         non-citizen
# 14                           black or african american
# 15                                               asian
# 16                                   two or more races
# 17                                             white',
# 18                                          hispanic',
# 19                   american indian or alaska native'
# 20                                  return to school',
# 21                                  another position',
# 22                                           unhappy',
# 23                                          military',
# 24                                  gross misconduct',
# 25                                             hours',
# 26                                    medical issues',
# 27                            relocation out of area',
# 28                                        more money',
# 29                                     career change',
# ..                                                 ...
# 84                                diversity job fair',
# 85                                     careerbuilder',
# 86                                          mbta ads',
# 87                                     word of mouth',
# 88                                             other',
# 89                                   vendor referral',
# 90                              on-campus recruiting',
# 91                                website banner ads',
# 92                                 employee referral',
# 93                                       exceptional',
# 94                                       fully meets',
# 95                          n/a- too early to review',
# 96                                               pip',
# 97                                 needs improvement',
# 98                                           exceeds',
# 99                                       90-day meets'
# 100                                           pay rate
# 101                                          more than
# 102                                          equals to
# 103                                          less than
# 104                                     date of hire',
# 105                              date of termination',
# 106                                              dob',
# 107                                            percent
# 108                                                sum
# 109                                            average
# 110                                            highest
# 111                                             lowest
# 112                                              hired
# 113                                         terminated
#
#                                               Synonyms  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4      men, males, guys, dudes, gents, gentlemen, boys
# 5    women, females, ladies, lady, ladys, girls, ga...
# 6    wed, legally married, espoused, joined in holy...
# 7                                                  NaN
# 8                    unmarried, bachelor, bachelorette
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                           from asia
# 16   multiracial, multi-racial, mixed, mixed race, ...
# 17                                           caucasian
# 18                                                 NaN
# 19                                                 NaN
# 20   went back to school, had to go to school again...
# 21   took on another job, landed a new position, ch...
# 22   wasn't happy, didn't like his job, didn't like...
# 23   joined the military, went to the military, lef...
# 24                                                 NaN
# 25                                                 NaN
# 26         got sick, fell sick, medical problems, sick
# 27   was relocated, had to relocated, was assigned ...
# 28                                                 NaN
# 29                                     changed careers
# ..                                                 ...
# 84                                                 NaN
# 85                                                 NaN
# 86                                  advertisement, ads
# 87                                      verbal mention
# 88                                                 NaN
# 89                 referred by vendor, vendor referred
# 90                     on-campus job fair, career fair
# 91                                                 NaN
# 92                                referred by employee
# 93                                       extraordinary
# 94                   up to the mark, meet expectations
# 95                                                 NaN
# 96                                                 NaN
# 97                                                 NaN
# 98   beyond expectations, more than expected, bette...
# 99                                                 NaN
# 100          salary, income, pay, earn, earnings, make
# 101                          greater than, higher than
# 102                is exactly, is equal to, equates to
# 103                                  lower than, below
# 104            start date, date of starting employment
# 105  end date, date of leaving job, date of ending ...
# 106  birthday, birthdate, birth date, date of birth...
# 107          fraction, portion, proportion, percentage
# 108  total, cumulative, added up, summed up. totall...
# 109                                               mean
# 110                       top, maximum, most, greatest
# 111                     least, minimum, bottom, lowest
# 112                                           employed
# 113                                      fired, let go
#
#                                              Gazetteer
# 0                                                  NaN
# 1            state, state of birth, state of residence
# 2                                                  NaN
# 3                                                  NaN
# 4        sex, gender, masculine, feminine, male person
# 5                                                  NaN
# 6    husbandless, without a partner, unwedded, wife...
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11   immigrant, illegal immigrant, h1 visa, foreign...
# 12                                                 NaN
# 13                                                 NaN
# 14   ethnicity, race, racial background, ethnic gro...
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 84                                                 NaN
# 85                                                 NaN
# 86                                                 NaN
# 87                                                 NaN
# 88                                                 NaN
# 89                                                 NaN
# 90                                                 NaN
# 91                                                 NaN
# 92                                                 NaN
# 93               performance rating, performance score
# 94                                                 NaN
# 95                                                 NaN
# 96                                                 NaN
# 97                                                 NaN
# 98                                                 NaN
# 99                                                 NaN
# 100                               earns, makes, amount
# 101                                                NaN
# 102                                                NaN
# 103                                                NaN
# 104                                                NaN
# 105                                                NaN
# 106                                                NaN
# 107                                                NaN
# 108                                                NaN
# 109                                                NaN
# 110                                                NaN
# 111                                                NaN
# 112                                                NaN
# 113                                                NaN
#
# [114 rows x 4 columns]

# %%
ent_dict = parse_clean_ent(ent_df, uniq)
ent_dict
# Out:
# {'name': [['Michael Albert',
#    'Mia Brown',
#    'Ivan Rogers',
#    'Julia Soto',
#    'Amy Dunn',
#    'Nan Singh',
#    'William LaRotonda',
#    'Tyrone Steans',
#    'Estelle Howard',
#    'Leigh Smith',
#    'Brandon LeBlanc',
#    'Sean Quinn',
#    'Bonalyn Boutwell',
#    'Janet King',
#    'Jennifer Zamora',
#    'Renee Becker',
#    'Taisha Goble',
#    'Daniff Hernandez',
#    'Jayne Horton',
#    'Noelle Johnson',
#    'Thomas Murray',
#    'Randall Pearson',
#    'Thelma Petrowsky',
#    'Lori Roby',
#    'Jason Salter',
#    'Kramer Simard',
#    'Simon Roup',
#    'Ricardo Ruiz',
#    'Peter Monroe',
#    'Eric Dougall',
#    'Rick Clayton',
#    'Lisa Galia',
#    'Leonara Lindsay',
#    'Alejandro Bacong',
#    'Anthony Cisco',
#    'Linda Dolan',
#    'Maria Gonzalez',
#    'Carlos Merlos',
#    'Tanya Morway',
#    'Anita Shepard',
#    'Neville Tredinnick',
#    'Jumil Turpin',
#    'Karthikeyan Ait Sidi',
#    'Claudia Carr',
#    'Donald Favis',
#    'Bianca Roehrich',
#    'Ann Daniele',
#    'Jyoti Lajiri',
#    'Jeremiah Semizoglou',
#    'Joe South',
#    'Sarah Warfield',
#    'Elisa Bramante',
#    'Charles Bozzi',
#    'Webster Butler',
#    'Elijiah Gray',
#    'Jonathan Hogland',
#    'Walter Immediato',
#    'Ketsia Liebig',
#    'Brannon Miller',
#    'Ebonee Peterson',
#    'Kelley Spirea',
#    'David Stanley',
#    'Kissy Sullivan',
#    'Courtney Wallace',
#    'Wilson Adinolfi',
#    'Trina Alagbe',
#    'Carol Anderson',
#    'Sam Athwal',
#    'Rachael Baczenski',
#    'Francesco Barone',
#    'Nader Barton',
#    'Lowan Biden',
#    'Helen Billis',
#    'Donna Brill',
#    'Josephine Bugali',
#    'Beatrice Chace',
#    'Lin Chan',
#    'Donovan Chang',
#    'Enola Chivukula',
#    'Caroline Cierpiszewski',
#    'Elijian Clukey',
#    'James Cockel',
#    'Spencer Cole',
#    'Jean Crimmings',
#    "Jene'ya Darson",
#    'Carl Desimone',
#    'Geoff Dickinson',
#    'Lily DiNocco',
#    'Denisa Dobrin',
#    'Marianne Eaton',
#    'Rex England',
#    'Miguel Estremera',
#    'April Evensen',
#    'Susan Ferguson',
#    'Nilson Fernandes',
#    'Violeta Ferreira',
#    'Libby Fidelia',
#    'Raul Garcia',
#    'Hamish Garneau',
#    'Barbara Gaul',
#    'Mildred Gentry',
#    'Melisa Gerke',
#    'Alex Gilles',
#    'Evelyn Girifalco',
#    'Shenice Gold',
#    'Roxana Goyal',
#    'Paula Gross',
#    'Joanne Handschiegl',
#    'Ludwick Harrell',
#    'Christie Harrington',
#    'Kara Harrison',
#    'Rose Ivey',
#    'Maryellen Jackson',
#    'Hannah Jacobi',
#    'Sneha Jhaveri',
#    'Judy Jung',
#    'Kathleen Kinsella',
#    'Alexandra Kirill',
#    'Bradley Knapp',
#    'John Kretschmer',
#    'Enrico Langton',
#    'Dallas Leach',
#    'Marilyn Linares',
#    'Allison Lydon',
#    'Lindsay Lynch',
#    'Samuel MacLennan',
#    'Lauren Mahoney',
#    'Debbie Mangal',
#    'Shana Maurice',
#    'Sandy Mckenna',
#    'Elizabeth Meads',
#    'Dawn Motlagh',
#    'Colombui Ndzi',
#    'Richard Newman',
#    'Shari Ngodup',
#    'Lei-Ming Nguyen',
#    "Lynn O'hare",
#    'Adeel Osturnka',
#    'Clinton Owad',
#    'Nina Panjwani',
#    'Emil Pelech',
#    'Shakira Perry',
#    'Hong Pham',
#    'Brad Pitt',
#    'Morissa Power',
#    'Louis Punjabhi',
#    'Janine Purinton',
#    'Quinn Rarrick',
#    'Haley Rivera',
#    'Alain Robinson',
#    'Ashley Rose',
#    'Bruno Rossetti',
#    'Melinda Saar-Beckles',
#    'Nore Sadki',
#    'Kamrin Sander',
#    'Nori Sewkumar',
#    'Seffi Shields',
#    'Taylor Sparks',
#    'Kristen Squatrito',
#    'Desiree Tavares',
#    'Sophia Theamstern',
#    'Theresa Tinto',
#    'Jeanette Tippett',
#    'Mei Trang',
#    'Abdellah Veera',
#    'Colleen Volk',
#    'Anna Von Massenbach',
#    'Scott Whittier',
#    'Barry Wilber',
#    'Jacquelyn Williams',
#    'Catherine Ybarra',
#    'Kimberly Beak',
#    'Dianna Blount',
#    'Betsy Bondwell',
#    'Joseph Buccheri',
#    'Joelle Burke',
#    'Benjamin Burkett',
#    'Phil Close',
#    'Daniel Davis',
#    'Carla Demita',
#    'Angela Erilus',
#    'Megan Faller',
#    'Nicole Fancett',
#    'Phylicia Gosciminski',
#    'Earnest Hankard',
#    'Adrienne Homberger',
#    'Julissa Hunts',
#    'Rosalie Hutter',
#    'Ming Huynh',
#    'Tayana Jeannite',
#    'Yen Johnston',
#    'Lindsey Langford',
#    'Mohammed Latif',
#    'Mathew Linden',
#    'Robyn Manchester',
#    'Karen Mancuso',
#    'Brigit McCarthy',
#    'Erasumus Monkfish',
#    'Luisa Monterro',
#    'Patrick Moran',
#    'Maliki Moumanil',
#    'Kristie Nowlan',
#    'Brooke Oliver',
#    'Ermine Pelletier',
#    'May Roberson',
#    'Adil Sahoo',
#    'Constance Sloan',
#    'Lenora Tejeda',
#    'Kenneth Thibaud',
#    'Cybil Trzeciak',
#    'Roger Walker',
#    'Jordan Winthrop',
#    'Hang Wolk',
#    'Edward Buck',
#    'Jessica Bunbury',
#    'Michelle Carter',
#    'Latia Costa',
#    'Jenna Dietrich',
#    'Alfred Digitale',
#    'Maruk Fraval',
#    'Gerry Friedman',
#    'Whitney Gill',
#    'Myriam Givens',
#    'Mike Guilianno',
#    'J e r e m y   P r a t e r',
#    'Bartholemew Khemmich',
#    'Giovanni Leruth',
#    'Jac McKinzie',
#    'Howard Mullaney',
#    'Jasmine Onque',
#    'Travis Ozark',
#    'Xana Potts',
#    'Caitrin Strong',
#    'Sharlene Terry',
#    'Jackie Valentin',
#    'Noah Villanueva',
#    'Debra Houlihan',
#    'Donysha Kampew',
#    'Colby Andreola',
#    'Judith Carabbio',
#    'Keyla Del Bosque',
#    'Sandra Martin',
#    'Luke Patronick',
#    'Adell Saada',
#    'Andrew Szabo'],
#   [],
#   []],
#  'state': [array(['MA', 'TX', 'CT', 'VA', 'VT', 'CA', 'WA', 'NH', 'NY', 'OH', 'IN',
#          'ID', 'TN', 'NV', 'CO', 'UT', 'AL', 'GA', 'FL', 'NC', 'KY', 'ND',
#          'MT', 'OR', 'AZ', 'ME', 'RI', 'PA'], dtype=object),
#   [],
#   ['state', 'state of birth', 'state of residence']],
#  'zip': [[], [nan], []],
#  'age': [['32',
#    '33',
#    '31',
#    '29',
#    '30',
#    '38',
#    '63',
#    '46',
#    '36',
#    '47',
#    '37',
#    '44',
#    '54',
#    '49',
#    '28',
#    '48',
#    '42',
#    '53',
#    '66',
#    '34',
#    '52',
#    '39',
#    '45',
#    '41',
#    '40',
#    '62',
#    '43',
#    '59',
#    '27',
#    '67',
#    '50',
#    '35',
#    '26',
#    '25',
#    '65',
#    '51',
#    '58',
#    '56',
#    '64'],
#   [],
#   []],
#  'sex': [['male', 'female'],
#   [['men', 'males', 'guys', 'dudes', 'gents', 'gentlemen', 'boys'],
#    ['women', 'females', 'ladies', 'lady', 'ladys', 'girls', 'gals', 'woman']],
#   ['sex', 'gender', 'masculine', 'feminine', 'male person']],
#  'maritaldesc': [['married', 'divorced', 'single', 'separated', 'widowed'],
#   [['wed',
#     'legally married',
#     'espoused',
#     'joined in holy matrimony',
#     'hitched'],
#    nan,
#    ['unmarried', 'bachelor', 'bachelorette'],
#    nan,
#    nan],
#   ['husbandless',
#    'without a partner',
#    'unwedded',
#    'wifeless',
#    'no longer married',
#    'without a husband',
#    'without a wife',
#    'maritaldesc',
#    'marital status']],
#  'citizendesc': [['us citizen', 'eligible noncitizen', 'non-citizen'],
#   [nan, nan, nan],
#   ['immigrant',
#    'illegal immigrant',
#    'h1 visa',
#    'foreigner',
#    'foreign',
#    'imported',
#    'out of country',
#    'from abroad',
#    'citizenship status',
#    'citizenship']],
#  'racedesc': [['black or african american',
#    'asian',
#    'two or more races',
#    'white',
#    'hispanic',
#    'american indian or alaska native'],
#   [nan,
#    ['from asia'],
#    ['multiracial',
#     'multi-racial',
#     'mixed',
#     'mixed race',
#     'biracial',
#     'interracial'],
#    ['caucasian'],
#    nan,
#    nan],
#   ['ethnicity',
#    'race',
#    'racial background',
#    'ethnic group',
#    'ethnic type',
#    'racial indentity',
#    'community']],
#  'reason_for_termination': [['return to school',
#    'another position',
#    'unhappy',
#    'military',
#    'gross misconduct',
#    'hours',
#    'medical issues',
#    'relocation out of area',
#    'more money',
#    'career change',
#    'n/a - has not started yet',
#    'retiring',
#    'n/a - still employed',
#    'attendance',
#    'no-call no-show',
#    'maternity leave - did not return',
#    'performance'],
#   [['went back to school',
#     'had to go to school again',
#     'needed to go back to school',
#     'went back to college'],
#    ['took on another job',
#     'landed a new position',
#     'changed positions',
#     'got a new position',
#     'found a new position'],
#    ["wasn't happy",
#     "didn't like his job",
#     "didn't like her job",
#     'hated the job',
#     'disliked the job',
#     "didn't enjoy the job",
#     "didn't like his work",
#     "didn't like her work"],
#    ['joined the military',
#     'went to the military',
#     'left for the military',
#     'enlisted in the military',
#     'was drafted into the military'],
#    nan,
#    nan,
#    ['got sick', 'fell sick', 'medical problems', 'sick'],
#    ['was relocated',
#     'had to relocated',
#     'was assigned to a new location',
#     'was assigned to a different location'],
#    nan,
#    ['changed careers'],
#    nan,
#    ['retired', 'went into retirement'],
#    nan,
#    ['poor attendance', 'bad attendance'],
#    nan,
#    ['did not come back from maternity leave', 'had a kid and dissapeared'],
#    ['poor performance', 'performed below expectations']],
#   []],
#  'employment_status': [['terminated for cause',
#    'leave of absence',
#    'active',
#    'voluntarily terminated',
#    'future start'],
#   [['fired', 'let go', 'evicted', 'kicked out', 'removed', 'dismissed'],
#    ['on absence leave'],
#    ['currently employed', 'currently working', 'currently works'],
#    ['quit', 'quitted', 'resigned', 'sent in a resignation'],
#    ['will start at a future time',
#     'will start later',
#     'will start some time in the future']],
#   ['renounce', 'employment status', 'current job status']],
#  'department': [['executive office',
#    'admin offices',
#    'production',
#    'it/is',
#    'software engineering',
#    'sales'],
#   [nan, nan, nan, nan, ['programming', 'coding', 'software development'], nan],
#   ['department', 'team', 'group', 'section', 'division', 'sector']],
#  'position': [['it manager - infra',
#    'cio',
#    'sales manager',
#    'president & ceo',
#    'administrative assistant',
#    'database administrator',
#    'area sales manager',
#    'it director',
#    'sr. accountant',
#    'it manager - support',
#    'production technician ii',
#    'network engineer',
#    'sr. network engineer',
#    'shared services manager',
#    'accountant i',
#    'it support',
#    'software engineering manager',
#    'production technician i',
#    'director of operations',
#    'director of sales',
#    'sr. dba',
#    'it manager - db',
#    'software engineer',
#    'production manager'],
#   [nan,
#    ['chief information officer'],
#    nan,
#    ['chief executive officer'],
#    nan,
#    ['db admin', 'db administrator', 'database admin'],
#    nan,
#    ['director of it'],
#    ['senior accountant'],
#    nan,
#    ['production technician 2', 'production technician two'],
#    nan,
#    ['senior network engineer'],
#    nan,
#    ['accountant 1', 'accountant one'],
#    ['tech support'],
#    nan,
#    ['production technician 1', 'production technician one'],
#    ['operations director'],
#    ['sales director'],
#    ['senior database administrator',
#     'senior db admin',
#     'senior db administrator'],
#    nan,
#    ['software developer', 'programmer'],
#    nan],
#   ['title', 'job title', 'role']],
#  'manager': [['brandon r. leblanc',
#    'janet king',
#    'board of directors',
#    'simon roup',
#    'jennifer zamora',
#    'eric dougall',
#    'peter monroe',
#    'michael albert',
#    'elijiah gray',
#    'webster butler',
#    'amy dunn',
#    'ketsia liebig',
#    'brannon miller',
#    'david stanley',
#    'kissy sullivan',
#    'kelley spirea',
#    'lynn daneault',
#    'john smith',
#    'debra houlihan',
#    'alex sweetwater'],
#   [],
#   ['manager name',
#    'manager',
#    'incharge',
#    'supervisor',
#    'mentor',
#    'leadership',
#    'boss',
#    'management',
#    'head',
#    'lead',
#    'chairman']],
#  'employee_source': [['information session',
#    'company intranet - partner',
#    'social networks - facebook twitter etc',
#    'newspager/magazine',
#    'internet search',
#    'billboard',
#    'pay per click',
#    'on-line web application',
#    'glassdoor',
#    'professional society',
#    'monster.com',
#    'diversity job fair',
#    'careerbuilder',
#    'mbta ads',
#    'word of mouth',
#    'other',
#    'vendor referral',
#    'on-campus recruiting',
#    'website banner ads',
#    'employee referral'],
#   [['info session'],
#    nan,
#    ['social media',
#     'social media apps',
#     'facebook',
#     'instagram',
#     'twitter',
#     'snapchat',
#     'social network'],
#    ['newspaper', 'magazine'],
#    ['google',
#     'bing',
#     'yahoo',
#     "search engine - google bing yahoo'",
#     'search engine'],
#    ['poster'],
#    ['ppc', 'google ads', 'google ppc', 'ppc google'],
#    ['application potal', 'job portal'],
#    ['glass door'],
#    ['professional group'],
#    ['monster'],
#    nan,
#    nan,
#    ['advertisement', 'ads'],
#    ['verbal mention'],
#    nan,
#    ['referred by vendor', 'vendor referred'],
#    ['on-campus job fair', 'career fair'],
#    nan,
#    ['referred by employee']],
#   ['how did you learn about this position',
#    'how did you find out about this job',
#    'how did you find out about this position',
#    'how did you learn about this job']],
#  'performance_score': [['exceptional',
#    'fully meets',
#    'n/a- too early to review',
#    'pip',
#    'needs improvement',
#    'exceeds',
#    '90-day meets'],
#   [['extraordinary'],
#    ['up to the mark', 'meet expectations'],
#    nan,
#    nan,
#    nan,
#    ['beyond expectations',
#     'more than expected',
#     'better than expected',
#     'higher than excpected'],
#    nan],
#   ['performance rating', 'performance score']],
#  'money': [['pay rate'],
#   [['salary', 'income', 'pay', 'earn', 'earnings', 'make']],
#   ['earns', 'makes', 'amount']],
#  'comparator': [['more than', 'equals to', 'less than'],
#   [['greater than', 'higher than'],
#    ['is exactly', 'is equal to', 'equates to'],
#    ['lower than', 'below']],
#   []],
#  'date_time': [['date of hire', 'date of termination', 'dob'],
#   [['start date', 'date of starting employment'],
#    ['end date', 'date of leaving job', 'date of ending employment'],
#    ['birthday', 'birthdate', 'birth date', 'date of birth', 'day of birth']],
#   []],
#  'function': [['percent', 'sum', 'average'],
#   [['fraction', 'portion', 'proportion', 'percentage'],
#    ['total', 'cumulative', 'added up', 'summed up. totalled', 'summed'],
#    ['mean']],
#   []],
#  'extreme': [['highest', 'lowest'],
#   [['top', 'maximum', 'most', 'greatest'],
#    ['least', 'minimum', 'bottom', 'lowest']],
#   []],
#  'employment_action': [['hired', 'terminated'],
#   [['employed'], ['fired', 'let go']],
#   []]}

# %% [markdown]
# <h4>Generate Gazetteers</h4>

# %%
gen_gazetteers(ent_dict)

# %% [markdown]
# <h4>Generate Mapping.json</h4>
