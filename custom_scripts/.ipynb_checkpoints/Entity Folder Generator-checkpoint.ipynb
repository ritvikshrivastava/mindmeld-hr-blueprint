# %%
import numpy as np
import pandas as pd
import random
import os
import json

# %% [markdown]
# <h2>Functions</h2>

# %% [markdown]
# <h3>General Functions</h3>

# %%
# Check if a Value is Nan
# param x - Value to check
# return boolean - If it is a Nan
def is_nan(x):
    return (x is np.nan or x != x)

# Check All Values in List are Nan
# param x - List to check
# return boolean - If it is all Nan
def list_is_nan(x):
    for i in x:
        if not is_nan(i): return False
    return True

# Converts names to single string
# param names (list) - List of names in the format [['Mia', 'Brown'],[..]]
# return unique (list) - List of names in the format ['Mia Brown', ..]
def name_to_str(names):
    return [",".join(name).replace(",", " ") for name in names]

# Converts names to single string
# param names (list) - List of names in the format ['Mia Brown', ..]
# return names_list (list) - List of names in the format [['Mia', 'Brown'],[..]]
def str_name_to_list(names):
    for i in range(len(names)):
        full_name = names[i].split()
        names[i] = [full_name[0], full_name[len(full_name) - 1]]
    return names

# %% [markdown]
# <h3>Get Unique Values</h3>

# %%
# Get the Names of Employees in the HR Dataset
# param df (dataframe) - Dataframe with names
# param column (str) - Column can be 'Employee Name' or 'Manager Name'
# Returns names (list) - Array of names (['First', 'Last'])
def get_names(df, column='Employee Name'):
    names = [df[[column]].iloc[i][0] for i in range(df.shape[0] - 1)]
    for i in range(len(names)):
        try:
            full_name = names[i].split(',')
            first = full_name[1].strip().split()[0]
            last = full_name[0]
            names[i] = [first, last]
        except:
            names[i] = ['Jeremy', 'Prater']
    return names

# Filter to list of unique names
# param names (list) - List of names in the format [['Mia', 'Brown'],[..]]
# param avoid (list) - List of names to avoid duplicates of
# return unique (list) - List of names in the format [['Mia', 'Brown'],[..]]
def filter_names_helper(names, avoid = []):
    unique = []
    first, last = [], []
    if(len(avoid) != 0):
        first = [n[0] for n in avoid]
        last = [n[1] for n in avoid]
    for name in names:
        if((name[0] not in first) and (name[1] not in last)):
            first.append(name[0])
            last.append(name[1])
            unique.append(name)
    return unique

# Filter to list of unique names that don't overlap with manager names
# param df (dataframe) - Dataframe with names 
# return unique (list) - List of names in the format [['Mia', 'Brown'],[..]]
def get_filtered_names(df):
    managers = str_name_to_list(get_uniq_str(df, "Manager Name"))
    managers = filter_names_helper(managers)
    survey_users = [['Mia','Brown'], ['Ivan','Rogers'], ['Julia','Soto'], ['Nan','Singh']]
    user_names = get_names(hr_data)
    user_names = filter_names_helper(user_names, avoid=survey_users)
    user_names = filter_names_helper(user_names, avoid=managers)
    user_names.extend(survey_users)
    return user_names

# %%
# Get the Unique Names of Employees in the HR Dataset
# param df (dataframe) - Dataframe with names
# return unique (list) - List of names in the format ['Mia Brown', ..]
def get_uniq_names(df):
    return filter_names(get_names(df))

# Get Unique String Values of a Dataframe Column
# param df (dataframe) - Source Dataframe
# param col_name (str) - Name of Column to get unique values'
# return uniq_arr (arr) - Array of Unique Values
def get_uniq_str(df, col_name):
    return [i.lower().strip() for i in df[col_name].unique()[:-1]]

# Get Unique String Values of a Dataframe Column
# param df (dataframe) - Source Dataframe
# param col_name (str) - Name of Column to get unique values'
# return uniq_arr (arr) - Array of Unique Values
def get_uniq_num(df, col_name):
    return [str(int(i)) for i in df[col_name].unique()[:-1]]

# Generate a Dictionary with Unique Values for Select Columns
# param df (dataframe) - Source Dataframe
# return uniq (dict) - Dictionary that maps entities to unique values
def gen_uniq_dict(df):
    # Get Unique Values of Relevant Columns
    uniq = {}
    # Predefined
    uniq['name'] = name_to_str(get_filtered_names(df))
    uniq['sex'] = ['male', 'female']
    uniq['employment_status'] = ['active', 'voluntarily terminated', 'terminated for a cause',
                          'on a leave of absence' + 'going to start work in the future']
    uniq['performance_score'] = ['fully meet performance expecations', 'are too early to review', 
                         'meet 90-day expectations', 'are exceptional', 'need improvement', 'exeed expecations']
    # Custom Preprocessing
    uniq['state'] = hr_data['State'].unique()[:-1]
    # Standard Preprocessing 
    uniq['age'] = get_uniq_num(hr_data, 'Age')
    uniq['maritaldesc'] = get_uniq_str(hr_data, "MaritalDesc")
    uniq['citizendesc'] = get_uniq_str(hr_data, "CitizenDesc")
    uniq['department'] = get_uniq_str(hr_data, "Department")
    uniq['position'] = get_uniq_str(hr_data, "Position")
    uniq['manager'] = name_to_str(str_name_to_list(get_uniq_str(hr_data, "Manager Name")))
    uniq['employee_source'] = get_uniq_str(hr_data, "Employee Source")
    return uniq

# %% [markdown]
# <h3>Load, Parse and Clean Entity Data</h3>

# %%
# Load entity data frame from CSV
# param path (str) - Path to csv
# return ent_df (dataframe) - Entity Info Dataframe
def load_ent(path):
    df = pd.read_csv(path).iloc[:, :4]
    ct = 0
    while (ct < len(df) and not list_is_nan(df.iloc[ct, :].values)): ct += 1
    return df.iloc[:ct, :]

# Parse CSV that contains [Entity, Options, Synonyms, Gazetteer]
# param ent_df (dataframe) - Contains the columns listed above
# return ent_dict (dict) - Uncleaned dictionary where the keys are the entities
#                          and the values are [options (arr), synonyms (arr), gazetteer (arr)]
def ent_parse(ent_df):
    ent_dict = {}
    ct = 0
    curr_ent = ''
    while(ct < len(ent_df)):
        row = ent_df.iloc[ct]
        # update curr_ent if new entity
        if(not is_nan(row['Entity'])): 
            curr_ent = row['Entity']
            ent_dict[curr_ent] = [[], [], []]
        # check if options is a list
        if(not is_nan(row['Options']) and row['Options'].count(',') > 2):
            ent_dict[curr_ent][0] = row['Options']
            if(not is_nan(row['Synonyms'])): 
                ent_dict[curr_ent][1] = row['Synonyms'].split(',')
            if(not is_nan(row[3])): ent_dict[curr_ent][2] = row['Gazetteer']
        # single entry in option column
        else:
            ent_dict[curr_ent][0].append(row['Options'])
            ent_dict[curr_ent][1].append(row['Synonyms'])
            ent_dict[curr_ent][2].append(row['Gazetteer'])
        ct += 1
    return ent_dict

# Cleans the gazetteers of the ent dictionary
# param ent_dict (dictionary) - Entity Dictionary
# return ent_dict (dictionary) - Cleaned Entity Dictionary
def clean_options(ent_dict):
    for i in ent_dict.keys():
        old_opt = ent_dict[i][0]
        new_opt = []
        for word in old_opt:
            if(not is_nan(word)):
                new_opt.append(word.replace("'", "").replace(",", ""))
        ent_dict[i][0] = new_opt
    return ent_dict

# Cleans the gazetteers of the ent dictionary
# param ent_dict (dictionary) - Entity Dictionary
# return ent_dict (dictionary) - Cleaned Entity Dictionary
def clean_synonyms(ent_dict):
    for i in ent_dict.keys():
        old_syn = ent_dict[i][1]
        new_syn = []
        if(len(old_syn) != 0):
            for j in old_syn:
                if(not is_nan(j)): new_syn.append([string.strip() for string in j.split(',')])
                else: new_syn.append(j)
        ent_dict[i][1] = new_syn
    return ent_dict

# Cleans the gazetteers of the ent dictionary
# param ent_dict (dictionary) - Entity Dictionary
# return ent_dict (dictionary) - Cleaned Entity Dictionary
def clean_gazetteer(ent_dict):
    for i in ent_dict.keys():
        old_gaz = ent_dict[i][2]
        clean_gaz = []
        if (len(old_gaz) != 0):        
            if (type(old_gaz) is str): clean_gaz = old_gaz.split(',')
            elif(not is_nan(old_gaz[0])): clean_gaz = (old_gaz[0].split(','))
        ent_dict[i][2] = [i.strip() for i in clean_gaz]
    return ent_dict

# Cleans an Entity Dictionary
# ent_dict (dict) - Uncleaned dictionary of parsed entity information
# uniq (dict) - Dictionary that maps entities to unique values
# return cleaned_ent_dict (dict) - Cleaned dictionary
def clean_ent_dict(ent_dict, uniq):
    ent_dict = clean_options(ent_dict)
    ent_dict = clean_synonyms(ent_dict)
    ent_dict = clean_gazetteer(ent_dict)
    ent_dict['name'][0] = uniq['name']
    ent_dict['state'][0] = uniq['state']
    ent_dict['age'][0] = uniq['age']
    ent_dict['manager'][0] = uniq['manager']
    return ent_dict

# Parse and Clean Entity Data
# Parse CSV that contains [Entity, Options, Synonyms, Gazetteer]
# param ent_df (dataframe) - Contains the columns listed above
def parse_clean_ent(ent_df, uniq):
    ent = ent_parse(ent_df)
    return clean_ent_dict(ent, uniq)

# %% [markdown]
# <h3>File Generation</h3>

# %%
# Convert a list into a text file
# param folder (str) - Name of the folder to write the file
# param lines (list) - List of values to write to file
def list_to_txt_file(folder, lines):
    directory = '../hr_assistant/entities/' + folder + '/'
    if not os.path.exists(directory): os.makedirs(directory)
    with open(directory + 'gazetteer.txt', 'w+') as filehandle:  
        filehandle.writelines("%s\n" % line for line in lines)
        
# Convert a dict into a json file
# param folder (str) - Name of the folder to write the file
# param dict (dict) - Json dict to write to file
def dict_to_json_file(folder, json_dict):
    directory = '../hr_assistant/entities/' + folder + '/'
    if not os.path.exists(directory): os.makedirs(directory)
    with open(directory + "mapping.json", "w+") as f:
        json_str = json.dumps(json_dict, indent=4)
        f.write(json_str)
        
# Generate a Mapping JSON Dict to create Mapping.json file
# param ent_dict (dict) - Dictionary that maps entities to options, synonyms, and gazetteer
# param entity (str) - The entity to generate the gazetteer list for
# return json_dict (dict) - Json Dict in the proper format for mapping.json
def gen_map_json(ent_dict, entity):
    opt = ent_dict[entity][0]
    syn = ent_dict[entity][1]
    # Check if the Options and the Synonyms Align
    if(len(opt) != len(syn)): syn = [[] for i in range(len(opt))]
    return gen_map_json_helper(opt, syn)

# Helper function to Generate a Mapping JSON Dictionary
# param options (list) - Array of options
# param synonyms (2d list) - Array of synonym arrays corresponding to options
# return json_dict (dict) - Json Dict in the proper format for mapping.json
def gen_map_json_helper(options, synonyms):
    json_dict = {}
    json_dict['entities'] = []
    for i in range(len(options)):
        new_dict = {}
        if(is_nan(synonyms[i])): new_dict['whitelist'] = []
        else: new_dict['whitelist'] = synonyms[i]
        new_dict['cname'] = options[i]
        json_dict['entities'].append(new_dict)
    return json_dict

# Create Mapping.json files for Every Entity in an Entity Dictionary
# param ent_dict (dict) - Dictionary that maps entities to options, synonyms, and gazetteer
def gen_map_json_files(ent_dict):
    for entity in ent_dict.keys():
        json_dict = gen_map_json(ent_dict, entity)
        if(not is_nan(json_dict)): dict_to_json_file(entity, json_dict)

# Collect All Synonyms for a Single Entity in Entity Dict
# param ent_dict (dict) - Dictionary that maps entities to options, synonyms, and gazetteer
# param entity (str) - The entity to get Synyonyms for
# return synonyms (list) - List of Synonyms of Specified entity
def get_synonyms(ent_dict, entity):
    synonyms = []
    for syn in ent_dict[entity][1]:
        if(not is_nan(syn)): synonyms.extend(syn)
    return synonyms

# Generate a Gazetter List for an Entity
# param ent_dict (dict) - Dictionary that maps entities to options, synonyms, and gazetteer
# param entity (str) - The entity to generate the gazetteer list for
# return gaz (list) - List of gazetteer word relevant to the entity
def gen_gaz_list(ent_dict, entity):
    gaz = []
    gaz.extend(ent_dict[entity][0])
    gaz.extend(get_synonyms(ent_dict, entity))
    gaz.extend(ent_dict[entity][2])
    return gaz

# Create Gazetteer Files for Every Entity in an Entity Dictionary
# param ent_dict (dict) - Dictionary that maps entities to options, synonyms, and gazetteer
def gen_gazetteers(ent_dict):
    for entity in ent_dict.keys():
        gaz_list = gen_gaz_list(ent_dict, entity)
        list_to_txt_file(entity, gaz_list)

# %% [markdown]
# <h2>Workflow</h2>

# %% [markdown]
# <h4>Load Data</h4>

# %%
hr_data = pd.read_csv('old_core_dataset.csv')
hr_data
# Out:
#              Employee Name  Employee Number State      Zip         DOB   Age  \
# 0               Brown, Mia     1.103024e+09    MA   1450.0  11/24/1985  32.0
# 1     LaRotonda, William       1.106027e+09    MA   1460.0   4/26/1984  33.0
# 2         Steans, Tyrone       1.302053e+09    MA   2703.0    9/1/1986  31.0
# 3          Howard, Estelle     1.211051e+09    MA   2170.0   9/16/1985  32.0
# 4              Singh, Nan      1.307060e+09    MA   2330.0   5/19/1988  29.0
# 5         Smith, Leigh Ann     7.110077e+08    MA   1844.0   6/14/1987  30.0
# 6      LeBlanc, Brandon  R     1.102024e+09    MA   1460.0   6/10/1984  33.0
# 7              Quinn, Sean     1.206043e+09    MA   2045.0   11/6/1984  33.0
# 8        Boutwell, Bonalyn     1.307060e+09    MA   2468.0    4/4/1987  30.0
# 9        Foster-Baker, Amy     1.201031e+09    MA   2050.0   4/16/1979  38.0
# 10             King, Janet     1.001495e+09    MA   1902.0   9/21/1954  63.0
# 11        Zamora, Jennifer     1.112031e+09    MA   2067.0   8/30/1979  38.0
# 12           Becker, Renee     1.102024e+09    MA   2026.0    4/4/1986  31.0
# 13           Goble, Taisha     9.050137e+08    MA   2127.0  10/23/1971  46.0
# 14       Hernandez, Daniff     1.410071e+09    MA   1960.0    8/7/1986  31.0
# 15           Horton, Jayne     1.105026e+09    MA   2493.0   2/21/1984  33.0
# 16        Johnson, Noelle      1.003018e+09    MA   2301.0   11/7/1986  31.0
# 17          Murray, Thomas     1.406068e+09    TX  78230.0    7/4/1988  29.0
# 18        Pearson, Randall     1.102024e+09    MA   2747.0    9/5/1984  33.0
# 19       Petrowsky, Thelma     1.108028e+09    MA   1886.0   9/16/1984  33.0
# 20             Roby, Lori      1.407069e+09    MA   1886.0  10/11/1981  36.0
# 21            Rogers, Ivan     1.203032e+09    MA   1810.0   8/26/1986  31.0
# 22           Salter, Jason     1.111030e+09    MA   2452.0  12/17/1987  30.0
# 23          Simard, Kramer     8.080103e+08    MA   2110.0    2/8/1970  47.0
# 24             Zhou, Julia     1.110030e+09    MA   2148.0   2/24/1979  38.0
# 25             Foss, Jason     1.192991e+09    MA   1460.0    7/5/1980  37.0
# 26              Roup,Simon     1.106027e+09    MA   2481.0    4/5/1973  44.0
# 27           Ruiz, Ricardo     1.001175e+09    MA   1915.0    1/4/1964  54.0
# 28           Monroe, Peter     1.011023e+09    MA   2134.0   10/5/1986  31.0
# 29           Dougall, Eric     1.101024e+09    MA   1886.0    7/9/1970  47.0
# ..                     ...              ...   ...      ...         ...   ...
# 272          Jeremy Prater     1.001085e+09    NV  89139.0    5/9/1974  43.0
# 273  Khemmich, Bartholemew     1.104025e+09    CO  80820.0  11/27/1979  38.0
# 274       Leruth, Giovanni     1.412072e+09    UT  84111.0  12/27/1988  29.0
# 275        Martins, Joseph     1.209049e+09    TX  78207.0   6/11/1970  47.0
# 276          McKinzie, Jac     1.209049e+09    TX  78789.0    7/1/1984  33.0
# 277       Mullaney, Howard     1.306058e+09    AL  36006.0   11/2/1975  42.0
# 278         Nguyen, Dheepa     1.111031e+09    GA  30428.0   3/31/1989  28.0
# 279         Onque, Jasmine     1.501072e+09    FL  33174.0   5/11/1990  27.0
# 280          Ozark, Travis     8.120118e+08    NC  27229.0   5/19/1982  35.0
# 281            Potts, Xana     1.102024e+09    KY  40220.0   8/29/1988  29.0
# 282       Riordan, Michael     1.502073e+09    ND  58782.0   1/15/1968  50.0
# 283        Strong, Caitrin     1.411071e+09    MT  59102.0   5/12/1989  28.0
# 284       Terry, Sharlene      1.401065e+09    OR  97756.0    5/7/1965  52.0
# 285        Valentin,Jackie     1.312064e+09    AZ  85006.0   5/23/1991  26.0
# 286       Villanueva, Noah     1.111031e+09    ME   4063.0   7/11/1989  28.0
# 287        Houlihan, Debra     1.009022e+09    RI   2908.0   3/17/1966  51.0
# 288         Daneault, Lynn     1.402065e+09    VT   5473.0   4/19/1990  27.0
# 289    Kampew, Donysha         1.109029e+09    PA  19444.0  11/11/1989  28.0
# 290            Smith, John     1.499903e+09    MA   1886.0   8/16/1984  33.0
# 291        Andreola, Colby     1.107027e+09    MA   2110.0   5/24/1979  38.0
# 292       Carabbio, Judith     1.101024e+09    MA   2132.0    4/5/1987  30.0
# 293      Del Bosque, Keyla     1.203032e+09    MA   2176.0    7/5/1979  38.0
# 294         Exantus, Susan     1.401065e+09    MA   1749.0   5/15/1987  30.0
# 295         Martin, Sandra     1.303055e+09    MA   2135.0   11/7/1987  30.0
# 296        Patronick, Luke     1.112031e+09    MA   1844.0   2/20/1979  38.0
# 297           Saada, Adell     1.012023e+09    MA   2132.0   7/24/1986  31.0
# 298          Szabo, Andrew     1.201031e+09    MA   2140.0    5/6/1983  34.0
# 299           True, Edward     1.102024e+09    MA   2451.0   6/14/1983  34.0
# 300       Sweetwater, Alex     1.001645e+09    MA   2184.0  11/22/1966  51.0
# 301                    NaN              NaN   NaN      NaN         NaN   NaN
#
#         Sex MaritalDesc          CitizenDesc Hispanic/Latino  ...  \
# 0    Female     Married           US Citizen              No  ...
# 1      Male    Divorced           US Citizen              No  ...
# 2      Male      Single           US Citizen              No  ...
# 3    Female     Married           US Citizen              No  ...
# 4    Female      Single           US Citizen              No  ...
# 5    Female     Married           US Citizen              No  ...
# 6      Male     Married           US Citizen              No  ...
# 7      Male     Married  Eligible NonCitizen              No  ...
# 8    Female     Married           US Citizen              No  ...
# 9    Female     Married           US Citizen              no  ...
# 10   Female     Married           US Citizen             Yes  ...
# 11   Female      Single           US Citizen              No  ...
# 12   Female      Single           US Citizen             Yes  ...
# 13   Female      Single           US Citizen              No  ...
# 14     Male     Married           US Citizen              No  ...
# 15   Female      Single           US Citizen              No  ...
# 16   Female     Married           US Citizen              No  ...
# 17     Male    Divorced           US Citizen              No  ...
# 18     Male     Married           US Citizen              No  ...
# 19   Female     Married           US Citizen              No  ...
# 20   Female     Married           US Citizen              No  ...
# 21     Male     Married           US Citizen              No  ...
# 22     Male    Divorced           US Citizen              No  ...
# 23     Male     Married           US Citizen             Yes  ...
# 24   Female      Single           US Citizen              No  ...
# 25     Male      Single           US Citizen              No  ...
# 26     Male      Single           US Citizen              No  ...
# 27     Male    Divorced           US Citizen              No  ...
# 28     Male     Married  Eligible NonCitizen             Yes  ...
# 29     Male      Single           US Citizen              No  ...
# ..      ...         ...                  ...             ...  ...
# 272    Male     Married           US Citizen              No  ...
# 273    Male      Single           US Citizen              No  ...
# 274    Male   Separated           US Citizen              No  ...
# 275    Male      Single  Eligible NonCitizen              No  ...
# 276    Male     Married           US Citizen              No  ...
# 277    Male      Single           US Citizen              No  ...
# 278  Female      Single           US Citizen              No  ...
# 279  Female      Single           US Citizen             Yes  ...
# 280    Male      Single           US Citizen              No  ...
# 281  Female     Married           US Citizen              No  ...
# 282    Male   Separated           US Citizen              No  ...
# 283  Female     Married           US Citizen              No  ...
# 284  Female      Single           US Citizen              No  ...
# 285  Female     Married           US Citizen              No  ...
# 286    Male      Single           US Citizen              No  ...
# 287  Female     Married           US Citizen              No  ...
# 288  Female      Single           US Citizen              No  ...
# 289  Female      Single           US Citizen              No  ...
# 290    Male    Divorced           US Citizen              no  ...
# 291  Female      Single           US Citizen              No  ...
# 292  Female      Single           US Citizen              No  ...
# 293  Female      Single           US Citizen              No  ...
# 294  Female     Married           US Citizen              No  ...
# 295  Female   Separated           US Citizen              No  ...
# 296    Male      Single           US Citizen              No  ...
# 297  Female     Married           US Citizen              No  ...
# 298    Male      Single           US Citizen              No  ...
# 299    Male      Single          Non-Citizen              No  ...
# 300    Male      Single           US Citizen              No  ...
# 301     NaN         NaN                  NaN             NaN  ...
#
#     Date of Hire Date of Termination                   Reason For Term  \
# 0     10/27/2008                 NaN              N/A - still employed
# 1       1/6/2014                 NaN              N/A - still employed
# 2      9/29/2014                 NaN              N/A - still employed
# 3      2/16/2015           4/15/2015              N/A - still employed
# 4       5/1/2015                 NaN              N/A - still employed
# 5      9/26/2011           9/25/2013                     career change
# 6       1/5/2016                 NaN              N/A - still employed
# 7      2/21/2011           8/15/2015                     career change
# 8      2/16/2015                 NaN              N/A - still employed
# 9       1/5/2009                 NaN              N/A - still employed
# 10      7/2/2012                 NaN              N/A - still employed
# 11     4/10/2010                 NaN              N/A - still employed
# 12      7/7/2014           9/12/2015                       performance
# 13     2/16/2015           3/15/2015                  no-call, no-show
# 14     2/16/2015           2/22/2015                  no-call, no-show
# 15     3/30/2015                 NaN              N/A - still employed
# 16      1/5/2015                 NaN              N/A - still employed
# 17    11/10/2014                 NaN              N/A - still employed
# 18     12/1/2014            5/1/2016                       performance
# 19    11/10/2014                 NaN              N/A - still employed
# 20     2/16/2015                 NaN              N/A - still employed
# 21     3/30/2015                 NaN              N/A - still employed
# 22      1/5/2015          10/31/2015                             hours
# 23      1/5/2015                 NaN              N/A - still employed
# 24     3/30/2015                 NaN              N/A - still employed
# 25     4/15/2011                 NaN              N/A - still employed
# 26     1/20/2013                 NaN              N/A - still employed
# 27      1/9/2012           11/4/2015                             hours
# 28     2/15/2012                 NaN              N/A - still employed
# 29      1/5/2014                 NaN              N/A - still employed
# ..           ...                 ...                               ...
# 272    5/12/2014                 NaN              N/A - still employed
# 273    8/19/2013                 NaN              N/A - still employed
# 274    4/30/2012                 NaN              N/A - still employed
# 275    5/14/2012                 NaN              N/A - still employed
# 276     7/6/2016                 NaN         N/A - Has not started yet
# 277    9/29/2014                 NaN              N/A - still employed
# 278     7/8/2013                 NaN              N/A - still employed
# 279    9/30/2013                 NaN              N/A - still employed
# 280     1/5/2015                 NaN              N/A - still employed
# 281     1/9/2012                 NaN              N/A - still employed
# 282     1/9/2006                 NaN              N/A - still employed
# 283    9/27/2010                 NaN              N/A - still employed
# 284    9/29/2014                 NaN              N/A - still employed
# 285     7/5/2011                 NaN              N/A - still employed
# 286     3/5/2012                 NaN              N/A - still employed
# 287     5/5/2014                 NaN              N/A - still employed
# 288     5/5/2014                 NaN              N/A - still employed
# 289    11/7/2011           4/24/2014  maternity leave - did not return
# 290    5/18/2014                 NaN              N/A - still employed
# 291   11/10/2014                 NaN              N/A - still employed
# 292   11/11/2013                 NaN              N/A - still employed
# 293     1/9/2012                 NaN              N/A - still employed
# 294     5/2/2011            6/5/2013                        attendance
# 295   11/11/2013                 NaN              N/A - still employed
# 296    11/7/2011            9/7/2015                  Another position
# 297    11/5/2012                 NaN              N/A - still employed
# 298     7/7/2014                 NaN              N/A - still employed
# 299    2/18/2013           4/15/2014                    medical issues
# 300    8/15/2011                 NaN              N/A - still employed
# 301          NaN                 NaN                               NaN
#
#           Employment Status                 Department  \
# 0                    Active              Admin Offices
# 1                    Active              Admin Offices
# 2                    Active              Admin Offices
# 3                    Active              Admin Offices
# 4                    Active              Admin Offices
# 5    Voluntarily Terminated              Admin Offices
# 6                    Active              Admin Offices
# 7    Voluntarily Terminated              Admin Offices
# 8                    Active              Admin Offices
# 9                    Active              Admin Offices
# 10                   Active           Executive Office
# 11                   Active                      IT/IS
# 12     Terminated for Cause                      IT/IS
# 13     Terminated for Cause                      IT/IS
# 14     Terminated for Cause                      IT/IS
# 15                   Active                      IT/IS
# 16         Leave of Absence                      IT/IS
# 17                   Active                      IT/IS
# 18   Voluntarily Terminated                      IT/IS
# 19                   Active                      IT/IS
# 20                   Active                      IT/IS
# 21                   Active                      IT/IS
# 22   Voluntarily Terminated                      IT/IS
# 23                   Active                      IT/IS
# 24                   Active                      IT/IS
# 25                   Active                      IT/IS
# 26                   Active                      IT/IS
# 27   Voluntarily Terminated                      IT/IS
# 28                   Active                      IT/IS
# 29                   Active                      IT/IS
# ..                      ...                        ...
# 272                  Active                      Sales
# 273                  Active                      Sales
# 274                  Active                      Sales
# 275                  Active                      Sales
# 276            Future Start                      Sales
# 277                  Active                      Sales
# 278                  Active                      Sales
# 279                  Active                      Sales
# 280                  Active                      Sales
# 281                  Active                      Sales
# 282                  Active                      Sales
# 283                  Active                      Sales
# 284                  Active                      Sales
# 285                  Active                      Sales
# 286                  Active                      Sales
# 287                  Active                      Sales
# 288                  Active                      Sales
# 289  Voluntarily Terminated                      Sales
# 290                  Active                      Sales
# 291                  Active       Software Engineering
# 292                  Active       Software Engineering
# 293                  Active       Software Engineering
# 294    Terminated for Cause       Software Engineering
# 295                  Active       Software Engineering
# 296  Voluntarily Terminated       Software Engineering
# 297                  Active       Software Engineering
# 298                  Active       Software Engineering
# 299  Voluntarily Terminated       Software Engineering
# 300                  Active  Software Engineering
# 301                     NaN                        NaN
#
#                          Position Pay Rate        Manager Name  \
# 0                    Accountant I    28.50  Brandon R. LeBlanc
# 1                    Accountant I    23.00  Brandon R. LeBlanc
# 2                    Accountant I    29.00  Brandon R. LeBlanc
# 3        Administrative Assistant    21.50  Brandon R. LeBlanc
# 4        Administrative Assistant    16.56  Brandon R. LeBlanc
# 5        Administrative Assistant    20.50  Brandon R. LeBlanc
# 6         Shared Services Manager    55.00          Janet King
# 7         Shared Services Manager    55.00          Janet King
# 8                  Sr. Accountant    34.95  Brandon R. LeBlanc
# 9                  Sr. Accountant    34.95  Board of Directors
# 10                President & CEO    80.00  Board of Directors
# 11                            CIO    65.00          Janet King
# 12         Database Administrator    43.00          Simon Roup
# 13         Database Administrator    48.50          Simon Roup
# 14         Database Administrator    40.10          Simon Roup
# 15         Database Administrator    34.00          Simon Roup
# 16         Database Administrator    40.00          Simon Roup
# 17         Database Administrator    35.50          Simon Roup
# 18         Database Administrator    41.00          Simon Roup
# 19         Database Administrator    42.75          Simon Roup
# 20         Database Administrator    39.55          Simon Roup
# 21         Database Administrator    42.20          Simon Roup
# 22         Database Administrator    45.00          Simon Roup
# 23         Database Administrator    30.20          Simon Roup
# 24         Database Administrator    31.40          Simon Roup
# 25                    IT Director    65.00     Jennifer Zamora
# 26                IT Manager - DB    62.00     Jennifer Zamora
# 27                IT Manager - DB    21.00     Jennifer Zamora
# 28             IT Manager - Infra    63.00     Jennifer Zamora
# 29           IT Manager - Support    64.00     Jennifer Zamora
# ..                            ...      ...                 ...
# 272            Area Sales Manager    56.00       Lynn Daneault
# 273            Area Sales Manager    55.00       Lynn Daneault
# 274            Area Sales Manager    55.00          John Smith
# 275            Area Sales Manager    56.00       Lynn Daneault
# 276            Area Sales Manager    55.00       Lynn Daneault
# 277            Area Sales Manager    55.00          John Smith
# 278            Area Sales Manager    55.00       Lynn Daneault
# 279            Area Sales Manager    57.00       Lynn Daneault
# 280            Area Sales Manager    55.00          John Smith
# 281            Area Sales Manager    55.00       Lynn Daneault
# 282            Area Sales Manager    55.00       Lynn Daneault
# 283            Area Sales Manager    54.00          John Smith
# 284            Area Sales Manager    55.00       Lynn Daneault
# 285            Area Sales Manager    55.00          John Smith
# 286            Area Sales Manager    56.00          John Smith
# 287             Director of Sales    60.00          Janet King
# 288                 Sales Manager    54.00      Debra Houlihan
# 289                 Sales Manager    60.25      Debra Houlihan
# 290                 Sales Manager    56.00      Debra Houlihan
# 291             Software Engineer    47.60     Alex Sweetwater
# 292             Software Engineer    56.00     Alex Sweetwater
# 293             Software Engineer    57.12     Alex Sweetwater
# 294             Software Engineer    48.50     Alex Sweetwater
# 295             Software Engineer    55.51     Alex Sweetwater
# 296             Software Engineer    52.25     Alex Sweetwater
# 297             Software Engineer    49.25     Alex Sweetwater
# 298             Software Engineer    48.00     Alex Sweetwater
# 299             Software Engineer    45.42     Alex Sweetwater
# 300  Software Engineering Manager    27.00     Jennifer Zamora
# 301                           NaN      NaN                 NaN
#
#                             Employee Source         Performance Score
# 0                        Diversity Job Fair               Fully Meets
# 1                        Website Banner Ads               Fully Meets
# 2                           Internet Search               Fully Meets
# 3                    Pay Per Click - Google  N/A- too early to review
# 4                        Website Banner Ads  N/A- too early to review
# 5                        Diversity Job Fair               Fully Meets
# 6                               Monster.com               Fully Meets
# 7                        Diversity Job Fair               Fully Meets
# 8                        Diversity Job Fair              90-day meets
# 9                                     Other               Fully Meets
# 10                   Pay Per Click - Google               Fully Meets
# 11                        Employee Referral               Exceptional
# 12        Search Engine - Google Bing Yahoo               Fully Meets
# 13                                Glassdoor               Fully Meets
# 14                        Employee Referral  N/A- too early to review
# 15                                Glassdoor  N/A- too early to review
# 16                                Glassdoor              90-day meets
# 17                       Diversity Job Fair               Exceptional
# 18                        Employee Referral               Fully Meets
# 19                        Employee Referral               Exceptional
# 20                        Employee Referral               Fully Meets
# 21                   Pay Per Click - Google  N/A- too early to review
# 22                          Vendor Referral              90-day meets
# 23                        Employee Referral              90-day meets
# 24                        Employee Referral              90-day meets
# 25                     Professional Society               Exceptional
# 26                     Professional Society               Fully Meets
# 27                       Diversity Job Fair               Fully Meets
# 28                       Diversity Job Fair         Needs Improvement
# 29                     Professional Society                   Exceeds
# ..                                      ...                       ...
# 272                      Website Banner Ads                       PIP
# 273                  Pay Per Click - Google               Fully Meets
# 274                      Website Banner Ads               Fully Meets
# 275                       Employee Referral               Fully Meets
# 276                      Website Banner Ads  N/A- too early to review
# 277                         Internet Search         Needs Improvement
# 278                  Pay Per Click - Google               Fully Meets
# 279                  Pay Per Click - Google               Fully Meets
# 280                      Website Banner Ads              90-day meets
# 281                      Website Banner Ads               Fully Meets
# 282                               Billboard                   Exceeds
# 283                    Professional Society               Fully Meets
# 284                             Monster.com               Fully Meets
# 285                                   Other               Fully Meets
# 286                      Website Banner Ads               Fully Meets
# 287                                MBTA ads               Fully Meets
# 288                  Pay Per Click - Google               Fully Meets
# 289  Social Networks - Facebook Twitter etc               Fully Meets
# 290                      Diversity Job Fair         Needs Improvement
# 291                         Vendor Referral               Fully Meets
# 292                  Pay Per Click - Google              90-day meets
# 293                             Monster.com              90-day meets
# 294                               Billboard         Needs Improvement
# 295       Search Engine - Google Bing Yahoo               Fully Meets
# 296                      Diversity Job Fair                   Exceeds
# 297                  Pay Per Click - Google               Fully Meets
# 298                                MBTA ads               Exceptional
# 299                      Diversity Job Fair               Fully Meets
# 300       Search Engine - Google Bing Yahoo               Fully Meets
# 301                                     NaN                       NaN
#
# [302 rows x 21 columns]

# %% [markdown]
# <h4>Create Unique Values Dictionary</h4>

# %%
uniq = gen_uniq_dict(hr_data)

# %% [markdown]
# <h4>Load Entities</h4>

# %%
ent_df = load_ent('HR Manager Schema - Entities.csv')
ent_df
# Out:
#                      Entity  \
# 0                      name
# 1                     state
# 2                       age
# 3                       sex
# 4                       NaN
# 5               maritaldesc
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                       NaN
# 10              citizendesc
# 11                      NaN
# 12                      NaN
# 13                 racedesc
# 14                      NaN
# 15                      NaN
# 16                      NaN
# 17                      NaN
# 18                      NaN
# 19   reason_for_termination
# 20                      NaN
# 21                      NaN
# 22                      NaN
# 23                      NaN
# 24                      NaN
# 25                      NaN
# 26                      NaN
# 27                      NaN
# 28                      NaN
# 29                      NaN
# ..                      ...
# 84                      NaN
# 85                      NaN
# 86                      NaN
# 87                      NaN
# 88                      NaN
# 89                      NaN
# 90                      NaN
# 91                      NaN
# 92        performance_score
# 93                      NaN
# 94                      NaN
# 95                      NaN
# 96                      NaN
# 97                      NaN
# 98                      NaN
# 99                    money
# 100              comparator
# 101                     NaN
# 102                     NaN
# 103               date_time
# 104                     NaN
# 105                     NaN
# 106           time_interval
# 107                function
# 108                     NaN
# 109                     NaN
# 110                 extreme
# 111                     NaN
# 112       employment_action
# 113                     NaN
#
#                                                Options  \
# 0                                                  NaN
# 1    MA', 'TX', 'CT', 'VA', 'VT', 'CA', 'WA', 'NH',...
# 2                                                  age
# 3                                                 male
# 4                                               female
# 5                                              married
# 6                                             divorced
# 7                                               single
# 8                                            separated
# 9                                              widowed
# 10                                          us citizen
# 11                                 eligible noncitizen
# 12                                         non-citizen
# 13                           black or african american
# 14                                               asian
# 15                                   two or more races
# 16                                             white',
# 17                                          hispanic',
# 18                   american indian or alaska native'
# 19                                  return to school',
# 20                                  another position',
# 21                                           unhappy',
# 22                                          military',
# 23                                  gross misconduct',
# 24                                             hours',
# 25                                    medical issues',
# 26                            relocation out of area',
# 27                                        more money',
# 28                                     career change',
# 29                         n/a - has not started yet',
# ..                                                 ...
# 84                                     careerbuilder',
# 85                                          mbta ads',
# 86                                     word of mouth',
# 87                                             other',
# 88                                   vendor referral',
# 89                              on-campus recruiting',
# 90                                website banner ads',
# 91                                 employee referral',
# 92                                       exceptional',
# 93                                       fully meets',
# 94                          n/a- too early to review',
# 95                                               pip',
# 96                                 needs improvement',
# 97                                           exceeds',
# 98                                       90-day meets'
# 99                                            pay rate
# 100                                          more than
# 101                                          equals to
# 102                                          less than
# 103                                     date of hire',
# 104                              date of termination',
# 105                                              dob',
# 106                                      time_interval
# 107                                            percent
# 108                                                sum
# 109                                            average
# 110                                            highest
# 111                                             lowest
# 112                                              hired
# 113                                         terminated
#
#                                               Synonyms  \
# 0                                                  NaN
# 1    Massachussets, Texas, Connecticut, Virginia, V...
# 2                      old, years old, age of, ages of
# 3      men, males, guys, dudes, gents, gentlemen, boys
# 4    women, females, ladies, lady, ladys, girls, ga...
# 5    wed, legally married, espoused, joined in holy...
# 6                                                  NaN
# 7                    unmarried, bachelor, bachelorette
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13           black, african american, african-american
# 14                                           from asia
# 15   multiracial, multi-racial, mixed, mixed race, ...
# 16                                           caucasian
# 17                                              latino
# 18   native, natives, indians, indian, american ind...
# 19   went back to school, had to go to school again...
# 20   took on another job, landed a new position, ch...
# 21   wasn't happy, didn't like his job, didn't like...
# 22   joined the military, went to the military, lef...
# 23                                                 NaN
# 24                                                 NaN
# 25         got sick, fell sick, medical problems, sick
# 26   was relocated, had to relocated, was assigned ...
# 27                                                 NaN
# 28                                     changed careers
# 29                                                 NaN
# ..                                                 ...
# 84                                                 NaN
# 85                                  advertisement, ads
# 86                                      verbal mention
# 87                                                 NaN
# 88                 referred by vendor, vendor referred
# 89                     on-campus job fair, career fair
# 90                                                 NaN
# 91                                referred by employee
# 92                                       extraordinary
# 93                   up to the mark, meet expectations
# 94                                                 NaN
# 95                                                 NaN
# 96                                                 NaN
# 97   beyond expectations, more than expected, bette...
# 98                                                 NaN
# 99   salary, income, pay, earn, earnings, make, dol...
# 100  greater than, higher than, longer, over, older...
# 101                is exactly, is equal to, equates to
# 102               lower than, below, under, fewer than
# 103  start date, date of starting employment, hirin...
# 104  end date, date of leaving job, date of ending ...
# 105  birthday, birthdate, birth date, date of birth...
# 106  yearly, monthly, annually, bi-weekly, hourly, ...
# 107       fraction, portion, proportion, percentage, %
# 108  total, cumulative, added up, summed up. totall...
# 109                           mean, typical, typically
# 110                  top, maximum, most, greatest, max
# 111                least, minimum, bottom, lowest, min
# 112                                employed, recruited
# 113                                      fired, let go
#
#                                              Gazetteer
# 0                                                  NaN
# 1    state, state of birth, state of residence, off...
# 2                                                  NaN
# 3        sex, gender, masculine, feminine, male person
# 4                                                  NaN
# 5    husbandless, without a partner, unwedded, wife...
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10   immigrant, illegal immigrant, h1 visa, foreign...
# 11                                                 NaN
# 12                                                 NaN
# 13   ethnicity, race, racial background, ethnic gro...
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 84                                                 NaN
# 85                                                 NaN
# 86                                                 NaN
# 87                                                 NaN
# 88                                                 NaN
# 89                                                 NaN
# 90                                                 NaN
# 91                                                 NaN
# 92               performance rating, performance score
# 93                                                 NaN
# 94                                                 NaN
# 95                                                 NaN
# 96                                                 NaN
# 97                                                 NaN
# 98                                                 NaN
# 99                                earns, makes, amount
# 100                                                NaN
# 101                                                NaN
# 102                                                NaN
# 103                                               year
# 104                                                NaN
# 105                                                NaN
# 106  00's, 10's, 20's, 30's, 40's, 50's, 60's, 70's...
# 107                  distribution, turn over rate, pct
# 108                                                NaN
# 109                                                NaN
# 110                                                NaN
# 111                                                NaN
# 112                                             joined
# 113                                                NaN
#
# [114 rows x 4 columns]

# %%
ent_dict = parse_clean_ent(ent_df, uniq)
ent_dict
# Out:
# {'name': [['William LaRotonda',
#    'Tyrone Steans',
#    'Estelle Howard',
#    'Leigh Smith',
#    'Brandon LeBlanc',
#    'Sean Quinn',
#    'Bonalyn Boutwell',
#    'Amy Foster-Baker',
#    'Janet King',
#    'Jennifer Zamora',
#    'Renee Becker',
#    'Taisha Goble',
#    'Daniff Hernandez',
#    'Jayne Horton',
#    'Noelle Johnson',
#    'Thomas Murray',
#    'Randall Pearson',
#    'Thelma Petrowsky',
#    'Lori Roby',
#    'Jason Salter',
#    'Kramer Simard',
#    'Simon Roup',
#    'Ricardo Ruiz',
#    'Peter Monroe',
#    'Eric Dougall',
#    'Rick Clayton',
#    'Lisa Galia',
#    'Leonara Lindsay',
#    'Alejandro Bacong',
#    'Anthony Cisco',
#    'Linda Dolan',
#    'Maria Gonzalez',
#    'Carlos Merlos',
#    'Tanya Morway',
#    'Anita Shepard',
#    'Neville Tredinnick',
#    'Jumil Turpin',
#    'Karthikeyan Ait Sidi',
#    'Claudia Carr',
#    'Donald Favis',
#    'Bianca Roehrich',
#    'Ann Daniele',
#    'Jyoti Lajiri',
#    'Jeremiah Semizoglou',
#    'Joe South',
#    'Sarah Warfield',
#    'Elisa Bramante',
#    'Michael Albert',
#    'Charles Bozzi',
#    'Webster Butler',
#    'Elijiah Gray',
#    'Jonathan Hogland',
#    'Walter Immediato',
#    'Ketsia Liebig',
#    'Brannon Miller',
#    'Ebonee Peterson',
#    'Kelley Spirea',
#    'David Stanley',
#    'Kissy Sullivan',
#    'Courtney Wallace',
#    'Wilson Adinolfi',
#    'Trina Alagbe',
#    'Carol Anderson',
#    'Sam Athwal',
#    'Rachael Baczenski',
#    'Francesco Barone',
#    'Nader Barton',
#    'Lowan Biden',
#    'Helen Billis',
#    'Donna Brill',
#    'Josephine Bugali',
#    'Beatrice Chace',
#    'Lin Chan',
#    'Donovan Chang',
#    'Enola Chivukula',
#    'Caroline Cierpiszewski',
#    'Elijian Clukey',
#    'James Cockel',
#    'Spencer Cole',
#    'Jean Crimmings',
#    "Jene'ya Darson",
#    'Carl Desimone',
#    'Geoff Dickinson',
#    'Lily DiNocco',
#    'Denisa Dobrin',
#    'Marianne Eaton',
#    'Rex England',
#    'Miguel Estremera',
#    'April Evensen',
#    'Susan Ferguson',
#    'Nilson Fernandes',
#    'Violeta Ferreira',
#    'Libby Fidelia',
#    'Raul Garcia',
#    'Hamish Garneau',
#    'Barbara Gaul',
#    'Mildred Gentry',
#    'Melisa Gerke',
#    'Alex Gilles',
#    'Evelyn Girifalco',
#    'Shenice Gold',
#    'Roxana Goyal',
#    'Paula Gross',
#    'Joanne Handschiegl',
#    'Ludwick Harrell',
#    'Christie Harrington',
#    'Kara Harrison',
#    'Rose Ivey',
#    'Maryellen Jackson',
#    'Hannah Jacobi',
#    'Sneha Jhaveri',
#    'Judy Jung',
#    'Kathleen Kinsella',
#    'Alexandra Kirill',
#    'Bradley Knapp',
#    'John Kretschmer',
#    'Enrico Langton',
#    'Dallas Leach',
#    'Marilyn Linares',
#    'Allison Lydon',
#    'Lindsay Lynch',
#    'Samuel MacLennan',
#    'Lauren Mahoney',
#    'Debbie Mangal',
#    'Shana Maurice',
#    'Sandy Mckenna',
#    'Elizabeth Meads',
#    'Dawn Motlagh',
#    'Colombui Ndzi',
#    'Richard Newman',
#    'Shari Ngodup',
#    'Lei-Ming Nguyen',
#    "Lynn O'hare",
#    'Adeel Osturnka',
#    'Clinton Owad',
#    'Nina Panjwani',
#    'Emil Pelech',
#    'Shakira Perry',
#    'Hong Pham',
#    'Brad Pitt',
#    'Morissa Power',
#    'Louis Punjabhi',
#    'Janine Purinton',
#    'Quinn Rarrick',
#    'Haley Rivera',
#    'Alain Robinson',
#    'Ashley Rose',
#    'Bruno Rossetti',
#    'Melinda Saar-Beckles',
#    'Nore Sadki',
#    'Kamrin Sander',
#    'Nori Sewkumar',
#    'Seffi Shields',
#    'Taylor Sparks',
#    'Kristen Squatrito',
#    'Desiree Tavares',
#    'Sophia Theamstern',
#    'Theresa Tinto',
#    'Jeanette Tippett',
#    'Mei Trang',
#    'Abdellah Veera',
#    'Colleen Volk',
#    'Anna Von Massenbach',
#    'Scott Whittier',
#    'Barry Wilber',
#    'Jacquelyn Williams',
#    'Catherine Ybarra',
#    'Kimberly Beak',
#    'Dianna Blount',
#    'Betsy Bondwell',
#    'Joseph Buccheri',
#    'Joelle Burke',
#    'Benjamin Burkett',
#    'Phil Close',
#    'Daniel Davis',
#    'Carla Demita',
#    'Angela Erilus',
#    'Megan Faller',
#    'Nicole Fancett',
#    'Phylicia Gosciminski',
#    'Earnest Hankard',
#    'Adrienne Homberger',
#    'Julissa Hunts',
#    'Rosalie Hutter',
#    'Ming Huynh',
#    'Tayana Jeannite',
#    'Yen Johnston',
#    'Lindsey Langford',
#    'Mohammed Latif',
#    'Mathew Linden',
#    'Robyn Manchester',
#    'Karen Mancuso',
#    'Brigit McCarthy',
#    'Erasumus Monkfish',
#    'Luisa Monterro',
#    'Patrick Moran',
#    'Maliki Moumanil',
#    'Kristie Nowlan',
#    'Brooke Oliver',
#    'Ermine Pelletier',
#    'May Roberson',
#    'Adil Sahoo',
#    'Constance Sloan',
#    'Lenora Tejeda',
#    'Kenneth Thibaud',
#    'Cybil Trzeciak',
#    'Roger Walker',
#    'Jordan Winthrop',
#    'Hang Wolk',
#    'Edward Buck',
#    'Jessica Bunbury',
#    'Michelle Carter',
#    'Latia Costa',
#    'Jenna Dietrich',
#    'Alfred Digitale',
#    'Maruk Fraval',
#    'Gerry Friedman',
#    'Whitney Gill',
#    'Myriam Givens',
#    'Mike Guilianno',
#    'Jeremy Prater',
#    'Bartholemew Khemmich',
#    'Giovanni Leruth',
#    'Jac McKinzie',
#    'Howard Mullaney',
#    'Jasmine Onque',
#    'Travis Ozark',
#    'Xana Potts',
#    'Caitrin Strong',
#    'Sharlene Terry',
#    'Jackie Valentin',
#    'Noah Villanueva',
#    'Debra Houlihan',
#    'Donysha Kampew',
#    'Colby Andreola',
#    'Judith Carabbio',
#    'Keyla Del Bosque',
#    'Sandra Martin',
#    'Luke Patronick',
#    'Adell Saada',
#    'Andrew Szabo',
#    'Mia Brown',
#    'Ivan Rogers',
#    'Julia Soto',
#    'Nan Singh'],
#   [nan],
#   []],
#  'state': [array(['MA', 'TX', 'CT', 'VA', 'VT', 'CA', 'WA', 'NH', 'NY', 'OH', 'IN',
#          'ID', 'TN', 'NV', 'CO', 'UT', 'AL', 'GA', 'FL', 'NC', 'KY', 'ND',
#          'MT', 'OR', 'AZ', 'ME', 'RI', 'PA'], dtype=object),
#   [['Massachussets'],
#    ['Texas'],
#    ['Connecticut'],
#    ['Virginia'],
#    ['Vermony'],
#    ['California'],
#    ['Washington'],
#    ['New Hampshire'],
#    ['New York'],
#    ['Ohio'],
#    ['Indiana'],
#    ['Idaho'],
#    ['Tennessee'],
#    ['Nevada'],
#    ['Colarado'],
#    ['Utah'],
#    ['Alabama'],
#    ['Georgia'],
#    ['Florida'],
#    ['North Carolina'],
#    ['Kentucky'],
#    ['North Dakota'],
#    ['Montana'],
#    ['Oregon'],
#    ['Arizona'],
#    ['Maine'],
#    ['Rhode Island'],
#    ['Pennsylvania']],
#   ['state',
#    'state of birth',
#    'state of residence',
#    'office location',
#    'location']],
#  'age': [['32',
#    '33',
#    '31',
#    '29',
#    '30',
#    '38',
#    '63',
#    '46',
#    '36',
#    '47',
#    '37',
#    '44',
#    '54',
#    '49',
#    '28',
#    '48',
#    '42',
#    '53',
#    '66',
#    '34',
#    '52',
#    '39',
#    '45',
#    '41',
#    '40',
#    '62',
#    '43',
#    '59',
#    '27',
#    '67',
#    '50',
#    '35',
#    '26',
#    '25',
#    '65',
#    '51',
#    '58',
#    '56',
#    '64'],
#   [['old', 'years old', 'age of', 'ages of']],
#   []],
#  'sex': [['male', 'female'],
#   [['men', 'males', 'guys', 'dudes', 'gents', 'gentlemen', 'boys'],
#    ['women', 'females', 'ladies', 'lady', 'ladys', 'girls', 'gals', 'woman']],
#   ['sex', 'gender', 'masculine', 'feminine', 'male person']],
#  'maritaldesc': [['married', 'divorced', 'single', 'separated', 'widowed'],
#   [['wed',
#     'legally married',
#     'espoused',
#     'joined in holy matrimony',
#     'hitched'],
#    nan,
#    ['unmarried', 'bachelor', 'bachelorette'],
#    nan,
#    nan],
#   ['husbandless',
#    'without a partner',
#    'unwedded',
#    'wifeless',
#    'no longer married',
#    'without a husband',
#    'without a wife',
#    'maritaldesc',
#    'marital status',
#    'spouse',
#    'husband',
#    'wife']],
#  'citizendesc': [['us citizen', 'eligible noncitizen', 'non-citizen'],
#   [nan, nan, nan],
#   ['immigrant',
#    'illegal immigrant',
#    'h1 visa',
#    'foreigner',
#    'foreign',
#    'imported',
#    'out of country',
#    'from abroad',
#    'citizenship status',
#    'citizenship']],
#  'racedesc': [['black or african american',
#    'asian',
#    'two or more races',
#    'white',
#    'hispanic',
#    'american indian or alaska native'],
#   [['black', 'african american', 'african-american'],
#    ['from asia'],
#    ['multiracial',
#     'multi-racial',
#     'mixed',
#     'mixed race',
#     'biracial',
#     'interracial'],
#    ['caucasian'],
#    ['latino'],
#    ['native',
#     'natives',
#     'indians',
#     'indian',
#     'american indian',
#     'alaska native']],
#   ['ethnicity',
#    'race',
#    'racial background',
#    'ethnic group',
#    'ethnic type',
#    'racial indentity',
#    'community']],
#  'reason_for_termination': [['return to school',
#    'another position',
#    'unhappy',
#    'military',
#    'gross misconduct',
#    'hours',
#    'medical issues',
#    'relocation out of area',
#    'more money',
#    'career change',
#    'n/a - has not started yet',
#    'retiring',
#    'n/a - still employed',
#    'attendance',
#    'no-call no-show',
#    'maternity leave - did not return',
#    'performance'],
#   [['went back to school',
#     'had to go to school again',
#     'needed to go back to school',
#     'went back to college'],
#    ['took on another job',
#     'landed a new position',
#     'changed positions',
#     'got a new position',
#     'found a new position'],
#    ["wasn't happy",
#     "didn't like his job",
#     "didn't like her job",
#     'hated the job',
#     'disliked the job',
#     "didn't enjoy the job",
#     "didn't like his work",
#     "didn't like her work"],
#    ['joined the military',
#     'went to the military',
#     'left for the military',
#     'enlisted in the military',
#     'was drafted into the military'],
#    nan,
#    nan,
#    ['got sick', 'fell sick', 'medical problems', 'sick'],
#    ['was relocated',
#     'had to relocated',
#     'was assigned to a new location',
#     'was assigned to a different location'],
#    nan,
#    ['changed careers'],
#    nan,
#    ['retired', 'went into retirement'],
#    nan,
#    ['poor attendance', 'bad attendance'],
#    nan,
#    ['did not come back from maternity leave', 'had a kid and dissapeared'],
#    ['poor performance', 'performed below expectations']],
#   []],
#  'employment_status': [['terminated for cause',
#    'leave of absence',
#    'active',
#    'voluntarily terminated',
#    'future start'],
#   [['fired', 'let go', 'evicted', 'kicked out', 'removed', 'dismissed'],
#    ['on absence leave'],
#    ['currently employed', 'currently working', 'currently works'],
#    ['quit', 'quitted', 'resigned', 'sent in a resignation'],
#    ['will start at a future time',
#     'will start later',
#     'will start some time in the future']],
#   ['renounce', 'employment status', 'current job status']],
#  'department': [['executive office',
#    'admin offices',
#    'production',
#    'it/is',
#    'software engineering',
#    'sales'],
#   [nan, nan, nan, nan, ['programming', 'coding', 'software development'], nan],
#   ['department', 'team', 'group', 'section', 'division', 'sector']],
#  'position': [['it manager - infra',
#    'cio',
#    'sales manager',
#    'president & ceo',
#    'administrative assistant',
#    'database administrator',
#    'area sales manager',
#    'it director',
#    'sr. accountant',
#    'it manager - support',
#    'production technician ii',
#    'network engineer',
#    'sr. network engineer',
#    'shared services manager',
#    'accountant i',
#    'it support',
#    'software engineering manager',
#    'production technician i',
#    'director of operations',
#    'director of sales',
#    'sr. dba',
#    'it manager - db',
#    'software engineer',
#    'production manager'],
#   [nan,
#    ['chief information officer'],
#    nan,
#    ['chief executive officer'],
#    nan,
#    ['db admin', 'db administrator', 'database admin'],
#    nan,
#    ['director of it'],
#    ['senior accountant'],
#    nan,
#    ['production technician 2', 'production technician two'],
#    nan,
#    ['senior network engineer'],
#    nan,
#    ['accountant 1', 'accountant one'],
#    ['tech support'],
#    nan,
#    ['production technician 1', 'production technician one'],
#    ['operations director'],
#    ['sales director'],
#    ['senior database administrator',
#     'senior db admin',
#     'senior db administrator'],
#    nan,
#    ['software developer', 'programmer'],
#    nan],
#   ['title', 'job title', 'role']],
#  'manager': [['brandon leblanc',
#    'janet king',
#    'board directors',
#    'simon roup',
#    'jennifer zamora',
#    'eric dougall',
#    'peter monroe',
#    'michael albert',
#    'elijiah gray',
#    'webster butler',
#    'amy dunn',
#    'ketsia liebig',
#    'brannon miller',
#    'david stanley',
#    'kissy sullivan',
#    'kelley spirea',
#    'lynn daneault',
#    'john smith',
#    'debra houlihan',
#    'alex sweetwater'],
#   [['manager name',
#     'manager',
#     'incharge',
#     'supervisor',
#     'mentor',
#     'leadership',
#     'boss',
#     'management',
#     'head',
#     'lead',
#     'chairman',
#     'working for',
#     'works for',
#     'work for',
#     'manage',
#     'managed by',
#     'managing',
#     'manages',
#     'reports to',
#     'report to',
#     'reporting to',
#     'reporting',
#     'working under',
#     'is under',
#     'leads']],
#   []],
#  'employee_source': [['information session',
#    'company intranet - partner',
#    'social networks - facebook twitter etc',
#    'newspager/magazine',
#    'internet search',
#    'billboard',
#    'pay per click',
#    'on-line web application',
#    'glassdoor',
#    'professional society',
#    'monster.com',
#    'diversity job fair',
#    'careerbuilder',
#    'mbta ads',
#    'word of mouth',
#    'other',
#    'vendor referral',
#    'on-campus recruiting',
#    'website banner ads',
#    'employee referral'],
#   [['info session'],
#    nan,
#    ['social media',
#     'social media apps',
#     'facebook',
#     'instagram',
#     'twitter',
#     'snapchat',
#     'social network'],
#    ['newspaper', 'magazine'],
#    ['google',
#     'bing',
#     'yahoo',
#     "search engine - google bing yahoo'",
#     'search engine'],
#    ['poster'],
#    ['ppc', 'google ads', 'google ppc', 'ppc google'],
#    ['application potal', 'job portal'],
#    ['glass door'],
#    ['professional group'],
#    ['monster'],
#    nan,
#    nan,
#    ['advertisement', 'ads'],
#    ['verbal mention'],
#    nan,
#    ['referred by vendor', 'vendor referred'],
#    ['on-campus job fair', 'career fair'],
#    nan,
#    ['referred by employee']],
#   ['how did you learn about this position',
#    'how did you find out about this job',
#    'how did you find out about this position',
#    'how did you learn about this job']],
#  'performance_score': [['exceptional',
#    'fully meets',
#    'n/a- too early to review',
#    'pip',
#    'needs improvement',
#    'exceeds',
#    '90-day meets'],
#   [['extraordinary'],
#    ['up to the mark', 'meet expectations'],
#    nan,
#    nan,
#    nan,
#    ['beyond expectations',
#     'more than expected',
#     'better than expected',
#     'higher than excpected'],
#    nan],
#   ['performance rating', 'performance score']],
#  'money': [['pay rate'],
#   [['salary',
#     'income',
#     'pay',
#     'earn',
#     'earnings',
#     'make',
#     'dollars',
#     '$',
#     'paycheck',
#     'earns',
#     'earning',
#     'earners',
#     'earner']],
#   ['earns', 'makes', 'amount']],
#  'comparator': [['more than', 'equals to', 'less than'],
#   [['greater than', 'higher than', 'longer', 'over', 'older than'],
#    ['is exactly', 'is equal to', 'equates to'],
#    ['lower than', 'below', 'under', 'fewer than']],
#   []],
#  'date_time': [['date of hire', 'date of termination', 'dob'],
#   [['start date', 'date of starting employment', 'hiring date'],
#    ['end date', 'date of leaving job', 'date of ending employment'],
#    ['birthday',
#     'birthdate',
#     'birth date',
#     'date of birth',
#     'day of birth',
#     'born on',
#     'born on the',
#     'born in',
#     'born after',
#     'born before']],
#   ['year']],
#  'time_interval': [['time_interval'],
#   [['yearly',
#     'monthly',
#     'annually',
#     'bi-weekly',
#     'hourly',
#     'month to month',
#     'month-to-month']],
#   ["00's",
#    "10's",
#    "20's",
#    "30's",
#    "40's",
#    "50's",
#    "60's",
#    "70's",
#    "80's",
#    "90's",
#    '00s',
#    '10s',
#    '20s',
#    '30s',
#    '40s',
#    '50s',
#    '60s',
#    '70s',
#    '80s',
#    '90s',
#    'tens',
#    'twenties',
#    'thirties',
#    'forties',
#    'fifties',
#    'sixties',
#    'seventies',
#    'eighties',
#    'nineties',
#    '1900s',
#    '1910s',
#    '1920s',
#    '1930s',
#    '1940s',
#    '1950s',
#    '1960s',
#    '1970s',
#    '1980s',
#    '1990s',
#    '2000s',
#    '2010s',
#    "1900's",
#    "1910's",
#    "1920's",
#    "1930's",
#    "1940's",
#    "1950's",
#    "1960's",
#    "1970's",
#    "1980's",
#    "1990's",
#    "2000's",
#    "2010's",
#    'by the month']],
#  'function': [['percent', 'sum', 'average'],
#   [['fraction', 'portion', 'proportion', 'percentage', '%'],
#    ['total', 'cumulative', 'added up', 'summed up. totalled', 'summed'],
#    ['mean', 'typical', 'typically']],
#   ['distribution', 'turn over rate', 'pct']],
#  'extreme': [['highest', 'lowest'],
#   [['top', 'maximum', 'most', 'greatest', 'max'],
#    ['least', 'minimum', 'bottom', 'lowest', 'min']],
#   []],
#  'employment_action': [['hired', 'terminated'],
#   [['employed', 'recruited'], ['fired', 'let go']],
#   ['joined']]}

# %%
for ent in ent_dict:
    print(ent_dict[ent][1])
# Out:
# [nan]
# [['Massachussets'], ['Texas'], ['Connecticut'], ['Virginia'], ['Vermony'], ['California'], ['Washington'], ['New Hampshire'], ['New York'], ['Ohio'], ['Indiana'], ['Idaho'], ['Tennessee'], ['Nevada'], ['Colarado'], ['Utah'], ['Alabama'], ['Georgia'], ['Florida'], ['North Carolina'], ['Kentucky'], ['North Dakota'], ['Montana'], ['Oregon'], ['Arizona'], ['Maine'], ['Rhode Island'], ['Pennsylvania']]
# [['old', 'years old', 'age of', 'ages of']]
# [['men', 'males', 'guys', 'dudes', 'gents', 'gentlemen', 'boys'], ['women', 'females', 'ladies', 'lady', 'ladys', 'girls', 'gals', 'woman']]
# [['wed', 'legally married', 'espoused', 'joined in holy matrimony', 'hitched'], nan, ['unmarried', 'bachelor', 'bachelorette'], nan, nan]
# [nan, nan, nan]
# [['black', 'african american', 'african-american'], ['from asia'], ['multiracial', 'multi-racial', 'mixed', 'mixed race', 'biracial', 'interracial'], ['caucasian'], ['latino'], ['native', 'natives', 'indians', 'indian', 'american indian', 'alaska native']]
# [['went back to school', 'had to go to school again', 'needed to go back to school', 'went back to college'], ['took on another job', 'landed a new position', 'changed positions', 'got a new position', 'found a new position'], ["wasn't happy", "didn't like his job", "didn't like her job", 'hated the job', 'disliked the job', "didn't enjoy the job", "didn't like his work", "didn't like her work"], ['joined the military', 'went to the military', 'left for the military', 'enlisted in the military', 'was drafted into the military'], nan, nan, ['got sick', 'fell sick', 'medical problems', 'sick'], ['was relocated', 'had to relocated', 'was assigned to a new location', 'was assigned to a different location'], nan, ['changed careers'], nan, ['retired', 'went into retirement'], nan, ['poor attendance', 'bad attendance'], nan, ['did not come back from maternity leave', 'had a kid and dissapeared'], ['poor performance', 'performed below expectations']]
# [['fired', 'let go', 'evicted', 'kicked out', 'removed', 'dismissed'], ['on absence leave'], ['currently employed', 'currently working', 'currently works'], ['quit', 'quitted', 'resigned', 'sent in a resignation'], ['will start at a future time', 'will start later', 'will start some time in the future']]
# [nan, nan, nan, nan, ['programming', 'coding', 'software development'], nan]
# [nan, ['chief information officer'], nan, ['chief executive officer'], nan, ['db admin', 'db administrator', 'database admin'], nan, ['director of it'], ['senior accountant'], nan, ['production technician 2', 'production technician two'], nan, ['senior network engineer'], nan, ['accountant 1', 'accountant one'], ['tech support'], nan, ['production technician 1', 'production technician one'], ['operations director'], ['sales director'], ['senior database administrator', 'senior db admin', 'senior db administrator'], nan, ['software developer', 'programmer'], nan]
# [['manager name', 'manager', 'incharge', 'supervisor', 'mentor', 'leadership', 'boss', 'management', 'head', 'lead', 'chairman', 'working for', 'works for', 'work for', 'manage', 'managed by', 'managing', 'manages', 'reports to', 'report to', 'reporting to', 'reporting', 'working under', 'is under', 'leads']]
# [['info session'], nan, ['social media', 'social media apps', 'facebook', 'instagram', 'twitter', 'snapchat', 'social network'], ['newspaper', 'magazine'], ['google', 'bing', 'yahoo', "search engine - google bing yahoo'", 'search engine'], ['poster'], ['ppc', 'google ads', 'google ppc', 'ppc google'], ['application potal', 'job portal'], ['glass door'], ['professional group'], ['monster'], nan, nan, ['advertisement', 'ads'], ['verbal mention'], nan, ['referred by vendor', 'vendor referred'], ['on-campus job fair', 'career fair'], nan, ['referred by employee']]
# [['extraordinary'], ['up to the mark', 'meet expectations'], nan, nan, nan, ['beyond expectations', 'more than expected', 'better than expected', 'higher than excpected'], nan]
# [['salary', 'income', 'pay', 'earn', 'earnings', 'make', 'dollars', '$', 'paycheck', 'earns', 'earning', 'earners', 'earner']]
# [['greater than', 'higher than', 'longer', 'over', 'older than'], ['is exactly', 'is equal to', 'equates to'], ['lower than', 'below', 'under', 'fewer than']]
# [['start date', 'date of starting employment', 'hiring date'], ['end date', 'date of leaving job', 'date of ending employment'], ['birthday', 'birthdate', 'birth date', 'date of birth', 'day of birth', 'born on', 'born on the', 'born in', 'born after', 'born before']]
# [['yearly', 'monthly', 'annually', 'bi-weekly', 'hourly', 'month to month', 'month-to-month']]
# [['fraction', 'portion', 'proportion', 'percentage', '%'], ['total', 'cumulative', 'added up', 'summed up. totalled', 'summed'], ['mean', 'typical', 'typically']]
# [['top', 'maximum', 'most', 'greatest', 'max'], ['least', 'minimum', 'bottom', 'lowest', 'min']]
# [['employed', 'recruited'], ['fired', 'let go']]

# %% [markdown]
# <h4>Labelling Check</h4>

# %%
intent_txt = pd.read_csv('HR Manager Schema - intent_master.csv')
intent_txt
# Out:
#                                              get_info  \
# 0                                        Returns Data
# 1   Returns a column information about a specific ...
# 2                          What is {nan|name}'s race?
# 3            Is {Michael|name} {married|maritaldesc}?
# 4             What is {Nan|name}'s official position?
# 5          How much does {Mia|name} get {paid|money}?
# 6   How {old|age} is the manager for the engineeri...
# 7             What is {Mia|name}'s employment status?
# 8                   Is {Ivan|name} from out of state?
# 9           Does {Michael|name} still work at Cisco?
# 10            What is {Mia|name}'s performance score?
# 11                  What position is {Julia|name} in?
# 12             Which department is {Michael|name} in?
# 13         How did {Mia|name} hear about our company?
# 14               Is {Nan|name} {married|maritaldesc}?
# 15                      Why did {Mia|name} get fired?
# 16         Which department does {Mia|name} work for?
# 17  Does {Julia|name}'s {manger|manager} provide h...
# 18                        How old is the {Ivan|name}?
# 19  Is {Nan|name} {actively employed|employment_st...
# 20                    What is {Mia|name}'s position?
# 21  What was the reason for {Mia|name}'s termination?
# 22                        Where does {Mia|name} live?
# 23                          Where is {Mia|name} from?
# 24  What is {Hakim|name}'s level in the organization?
# 25  What is {Nan Singh|name}'s performance evaluat...
# 26                    What is {Nan|name}'s last name?
# 27      Does {Mia|name}'s race affect her indulgence?
# 28                    How well is the employee doing?
# 29                What does {Michael|name} look like?
# ..                                                ...
# 62    tell me what is {Mia|name}'s citizenship status
# 63              is {Mia|name} a {citizen|citizendesc}
# 64              which branch is {Nan|name} working in
# 65  why did we {let go|employment_action} of {Nan|...
# 66  did we {fire|employment_action} Mr. {Nan|name}...
# 67       can you desribe the race of {Nan|name} Singh
# 68                   give me {Nan|name}'s race please
# 69                   how did {Nan|name} hear about us
# 70  did {Nan|name} hear about us through {Glassdoo...
# 71                                                NaN
# 72                                                NaN
# 73                                                NaN
# 74                                                NaN
# 75                                                NaN
# 76                                                NaN
# 77                                                NaN
# 78                                                NaN
# 79                                                NaN
# 80                                                NaN
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
# 84                                                NaN
# 85                                                NaN
# 86                                                NaN
# 87                                                NaN
# 88                                                NaN
# 89                                                NaN
# 90                                                NaN
# 91                                                NaN
#
#                                         get_aggregate  \
# 0                                      Returns Number
# 1              Average, total, percentage of a column
# 2   What is the {total|function} number of {us cit...
# 3   What {percent|function} of employees {exceeded...
# 4   What is the {percentage|function} of new grads...
# 5           What is the {average|function} {age|age}?
# 6             What percent of employees are managers?
# 7   What's the {average|function} {age of|age} emp...
# 8   What {percentage|function} of the employees ar...
# 9   What {percentage|function} of employees are {e...
# 10  What {percentage|function} of employees are {f...
# 11  {Percentage|function} of Employees in departme...
# 12  What {percentage|function} of employees {meet ...
# 13  What {percentage|function} of employees are pa...
# 14  Give an estimate {total|function} of the {fema...
# 15  What {percent|function} of people working here...
# 16  What is the {percentage|function} of employees...
# 17  Tell me the {percent|function} of employees ar...
# 18  What {fraction|function} of our employees are ...
# 19  What is the {percentage|function} of {senior e...
# 20  What {percentage|function} of workers are {old...
# 21  What is the {median|function} {age of|age} emp...
# 22  What is the {voluntary attrition rate|function...
# 23  What {fraction|function} of {terminations|empl...
# 24  What {percentage|function} of employees are {m...
# 25  What is the {percentage|function} of {engineer...
# 26  what {proportion|function} of employees were {...
# 27  What is the {percentage|function} breakdown of...
# 28  What is the {average|function} tenure of emplo...
# 29  What {percent|function} of employees are {fema...
# ..                                                ...
# 62  How many people have worked here since {2015|s...
# 63        How many employees are {C-levels|position}?
# 64  What is the total number of {Black or African ...
# 65  How many of {Mia Brown|name}'s reports left th...
# 66   How many people are there under {30|sys_number}?
# 67  how many employees work for the {collab depart...
# 68                       How many managers are there?
# 69  What are the {M/F|sex} ratios in different dep...
# 70  How many employees {meet|performance_score} th...
# 71  Employees with more than {5 yrs|sys_duration} ...
# 72  How many employees fall {below expectations|pe...
# 73               How many employees are out of state?
# 74  How many employees are between {20|sys_number}...
# 75  How many employees are {older than|comparator}...
# 76                       What is the employee's race?
# 77     How many employees live in {California|state}?
# 78                   How many employees are above 35?
# 79      How many employees are from {New York|state}?
# 80  How many employees were {born in January|date_...
# 81  How many {software engineers|position} do we h...
# 82  How many workers performed {below expectations...
# 83  How many {software engineers|position} work fo...
# 84          How many employees are named {Ivan|name}?
# 85  When do we most often {hire/fire|employment_st...
# 86  How many employees are {over|comparator} the {...
# 87          Number of {Married|maritaldesc} employees
# 88         Hiow many employees are in our department?
# 89  How many {business analysts|position} are empl...
# 90  How many people are {over|comparator} {21|sys_...
# 91  How many employees work for {Michael Albert|ma...
#
#                                         get_employees  \
# 0                                   Returns Employees
# 1   Returns a list of employees that meets a colum...
# 2      Give me employees who are {single|maritaldesc}
# 3                       All employees from {MA|state}
# 4   Which employees have been recently {terminated...
# 5   Which employees are not {US citizens|citizende...
# 6   Which employees were {let go|employment_action...
# 7     how many employees work from {California|state}
# 8   Which employees have been {terminated|employme...
# 9   Which employees have been with the company lon...
# 10  Which employees have gotten only {positive fee...
# 11       Which employees have a {spouse|maritaldesc}?
# 12  Which employees {quit working|employment_statu...
# 13  Which employees are {activley employed|employm...
# 14  Which employees have the {highest|comparator} ...
# 15  Who was {hired|employment_action} based on a {...
# 16  Which employees are in the {engineering depart...
# 17  Which employees have the {lowest|comparator} p...
# 18              Which employees are {asian|racedesc}?
# 19     Which employees are {US citizens|citizendesc}?
# 20               Show {married|maritaldesc} employees
# 21  Who is married in {Collaboration Department|de...
# 22  Which employees are {over|comparator} {30|sys_...
# 23  Which employee(s) {do not meet|performance_sco...
# 24  Which employees were {recruited|employment_act...
# 25        Which employees are {citizens|citizendesc}?
# 26                   Which employees have a position?
# 27         Which employees are {married|maritaldesc}?
# 28                  Which employees are {female|sex}?
# 29                  Who is our {oldest|age} employee?
# ..                                                ...
# 62                   {divorced|maritaldesc} employees
# 63  give me a list of {separated employees|marital...
# 64         employees that are {separated|maritaldesc}
# 65      workers that have been {divorced|maritaldesc}
# 66  employees between the {age of|age} {20|sys_num...
# 67               employees in their {20|sys_number}'s
# 68             {20|sys_number} {yr old|age} employees
# 69           {34|sys_number} {year old|age} employees
# 70  employees {older than|age} {30 years|sys_durat...
# 71          employees that live in {california|state}
# 72                          employees from {MA|state}
# 73                               {MA|state} employees
# 74                          {MA|state} employees list
# 75  give me a list of employes that are based in {...
# 76                         {MA|state} based employees
# 77                      employees based in {MA|state}
# 78           Which employees are {managers|position}?
# 79             employees that are {managers|position}
# 80                        list of {managers|position}
# 81                           {managers|position} list
# 82                       {manager|position} employees
# 83                       employee {managers|position}
# 84                                {managers|position}
# 85                                                NaN
# 86                                                NaN
# 87                                                NaN
# 88                                                NaN
# 89                                                NaN
# 90                                                NaN
# 91                                                NaN
#
#                                            get_salary  \
# 0                                      Returns Salary
# 1          Returns the salary of a specific employee.
# 2                           What is {Mia|name}'s pay?
# 3                      What is {Mia|name}'s pay rate?
# 4               What is the pay rate of {Julia|name}?
# 5                      What is {Nan|name}'s pay rate?
# 6                  How much does {Michael|name} make?
# 7   Is {Mia|name} being {paid|money} {$|money}{40k...
# 8   Does {Mia|name} get {$|money}{70k|sys_number} ...
# 9   When we let {Nan|name} go {fired|employment_ac...
# 10                    {pay rate|money} of  {Mia|name}
# 11               how much money does {Mia|name} make?
# 12                 What does {Mia|name} {make|money}?
# 13  How much {money|money} does {Mia|name} bring i...
# 14  {Each year|time_interval}, how much does {Mia|...
# 15  What are {Mia|name}'s {earnings|money} {year t...
# 16  What is {Mia|name}'s {annual|time_interval} {s...
# 17  What does {Mia|name} {make|money} {monthly|tim...
# 18  How much does {Mia|name} {make|money} {every m...
# 19  How much does Cisco {pay|money} {Mia|name} {ea...
# 20  How much {salary|money} does {Mia|name} {earn|...
# 21  Does {Mia|name} {make|money} {more than|compar...
# 22  Does {Mia|name} {earn|money} more money than s...
# 23  What is {Mia|name}'s exact {salary|money} in {...
# 24  Tell me about {Mia|name}'s {month to month|tim...
# 25  Is {50k|sys_number} {more than|comparator} wha...
# 26  Does {60,000|sys_number} exceed what {Mia|name...
# 27   {Mia|name} {Salary|money} {Yearly|time_interval}
# 28  {Mia|name} {Salary|money} {Monthly|time_interval}
# 29    {Mia|name} {Salary|money} {Daily|time_interval}
# ..                                                ...
# 62                        {Mia|name} {pay|money} info
# 63              {Mia|name} {salary|money} amount info
# 64         Tell me how much {Mia|name} {making|money}
# 65                  What is {Mia|name} {making|money}
# 66  What does {Mia|name} {make|money} on the {Payr...
# 67  What is cisco giving {Mia|name} to {pay|money}...
# 68  What is {Mia|name}'s {hourly|time_interval} {s...
# 69  What does {Mia|name} {make|money} {on the hour...
# 70      {Hourly|time_interval} {pay|money} {Mia|name}
# 71      {Mia|name} {hourly|time_interval} {pay|money}
# 72  {Mia|name} {hourly|time_interval} {compensatio...
# 73                                                NaN
# 74                                                NaN
# 75                                                NaN
# 76                                                NaN
# 77                                                NaN
# 78                                                NaN
# 79                                                NaN
# 80                                                NaN
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
# 84                                                NaN
# 85                                                NaN
# 86                                                NaN
# 87                                                NaN
# 88                                                NaN
# 89                                                NaN
# 90                                                NaN
# 91                                                NaN
#
#                                  get_salary_aggregate  \
# 0                                      Returns Number
# 1   Average, total, percentage specifically relate...
# 2   What is the {median|function} {pay|money} of {...
# 3   what {percentage|function} of employees make {...
# 4    What is the {average|function} {pay rate|money}?
# 5   What is the {average|function} {pay|money} of ...
# 6   Calculate the {average|function} {pay rate|mon...
# 7   {average|function} {pay rate|money} for {women...
# 8     What's the {average|function} {pay rate|money}?
# 9   What is the {average|function} {pay rate|money...
# 10  How many employees are paid above {$|money}{20...
# 11  what number of people {earn|money} {fewer than...
# 12  what number of people {earn|money} {fewer than...
# 13  how many people are {paid|money} {less than|co...
# 14  How many employees make {6 figure|sys_number} ...
# 15  What is the {total|function} {earnings|money} ...
# 16  How much does the {average|function} employee ...
# 17  What is the {average|function} {amount of mone...
# 18  What is the {total|function} {earnings|money} ...
# 19  How much {money|money} did all the employees {...
# 20  Get me the combined {total|function} incomes f...
# 21  Tell me about the {range|function} of {salarie...
# 22  Describe the {salary|money} {range|function} f...
# 23  What percent of workers {made|money} below {70...
# 24  Of all the workers that {started at the compan...
# 25  Employees {hired between 2013 and 2014|date_ti...
# 26  {Mean|function} {pay|money} of workers {hired ...
# 27  Of the employees {born before 1990|date_time},...
# 28  What are workers {born before 1985|date_time} ...
# 29  What is the {typical|function} {compensation|m...
# ..                                                ...
# 62  amount of {money|money} {earned|money} by {fem...
# 63  what is the {fraction|function} of {female|sex...
# 64  i want the {fraction|function} of employees in...
# 65  what is the {porportion|function} of workers {...
# 66  what is the {lowest|extreme} {pay|money} in th...
# 67  what is the {total|function} {pay|money} in th...
# 68  how much are all the employees in the {sales d...
# 69  how much is the {sales department|department} ...
# 70  get me the {total|function} amount that the {s...
# 71                                                NaN
# 72                                                NaN
# 73                                                NaN
# 74                                                NaN
# 75                                                NaN
# 76                                                NaN
# 77                                                NaN
# 78                                                NaN
# 79                                                NaN
# 80                                                NaN
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
# 84                                                NaN
# 85                                                NaN
# 86                                                NaN
# 87                                                NaN
# 88                                                NaN
# 89                                                NaN
# 90                                                NaN
# 91                                                NaN
#
#                                  get_salary_employees  \
# 0                                    Return Employees
# 1   (Returns Employee Name and Salary, Like Get_Em...
# 2                           Who makes the most money?
# 3   Which employees make more than {$|money}{10|sy...
# 4   Which employee(s) have {lowest|comparator} {in...
# 5   Tell me who all are {making|money} {more than|...
# 6   Which {software engineers|position} are {paid|...
# 7   who make a {salary|money} {more than|comparato...
# 8   For employees {hired|employment_action} {betwe...
# 9   For employees {hired|employment_action} {betwe...
# 10  Of all employees that {started at the company|...
# 11  Tell me who earned the {least|extreme} that wa...
# 12  Of the employees {hired after 2014|date_time} ...
# 13  Which workers are {compensated|money} {more th...
# 14  Which employee that {works under|manager} {Sim...
# 15  Tell me the employee that {works for|manager} ...
# 16  What are the {yearly|time_interval} {salaries|...
# 17  Which {Sr. DBA|position} {earns|money} the {mo...
# 18  Of all the {Production Managers|position}, whi...
# 19  Get me the {top|extreme} {ten|sys_number} {ear...
# 20  I want the {5|sys_number}{%|function} {bottom|...
# 21  Admin Offices {bottom|extreme} {16|sys_number}...
# 22  list of {top|extreme} twenty {earners|money} i...
# 23  Who {earns|money} the {most|extreme} in the {p...
# 24  who {makes|money} the {least|extreme} {amount ...
# 25  Which White employee {earns|money} the {most|e...
# 26  who are the company's {top|extreme} {20|sys_nu...
# 27  give me the {salaries|money} of {interracial|r...
# 28  give me the {salaries|money} for all of the em...
# 29  I want a list with {salaries|money} of employe...
# ..                                                ...
# 62     {sales department|department} {salaries|money}
# 63  show me the employee {salaries|money} for {fem...
# 64  what are the {salaries|money} for {active|empl...
# 65  what are the {salaries|money} for employees th...
# 66  show me the {highest|extreme} {earning|money} ...
# 67  who is the {highest|extreme} {earning|money} {...
# 68  {IT support|position} {top|extreme} {earner|mo...
# 69  {IT support|position} {lowest|extreme} {earner...
# 70  the {lowest|extreme} 10 {earners|money} in {Sa...
# 71                                                NaN
# 72                                                NaN
# 73                                                NaN
# 74                                                NaN
# 75                                                NaN
# 76                                                NaN
# 77                                                NaN
# 78                                                NaN
# 79                                                NaN
# 80                                                NaN
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
# 84                                                NaN
# 85                                                NaN
# 86                                                NaN
# 87                                                NaN
# 88                                                NaN
# 89                                                NaN
# 90                                                NaN
# 91                                                NaN
#
#                                              get_date  \
# 0                                        Returns Date
# 1   Like Get_Info but only for born, hired, fired ...
# 2   What is the {date of hiring|date_time} for {Mi...
# 3               When did {Amy|name} join the company?
# 4     How long has {Ivan|name} been with the company?
# 5      When was {Nan|name} {fired|employment_action}?
# 6                How long was {Mia|name} working for?
# 7             When was {Michael|name}'s date of hire?
# 8                 What is {Nan|name}'s date of birth?
# 9                     What year was {Mia|name} hired?
# 10  When did we {fire|employment_action} {Jeff|name}?
# 11               How long has {Mia|name} worked here?
# 12                When was {Mia|name}'s date of hire?
# 13            What was the {Amy|name}'s date of hire?
# 14  When was {Michael|name} {hired|employment_acti...
# 15     When was {Mia|name} {hired|employment_action}?
# 16  What was {Mia|name}'s {date of hiring|date_time}?
# 17  What was the exact date when {Amy|name} {start...
# 18  Can you tell me how long has {Ivan|name} worke...
# 19  Which date was {Nan|name} {let go|employment_a...
# 20       Give me {Mia|name}'s {hiring date|date_time}
# 21  When {Amy|name} was {hired|employment_action} ...
# 22  Has {Ivan|name} been working here for {3 years...
# 23  What was the date when {Mia|name} was {hired|e...
# 24  When {Mia|name} {began her employment|date_tim...
# 25  The date was what when {Mia|name} {started wor...
# 26                  {Mia|name} {start date|date_time}
# 27                   {Mia|name} {fire date|date_time}
# 28                 {start date|date_time}, {Mia|name}
# 29                 {fire date|date_time}, {Ivan|name}
# ..                                                ...
# 62  when did {Amy|name} officially {join|employmen...
# 63                 {Nan|name} {firing date|date_time}
# 64                {Amy|name} {date of fire|date_time}
# 65  {Mia|name} {date of employment termination|dat...
# 66  employment {termination date|date_time} {Amy|n...
# 67     {Mia|name} was {fired on which date|date_time}
# 68            {Mia|name} {termination date|date_time}
# 69  Was {Mia|name} {fired in between the month of ...
# 70  tell me the date when {Mia|name} had to {leave...
# 71  What was {Amy|name}'s official join date at th...
# 72  What is the duration of {Ivan|name}'s employme...
# 73                                                NaN
# 74                                                NaN
# 75                                                NaN
# 76                                                NaN
# 77                                                NaN
# 78                                                NaN
# 79                                                NaN
# 80                                                NaN
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
# 84                                                NaN
# 85                                                NaN
# 86                                                NaN
# 87                                                NaN
# 88                                                NaN
# 89                                                NaN
# 90                                                NaN
# 91                                                NaN
#
#                              get_date_range_aggregate  \
# 0                                      Returns Number
# 1   (Average, Total, Percentage) Like Get_Aggregat...
# 2   What {percentage|function} of employees were {...
# 3   What {percent|function} of employees were {hir...
# 4   What {percentage|function} of employees were {...
# 5   What {percent|function} of all our employees w...
# 6   What {percentage|function} of employees were {...
# 7   How many employees were {hired|employment_acti...
# 8   How many people were based out of {Colarado|st...
# 9   What {percentage|function} of employees have b...
# 10  How many employees are below the {age of|age} ...
# 11  How many employees are {under|comparator} {30|...
# 12  How many employees are {over|comparator} {50|s...
# 13  How many employees were born in the {year 2009...
# 14  How many people have worked here since {2015|d...
# 15   How many people are there under {30|sys_number}?
# 16  Employees with more than {5 yrs|sys_duration} ...
# 17    number of people {working since 2016|date_time}
# 18  {total|function} number of employee that have ...
# 19  what is the {fraction|function} of employees t...
# 20  have there been any employees that have been {...
# 21  can you please tell me what {fraction|function...
# 22  what is the {total|function} number of employe...
# 23  employees {born|date_time} {before 1994|sys_in...
# 24  i want the {count|function} of employees that ...
# 25  {percent|function} of employees {born|date_tim...
# 26  {1980|sys_time} {born|date_time} employees {to...
# 27  how many employees were {born|date_time} withi...
# 28  what is the number of employees {born|date_tim...
# 29                                                NaN
# ..                                                ...
# 62                                                NaN
# 63                                                NaN
# 64                                                NaN
# 65                                                NaN
# 66                                                NaN
# 67                                                NaN
# 68                                                NaN
# 69                                                NaN
# 70                                                NaN
# 71                                                NaN
# 72                                                NaN
# 73                                                NaN
# 74                                                NaN
# 75                                                NaN
# 76                                                NaN
# 77                                                NaN
# 78                                                NaN
# 79                                                NaN
# 80                                                NaN
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
# 84                                                NaN
# 85                                                NaN
# 86                                                NaN
# 87                                                NaN
# 88                                                NaN
# 89                                                NaN
# 90                                                NaN
# 91                                                NaN
#
#                              get date_range_employees  \
# 0                                   Returns Employees
# 1   Like Get_Employees but filtered by Date(Born, ...
# 2   Give me a list of people {hired this year|date...
# 3   Tell me about employees who {started in Spring...
# 4   Which employees were not yet {born|date_time} ...
# 5   list the employees who {joined last Monday|dat...
# 6   Which employess were {hired|employment_action}...
# 7   Which employees were {hired after Jan 1, 2019|...
# 8   Who worked for Cisco for {less than|comparator...
# 9   Which employees have been {hired this year|dat...
# 10  Which employee was {hired within the last mont...
# 11  Which employees have {been with us|date_time} ...
# 12  Give me the employees that have {been with us|...
# 13  I want a list of employees that were {born in|...
# 14  Which employees were {born in|date_time} the {...
# 15  Fetch me a list of workers that have their {bi...
# 16  What are our {top|extreme} {10|sys_number} {ol...
# 17  Give me the {top|extreme} ten {youngest|age} w...
# 18                       List of {oldest|age} workers
# 19                       List of {youngest|age} works
# 20                        {oldest|age} employees list
# 21                      {youngest|age} employees list
# 22  {15|sys_number} most recently {fired|employmen...
# 23  {fifteen|sys_number} most recently {hired|empl...
# 24        Which employees joined the company recently
# 25  Give me a list of employees that were {hired i...
# 26  Give me a list of folks {fired last summer|dat...
# 27  Which employees did we {get rid of last fall|d...
# 28  Which employees are {born in|date_time} {May|s...
# 29  Give me a list of employees that have a {birth...
# ..                                                ...
# 62  {singles|maritaldesc} {fired|employment_action...
# 63  {married|maritaldesc} employees {hired|employm...
# 64  {divorced|maritaldesc} folks that had their em...
# 65  white employees {born|date_time} {after 1990|s...
# 66  {90's|time_interval} {born|date_time} {white|r...
# 67  {asians|racedesc} {born in|date_time} the {80'...
# 68  find me the {asians|racedesc} {born|date_time}...
# 69  get me {accountants|position} {born|date_time}...
# 70  who are our {90's|time_interval} {born|date_ti...
# 71                                                NaN
# 72                                                NaN
# 73                                                NaN
# 74                                                NaN
# 75                                                NaN
# 76                                                NaN
# 77                                                NaN
# 78                                                NaN
# 79                                                NaN
# 80                                                NaN
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
# 84                                                NaN
# 85                                                NaN
# 86                                                NaN
# 87                                                NaN
# 88                                                NaN
# 89                                                NaN
# 90                                                NaN
# 91                                                NaN
#
#                                         get_hierarchy
# 0                                  Returns Employees
# 1   (up and down hierarchy employees for all names...
# 2                       Who is {Mia|name}'s manager?
# 3   Which employees have {Julia|name} as their man...
# 4         What is the name of {Julia|name}'s manager?
# 5                    Who is {Michael|name}'s manager?
# 6                Who is {John Reeder|name}'s manager?
# 7                  Who is {Mia Brown|name}'s manager?
# 8                   Who is the manager for {Bob|name}
# 9                What is {Mia|name}'s manager's name?
# 10                  Who reports into {Nan Singh|name}
# 11  can i have the names of employees who report t...
# 12  Which employees are under the Manager {Amy|name}?
# 13           who {works for|manager} {Nan Singh|name}
# 14  Tell who is {working under|manager} Mr. {Singh...
# 15  employee list with {manager|manager} being {Na...
# 16  {Nan singh|name} is the {manager|manager} of w...
# 17  which employees is {Nan singh|name} the {manag...
# 18  for which employees is {Nan singh|name} the {s...
# 19  {nan singh|name} is the {manager|manager} for ...
# 20  which of our employees have {nan singh|name} a...
# 21  get me a list of all of the employees that are...
# 22  employees that directly {report|manager} to Mr...
# 23  who is Ms. {Amy Dunn|name} {reporting|manager} to
# 24  Does {Amy Dunn|name} have a {manager|manager},...
# 25  I want to know the name of the {manager|manage...
# 26                  {Amy Dunn|name} {manager|manager}
# 27             {amy dunn|name} {manager|manager} name
# 28      {manager|manager} name for ms {amy dunn|name}
# 29  get me ms. {dunn|name}'s {manager|manager} ful...
# ..                                                ...
# 62  tell me the {supervisor|manager} that is {repo...
# 63                                                NaN
# 64                                                NaN
# 65                                                NaN
# 66                                                NaN
# 67                                                NaN
# 68                                                NaN
# 69                                                NaN
# 70                                                NaN
# 71                                                NaN
# 72                                                NaN
# 73                                                NaN
# 74                                                NaN
# 75                                                NaN
# 76                                                NaN
# 77                                                NaN
# 78                                                NaN
# 79                                                NaN
# 80                                                NaN
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
# 84                                                NaN
# 85                                                NaN
# 86                                                NaN
# 87                                                NaN
# 88                                                NaN
# 89                                                NaN
# 90                                                NaN
# 91                                                NaN
#
# [92 rows x 10 columns]

# %%
text = intent_txt[intent_txt.columns[2]][10]
text
# Out:
# 'Which employees have gotten only {positive feedback|performance_score}?'

# %%
get_labels(text)
# Out:
# ['{positive feedback|performance_score}']

# %%
get_label_kv(get_labels(text))
# Out:
# [['positive feedback'], ['performance_score']]

# %%
def get_labels(text):
    chars = list(text)
    start, stop = 0, 0
    labels = []
    for i in range(len(chars)):
        if chars[i] == '{': 
            start = i
        if chars[i] == '}':
            stop = i
            txt = chars[start:(stop + 1)]
            labels.append("".join(chars[start:(stop + 1)]))
    return labels

# %%
def get_label_kv(labels):
    k = []
    v = []
    for label in labels:
        k.append(label.split('|')[0].replace("{", ""))
        v.append(label.split('|')[1].replace("}", ""))
    return [k,v]

# %%
def label_chk_helper(sentence, ent_dict, labels, col, idx):

    for ent in ent_dict:
        syns = get_synonyms(ent_dict, ent)
        
        for syn in syns:
            if syn in sentence and syn not in labels[0] and syn not in labels[1]: pass
#                 print("POTENTIAL MISSING LABEL")
#                 print("SYNONYM: " + syn)
#                 print("ENTITY: " + ent)
#                 print("SENTENCE: " + sentence)
#                 print("Column: " + col)
#                 print("Index: " + idx)
#                 print("==========================================")

# %%
# Check if the Synonyms to Entities Were not Labelled in Training
# param df (dataframe) - Dataframe where each column is an intent and each row has sentence examples
# param ent_dict (dict) - Dictionary that contains entities as keys and synonyms
def label_chk(df, ent_dict):
    for col in df:
        print(col.upper() + "=============================================================")
        idx = 2
        nan = is_nan(df[col][idx])
        while(not nan):
            try:
                nan = is_nan(df[col][idx])
                # Check for Synonyms
                l_dict = {}
                
                sentence = df[col][idx]
                labels = get_labels(sentence)
                labels = get_label_kv(labels)
                label_chk_helper(sentence, ent_dict, labels, col, idx)
                
                if(len(labels[0]) != 0):
                    for ct in range(len(labels[0])):
                        k = labels[0][ct]
                        v = labels[1][ct]
            
                        if k in l_dict:
                            print("MISMATCH " + k)
                            print("SENTENCE: " )
                        else: 
                            l_dict[k] = v

                
                idx += 1
            except Exception as e: 
                #print(e)
                break

# %%
label_chk(intent_txt, ent_dict)
# Out:
# GET_INFO=============================================================
# GET_AGGREGATE=============================================================
# GET_EMPLOYEES=============================================================
# GET_SALARY=============================================================
# GET_SALARY_AGGREGATE=============================================================
# GET_SALARY_EMPLOYEES=============================================================
# MISMATCH earning
# GET_DATE=============================================================
# GET_DATE_RANGE_AGGREGATE=============================================================
# GET DATE_RANGE_EMPLOYEES=============================================================
# GET_HIERARCHY=============================================================
# MISMATCH manager
# MISMATCH supervisor

# %% [markdown]
# <h4>Generate Gazetteers</h4>

# %%
gen_gazetteers(ent_dict)

# %% [markdown]
# <h4>Generate Mapping.json</h4>

# %%
gen_map_json_files(ent_dict)
