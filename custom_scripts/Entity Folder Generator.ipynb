# %%
import numpy as np
import pandas as pd
import random
import os
import json

# %% [markdown]
# <h2>Functions</h2>

# %% [markdown]
# <h3>General Functions</h3>

# %%
# Check if a Value is Nan
# param x - Value to check
# return boolean - If it is a Nan
def is_nan(x):
    return (x is np.nan or x != x)

# Check All Values in List are Nan
# param x - List to check
# return boolean - If it is all Nan
def list_is_nan(x):
    for i in x:
        if not is_nan(i): return False
    return True

# Converts names to single string
# param names (list) - List of names in the format [['Mia', 'Brown'],[..]]
# return unique (list) - List of names in the format ['Mia Brown', ..]
def name_to_str(names):
    return [",".join(name).replace(",", " ") for name in names]

# Converts names to single string
# param names (list) - List of names in the format ['Mia Brown', ..]
# return names_list (list) - List of names in the format [['Mia', 'Brown'],[..]]
def str_name_to_list(names):
    for i in range(len(names)):
        full_name = names[i].split()
        names[i] = [full_name[0], full_name[len(full_name) - 1]]
    return names

# Extracts All of the Elements in a List of (One or Two D) Lists
# param two_d_list (list) List of (One or Two D) Lists
# return new_elems (list) List of elements
def extract_2d_list(two_d_list):
    elems, new_elems = [], []
    for elem in two_d_list: elems.extend(elem)
    for elem in elems:
        if isinstance(elem, list): new_elems.extend(elem)
        else: new_elems.append(elem)
    return new_elems

# %% [markdown]
# <h3>Get Unique Values</h3>

# %%
# Get the Names of Employees in the HR Dataset
# param df (dataframe) - Dataframe with names
# param column (str) - Column can be 'Employee Name' or 'Manager Name'
# Returns names (list) - Array of names (['First', 'Last'])
def get_names(df, column='Employee Name'):
    names = [df[[column]].iloc[i][0] for i in range(df.shape[0] - 1)]
    for i in range(len(names)):
        try:
            full_name = names[i].split(',')
            first = full_name[1].strip().split()[0]
            last = full_name[0]
            names[i] = [first, last]
        except:
            names[i] = ['Jeremy', 'Prater']
    return names

# Filter to list of unique names
# param names (list) - List of names in the format [['Mia', 'Brown'],[..]]
# param avoid (list) - List of names to avoid duplicates of
# return unique (list) - List of names in the format [['Mia', 'Brown'],[..]]
def filter_names_helper(names, avoid = []):
    unique = []
    first, last = [], []
    if(len(avoid) != 0):
        first = [n[0] for n in avoid]
        last = [n[1] for n in avoid]
    for name in names:
        if((name[0] not in first) and (name[1] not in last)):
            first.append(name[0])
            last.append(name[1])
            unique.append(name)
    return unique

# Filter to list of unique names that don't overlap with manager names
# param df (dataframe) - Dataframe with names 
# return unique (list) - List of names in the format [['Mia', 'Brown'],[..]]
def get_filtered_names(df):
    managers = str_name_to_list(get_uniq_str(df, "Manager Name"))
    managers = filter_names_helper(managers)
    survey_users = [['Mia','Brown'], ['Ivan','Rogers'], ['Julia','Soto'], ['Nan','Singh']]
    user_names = get_names(hr_data)
    user_names = filter_names_helper(user_names, avoid=survey_users)
    user_names = filter_names_helper(user_names, avoid=managers)
    user_names.extend(survey_users)
    return user_names

# Update Name Synonyms
def name_syn_update(ent_dict):
    syn_names = []
    for name in ent_dict['name'][0]:
        name_splt = name.split()
        name_syn = [name.lower(), name_splt[0], name_splt[0].lower(),
                    name_splt[1], name_splt[1].lower()]
        syn_names.append(name_syn)
    return syn_names

# %%
# Get the Unique Names of Employees in the HR Dataset
# param df (dataframe) - Dataframe with names
# return unique (list) - List of names in the format ['Mia Brown', ..]
def get_uniq_names(df):
    return filter_names(get_names(df))

# Get Unique String Values of a Dataframe Column
# param df (dataframe) - Source Dataframe
# param col_name (str) - Name of Column to get unique values'
# return uniq_arr (arr) - Array of Unique Values
def get_uniq_str(df, col_name):
    return [i.lower().strip() for i in df[col_name].unique()[:-1]]

# Get Unique String Values of a Dataframe Column
# param df (dataframe) - Source Dataframe
# param col_name (str) - Name of Column to get unique values'
# return uniq_arr (arr) - Array of Unique Values
def get_uniq_num(df, col_name):
    return [str(int(i)) for i in df[col_name].unique()[:-1]]

# Generate a Dictionary with Unique Values for Select Columns
# param df (dataframe) - Source Dataframe
# return uniq (dict) - Dictionary that maps entities to unique values
def gen_uniq_dict(df):
    # Get Unique Values of Relevant Columns
    uniq = {}
    # Predefined
    uniq['name'] = name_to_str(get_filtered_names(df))
    uniq['sex'] = ['male', 'female']
    uniq['employment_status'] = ['active', 'voluntarily terminated', 'terminated for a cause',
                          'on a leave of absence' + 'going to start work in the future']
    uniq['performance_score'] = ['fully meet performance expecations', 'are too early to review', 
                         'meet 90-day expectations', 'are exceptional', 'need improvement', 'exeed expecations']
    # Custom Preprocessing
    uniq['state'] = hr_data['State'].unique()[:-1]
    # Standard Preprocessing 
    uniq['age'] = get_uniq_num(hr_data, 'Age')
    uniq['maritaldesc'] = get_uniq_str(hr_data, "MaritalDesc")
    uniq['citizendesc'] = get_uniq_str(hr_data, "CitizenDesc")
    uniq['racedesc'] = get_uniq_str(hr_data, "RaceDesc")
    uniq['department'] = get_uniq_str(hr_data, "Department")
    uniq['position'] = get_uniq_str(hr_data, "Position")
    #uniq['manager'] = name_to_str(str_name_to_list(get_uniq_str(hr_data, "Manager Name")))
    uniq['employee_source'] = get_uniq_str(hr_data, "Employee Source")
    return uniq

# Generate a Dictionary with Unique Values for Select Columns
# param uniq (dict) - Dictionary that maps entities to unique values
# param ent_dict (dict) - Dictionary that Contains Entity Information
# return uniq (dict) - Dictionary that maps entities to unique values
def uniq_dict_update(uniq, ent_dict):
    uniq['money'] = ent_dict['money'][1][0]
    uniq['time_interval'] = extract_2d_list(ent_dict['time_interval'])
    uniq['time_recur'] = extract_2d_list(ent_dict['time_recur'])
    uniq['function'] = extract_2d_list(ent_dict['function'])
    uniq['extreme'] = extract_2d_list(ent_dict['extreme'])
    uniq['employment_action'] = extract_2d_list(ent_dict['employment_action'])
    uniq['date_compare'] = extract_2d_list(ent_dict['date_compare'])
    uniq['manager'] = extract_2d_list(ent_dict['manager'])
    return uniq

# %%
#extract_2d_list(ent_dict['manager'])

# %% [markdown]
# <h3>Load, Parse and Clean Entity Data</h3>

# %%
# Load entity data frame from CSV
# param path (str) - Path to csv
# return ent_df (dataframe) - Entity Info Dataframe
def load_ent(path):
    df = pd.read_csv(path).iloc[:, :4]
    ct = 0
    while (ct < len(df) and not list_is_nan(df.iloc[ct, :].values)): ct += 1
    return df.iloc[:ct, :]

# Parse CSV that contains [Entity, Options, Synonyms, Gazetteer]
# param ent_df (dataframe) - Contains the columns listed above
# return ent_dict (dict) - Uncleaned dictionary where the keys are the entities
#                          and the values are [options (arr), synonyms (arr), gazetteer (arr)]
def ent_parse(ent_df):
    ent_dict = {}
    ct = 0
    curr_ent = ''
    while(ct < len(ent_df)):
        row = ent_df.iloc[ct]
        # update curr_ent if new entity
        if(not is_nan(row['Entity'])): 
            curr_ent = row['Entity']
            ent_dict[curr_ent] = [[], [], []]
        # check if options is a list
        if(not is_nan(row['Options']) and row['Options'].count(',') > 2):
            ent_dict[curr_ent][0] = row['Options']
            if(not is_nan(row['Synonyms'])): 
                ent_dict[curr_ent][1] = row['Synonyms'].split(',')
            if(not is_nan(row[3])): ent_dict[curr_ent][2] = row['Gazetteer']
        # single entry in option column
        else:
            ent_dict[curr_ent][0].append(row['Options'])
            ent_dict[curr_ent][1].append(row['Synonyms'])
            ent_dict[curr_ent][2].append(row['Gazetteer'])
        ct += 1
    return ent_dict

# Cleans the gazetteers of the ent dictionary
# param ent_dict (dictionary) - Entity Dictionary
# return ent_dict (dictionary) - Cleaned Entity Dictionary
def clean_options(ent_dict):
    for i in ent_dict.keys():
        old_opt = ent_dict[i][0]
        new_opt = []
        for word in old_opt:
            if(not is_nan(word)):
                new_opt.append(word.replace("'", "").replace(",", ""))
        ent_dict[i][0] = new_opt
    return ent_dict

# Cleans the gazetteers of the ent dictionary
# param ent_dict (dictionary) - Entity Dictionary
# return ent_dict (dictionary) - Cleaned Entity Dictionary
def clean_synonyms(ent_dict):
    for i in ent_dict.keys():
        old_syn = ent_dict[i][1]
        new_syn = []
        if(len(old_syn) != 0):
            for j in old_syn:
                if(not is_nan(j)): new_syn.append([string.strip() for string in j.split(',')])
                else: new_syn.append(j)
        ent_dict[i][1] = new_syn
    return ent_dict

# Cleans the gazetteers of the ent dictionary
# param ent_dict (dictionary) - Entity Dictionary
# return ent_dict (dictionary) - Cleaned Entity Dictionary
def clean_gazetteer(ent_dict):
    for i in ent_dict.keys():
        old_gaz = ent_dict[i][2]
        clean_gaz = []
        if (len(old_gaz) != 0):        
            if (type(old_gaz) is str): clean_gaz = old_gaz.split(',')
            elif(not is_nan(old_gaz[0])): clean_gaz = (old_gaz[0].split(','))
        ent_dict[i][2] = [i.strip() for i in clean_gaz]
    return ent_dict

# Cleans an Entity Dictionary
# ent_dict (dict) - Uncleaned dictionary of parsed entity information
# uniq (dict) - Dictionary that maps entities to unique values
# return cleaned_ent_dict (dict) - Cleaned dictionary
def clean_ent_dict(ent_dict, uniq):
    ent_dict = clean_options(ent_dict)
    ent_dict = clean_synonyms(ent_dict)
    ent_dict = clean_gazetteer(ent_dict)
    ent_dict['name'][0] = uniq['name']
    ent_dict['state'][0] = uniq['state']
    ent_dict['age'][0] = uniq['age']
    return ent_dict

# Parse and Clean Entity Data
# Parse CSV that contains [Entity, Options, Synonyms, Gazetteer]
# param ent_df (dataframe) - Contains the columns listed above
def parse_clean_ent(ent_df, uniq):
    ent = ent_parse(ent_df)
    return clean_ent_dict(ent, uniq)

# %% [markdown]
# <h3>File Generation</h3>

# %%
# Convert a list into a text file
# param folder (str) - Name of the folder to write the file
# param lines (list) - List of values to write to file
def list_to_txt_file(folder, lines):
    directory = '../hr_assistant/entities/' + folder + '/'
    if not os.path.exists(directory): os.makedirs(directory)
    with open(directory + 'gazetteer.txt', 'w+') as filehandle:  
        filehandle.writelines("%s\n" % line for line in lines)
        
# Convert a dict into a json file
# param folder (str) - Name of the folder to write the file
# param dict (dict) - Json dict to write to file
def dict_to_json_file(folder, json_dict):
    directory = '../hr_assistant/entities/' + folder + '/'
    if not os.path.exists(directory): os.makedirs(directory)
    with open(directory + "mapping.json", "w+") as f:
        json_str = json.dumps(json_dict, indent=4)
        f.write(json_str)
        
# Generate a Mapping JSON Dict to create Mapping.json file
# param ent_dict (dict) - Dictionary that maps entities to options, synonyms, and gazetteer
# param entity (str) - The entity to generate the gazetteer list for
# return json_dict (dict) - Json Dict in the proper format for mapping.json
def gen_map_json(ent_dict, entity):
    opt = ent_dict[entity][0]
    syn = ent_dict[entity][1]
    # Check if the Options and the Synonyms Align
    if(len(opt) != len(syn)): syn = [[] for i in range(len(opt))]
    return gen_map_json_helper(opt, syn)

# Helper function to Generate a Mapping JSON Dictionary
# param options (list) - Array of options
# param synonyms (2d list) - Array of synonym arrays corresponding to options
# return json_dict (dict) - Json Dict in the proper format for mapping.json
def gen_map_json_helper(options, synonyms):
    json_dict = {}
    json_dict['entities'] = []
    for i in range(len(options)):
        new_dict = {}
        if(is_nan(synonyms[i])): new_dict['whitelist'] = []
        else: new_dict['whitelist'] = synonyms[i]
        new_dict['cname'] = options[i]
        json_dict['entities'].append(new_dict)
    return json_dict

# Create Mapping.json files for Every Entity in an Entity Dictionary
# param ent_dict (dict) - Dictionary that maps entities to options, synonyms, and gazetteer
def gen_map_json_files(ent_dict):
    for entity in ent_dict.keys():
        json_dict = gen_map_json(ent_dict, entity)
        if(not is_nan(json_dict)): dict_to_json_file(entity, json_dict)

# Collect All Synonyms for a Single Entity in Entity Dict
# param ent_dict (dict) - Dictionary that maps entities to options, synonyms, and gazetteer
# param entity (str) - The entity to get Synyonyms for
# return synonyms (list) - List of Synonyms of Specified entity
def get_synonyms(ent_dict, entity):
    synonyms = []
    for syn in ent_dict[entity][1]:
        if(not is_nan(syn)): synonyms.extend(syn)
    return synonyms

# Generate a Gazetter List for an Entity
# param ent_dict (dict) - Dictionary that maps entities to options, synonyms, and gazetteer
# param entity (str) - The entity to generate the gazetteer list for
# return gaz (list) - List of gazetteer word relevant to the entity
def gen_gaz_list(ent_dict, entity):
    gaz = []
    gaz.extend(ent_dict[entity][0])
    gaz.extend(get_synonyms(ent_dict, entity))
    gaz.extend(ent_dict[entity][2])
    return gaz

# Create Gazetteer Files for Every Entity in an Entity Dictionary
# param ent_dict (dict) - Dictionary that maps entities to options, synonyms, and gazetteer
def gen_gazetteers(ent_dict):
    for entity in ent_dict.keys():
        gaz_list = gen_gaz_list(ent_dict, entity)
        list_to_txt_file(entity, gaz_list)

# %% [markdown]
# <h3>Debug Labelling</h3>

# %%
# Find all labels in a sentence
# pram text (str) String that may or may not contain labels in the form of {ent_type|ent}
# return labels (list) List of labels found in the text
def get_labels(text):
    chars = list(text)
    start, stop = 0, 0
    labels = []
    positions = []
    for i in range(len(chars)):
        if chars[i] == '{': 
            start = i
        if chars[i] == '}':
            stop = i
            txt = chars[start:(stop + 1)]
            labels.append("".join(chars[start:(stop + 1)]))
            positions.append([start, stop])
    return labels, positions

# Given a list of labels, Seperate Key and Values
# param labels (list) List of labels found in the text
# return kv (2d list) List of the Keys list and Values list [[key_array], [value_array]]
def get_kv(labels):
    k = []
    v = []
    for label in labels:
        if '|' in label:
            k.append(label.split('|')[0].replace("{", ""))
            v.append(label.split('|')[1].replace("}", ""))
    return [k,v]

# Check if a Synonym Exists in a Sentence that it is labelled
# param sentence (str) String that may or may not contain labels in the form of {ent_type|ent}
# param ent_dict (dict) - Dictionary that maps entities to options, synonyms, and gazetteer
# param kv_labels (2d list) List of the Keys list and Values list [[key_array], [value_array]]
# param col (str) Column in the dataframe
# param idx (int) Index of the Current Sentence in the Dataframe
def label_chk_helper(sentence, ent_dict, kv_labels, col, idx):
    sent_split = [word.lower() for word in sentence.split()]
    for ent in ent_dict:
        # Check for 'Entity Options' in text
        options = ent_dict[ent][0]
        for opt in options:
            if opt in sent_split and opt not in kv_labels[0] and opt not in kv_labels[1]:
                print("POTENTIAL OPTION-MISSING LABEL")
                print("OPTION: " + opt)
                print("ENTITY: " + ent)
                print("SENTENCE: " + sentence)
                print("Column: " + col)
                print("Index: " + str(idx + 2))
                print("==========================================")
        # Check for 'Synonym Options' in text
        syns = get_synonyms(ent_dict, ent)
        for syn in syns:
            if syn.lower() in sent_split and syn not in kv_labels[0]:
                print("POTENTIAL SYNONYM-MISSING LABEL")
                print("SYNONYM: " + syn)
                print("ENTITY: " + ent)
                print("SENTENCE: " + sentence)
                print("Column: " + col)
                print("Index: " + str(idx + 2))
                print("==========================================")
                
# Finds mismatches between labels in the Dataframe
# param kv_labels (2d list) List of the Keys list and Values list [[key_array], [value_array]]
# param sentence (str) String that may or may not contain labels in the form of {ent_type|ent}
# param l_dict (dict) Dictionary that keeps track of entity label mappings passed in from the main function
# param col (str) Column in the dataframe
# param idx (int) Index of the Current Sentence in the Dataframe
def chk_mismatch(labels, sentence, l_dict, col, idx):
    if(len(labels[0]) != 0):
        for ct in range(len(labels[0])):
            k = labels[0][ct]
            v = labels[1][ct]
            
            if k in l_dict: 
                if l_dict[k] != v:
                    print("POTENTIAL MISMATCH for: " + k)
                    print("CURRENT LABEL: " + v)
                    print("IN DICT: " + l_dict[k])
                    print("SENTENCE: " + sentence)
                    print("Column: " + col)
                    print("Index: " + str(idx + 2))
                    print("==========================================")
            else: l_dict[k] = v  

# Check if the Synonyms to Entities Were not Labelled in Training
# param df (dataframe) - Dataframe where each column is an intent and each row has sentence examples
# param ent_dict (dict) - Dictionary that contains entities as keys and synonyms
def label_chk(df, ent_dict):
    for col in df:
        print(col.upper() + "=============================================================")
        idx = 2
        nan = is_nan(df[col][idx])
        l_dict = {}
        while(idx < len(df)):
            if(is_nan(df[col][idx])): break
            sentence = df[col][idx]
            labels, pos = get_labels(sentence)
            labels = get_kv(labels)
            label_chk_helper(sentence, ent_dict, labels, col, idx)
            chk_mismatch(labels, sentence, l_dict, col, idx)
            idx += 1

# %% [markdown]
# <h2>Workflow</h2>

# %% [markdown]
# <h4>Load Data</h4>

# %%
hr_data = pd.read_csv('old_core_dataset.csv')
hr_data
# Out:
#              Employee Name  Employee Number State      Zip         DOB   Age  \
# 0               Brown, Mia     1.103024e+09    MA   1450.0  11/24/1985  32.0
# 1     LaRotonda, William       1.106027e+09    MA   1460.0   4/26/1984  33.0
# 2         Steans, Tyrone       1.302053e+09    MA   2703.0    9/1/1986  31.0
# 3          Howard, Estelle     1.211051e+09    MA   2170.0   9/16/1985  32.0
# 4              Singh, Nan      1.307060e+09    MA   2330.0   5/19/1988  29.0
# 5         Smith, Leigh Ann     7.110077e+08    MA   1844.0   6/14/1987  30.0
# 6      LeBlanc, Brandon  R     1.102024e+09    MA   1460.0   6/10/1984  33.0
# 7              Quinn, Sean     1.206043e+09    MA   2045.0   11/6/1984  33.0
# 8        Boutwell, Bonalyn     1.307060e+09    MA   2468.0    4/4/1987  30.0
# 9        Foster-Baker, Amy     1.201031e+09    MA   2050.0   4/16/1979  38.0
# 10             King, Janet     1.001495e+09    MA   1902.0   9/21/1954  63.0
# 11        Zamora, Jennifer     1.112031e+09    MA   2067.0   8/30/1979  38.0
# 12           Becker, Renee     1.102024e+09    MA   2026.0    4/4/1986  31.0
# 13           Goble, Taisha     9.050137e+08    MA   2127.0  10/23/1971  46.0
# 14       Hernandez, Daniff     1.410071e+09    MA   1960.0    8/7/1986  31.0
# 15           Horton, Jayne     1.105026e+09    MA   2493.0   2/21/1984  33.0
# 16        Johnson, Noelle      1.003018e+09    MA   2301.0   11/7/1986  31.0
# 17          Murray, Thomas     1.406068e+09    TX  78230.0    7/4/1988  29.0
# 18        Pearson, Randall     1.102024e+09    MA   2747.0    9/5/1984  33.0
# 19       Petrowsky, Thelma     1.108028e+09    MA   1886.0   9/16/1984  33.0
# 20             Roby, Lori      1.407069e+09    MA   1886.0  10/11/1981  36.0
# 21            Rogers, Ivan     1.203032e+09    MA   1810.0   8/26/1986  31.0
# 22           Salter, Jason     1.111030e+09    MA   2452.0  12/17/1987  30.0
# 23          Simard, Kramer     8.080103e+08    MA   2110.0    2/8/1970  47.0
# 24             Zhou, Julia     1.110030e+09    MA   2148.0   2/24/1979  38.0
# 25             Foss, Jason     1.192991e+09    MA   1460.0    7/5/1980  37.0
# 26              Roup,Simon     1.106027e+09    MA   2481.0    4/5/1973  44.0
# 27           Ruiz, Ricardo     1.001175e+09    MA   1915.0    1/4/1964  54.0
# 28           Monroe, Peter     1.011023e+09    MA   2134.0   10/5/1986  31.0
# 29           Dougall, Eric     1.101024e+09    MA   1886.0    7/9/1970  47.0
# ..                     ...              ...   ...      ...         ...   ...
# 272          Jeremy Prater     1.001085e+09    NV  89139.0    5/9/1974  43.0
# 273  Khemmich, Bartholemew     1.104025e+09    CO  80820.0  11/27/1979  38.0
# 274       Leruth, Giovanni     1.412072e+09    UT  84111.0  12/27/1988  29.0
# 275        Martins, Joseph     1.209049e+09    TX  78207.0   6/11/1970  47.0
# 276          McKinzie, Jac     1.209049e+09    TX  78789.0    7/1/1984  33.0
# 277       Mullaney, Howard     1.306058e+09    AL  36006.0   11/2/1975  42.0
# 278         Nguyen, Dheepa     1.111031e+09    GA  30428.0   3/31/1989  28.0
# 279         Onque, Jasmine     1.501072e+09    FL  33174.0   5/11/1990  27.0
# 280          Ozark, Travis     8.120118e+08    NC  27229.0   5/19/1982  35.0
# 281            Potts, Xana     1.102024e+09    KY  40220.0   8/29/1988  29.0
# 282       Riordan, Michael     1.502073e+09    ND  58782.0   1/15/1968  50.0
# 283        Strong, Caitrin     1.411071e+09    MT  59102.0   5/12/1989  28.0
# 284       Terry, Sharlene      1.401065e+09    OR  97756.0    5/7/1965  52.0
# 285        Valentin,Jackie     1.312064e+09    AZ  85006.0   5/23/1991  26.0
# 286       Villanueva, Noah     1.111031e+09    ME   4063.0   7/11/1989  28.0
# 287        Houlihan, Debra     1.009022e+09    RI   2908.0   3/17/1966  51.0
# 288         Daneault, Lynn     1.402065e+09    VT   5473.0   4/19/1990  27.0
# 289    Kampew, Donysha         1.109029e+09    PA  19444.0  11/11/1989  28.0
# 290            Smith, John     1.499903e+09    MA   1886.0   8/16/1984  33.0
# 291        Andreola, Colby     1.107027e+09    MA   2110.0   5/24/1979  38.0
# 292       Carabbio, Judith     1.101024e+09    MA   2132.0    4/5/1987  30.0
# 293      Del Bosque, Keyla     1.203032e+09    MA   2176.0    7/5/1979  38.0
# 294         Exantus, Susan     1.401065e+09    MA   1749.0   5/15/1987  30.0
# 295         Martin, Sandra     1.303055e+09    MA   2135.0   11/7/1987  30.0
# 296        Patronick, Luke     1.112031e+09    MA   1844.0   2/20/1979  38.0
# 297           Saada, Adell     1.012023e+09    MA   2132.0   7/24/1986  31.0
# 298          Szabo, Andrew     1.201031e+09    MA   2140.0    5/6/1983  34.0
# 299           True, Edward     1.102024e+09    MA   2451.0   6/14/1983  34.0
# 300       Sweetwater, Alex     1.001645e+09    MA   2184.0  11/22/1966  51.0
# 301                    NaN              NaN   NaN      NaN         NaN   NaN
#
#         Sex MaritalDesc          CitizenDesc Hispanic/Latino  ...  \
# 0    Female     Married           US Citizen              No  ...
# 1      Male    Divorced           US Citizen              No  ...
# 2      Male      Single           US Citizen              No  ...
# 3    Female     Married           US Citizen              No  ...
# 4    Female      Single           US Citizen              No  ...
# 5    Female     Married           US Citizen              No  ...
# 6      Male     Married           US Citizen              No  ...
# 7      Male     Married  Eligible NonCitizen              No  ...
# 8    Female     Married           US Citizen              No  ...
# 9    Female     Married           US Citizen              no  ...
# 10   Female     Married           US Citizen             Yes  ...
# 11   Female      Single           US Citizen              No  ...
# 12   Female      Single           US Citizen             Yes  ...
# 13   Female      Single           US Citizen              No  ...
# 14     Male     Married           US Citizen              No  ...
# 15   Female      Single           US Citizen              No  ...
# 16   Female     Married           US Citizen              No  ...
# 17     Male    Divorced           US Citizen              No  ...
# 18     Male     Married           US Citizen              No  ...
# 19   Female     Married           US Citizen              No  ...
# 20   Female     Married           US Citizen              No  ...
# 21     Male     Married           US Citizen              No  ...
# 22     Male    Divorced           US Citizen              No  ...
# 23     Male     Married           US Citizen             Yes  ...
# 24   Female      Single           US Citizen              No  ...
# 25     Male      Single           US Citizen              No  ...
# 26     Male      Single           US Citizen              No  ...
# 27     Male    Divorced           US Citizen              No  ...
# 28     Male     Married  Eligible NonCitizen             Yes  ...
# 29     Male      Single           US Citizen              No  ...
# ..      ...         ...                  ...             ...  ...
# 272    Male     Married           US Citizen              No  ...
# 273    Male      Single           US Citizen              No  ...
# 274    Male   Separated           US Citizen              No  ...
# 275    Male      Single  Eligible NonCitizen              No  ...
# 276    Male     Married           US Citizen              No  ...
# 277    Male      Single           US Citizen              No  ...
# 278  Female      Single           US Citizen              No  ...
# 279  Female      Single           US Citizen             Yes  ...
# 280    Male      Single           US Citizen              No  ...
# 281  Female     Married           US Citizen              No  ...
# 282    Male   Separated           US Citizen              No  ...
# 283  Female     Married           US Citizen              No  ...
# 284  Female      Single           US Citizen              No  ...
# 285  Female     Married           US Citizen              No  ...
# 286    Male      Single           US Citizen              No  ...
# 287  Female     Married           US Citizen              No  ...
# 288  Female      Single           US Citizen              No  ...
# 289  Female      Single           US Citizen              No  ...
# 290    Male    Divorced           US Citizen              no  ...
# 291  Female      Single           US Citizen              No  ...
# 292  Female      Single           US Citizen              No  ...
# 293  Female      Single           US Citizen              No  ...
# 294  Female     Married           US Citizen              No  ...
# 295  Female   Separated           US Citizen              No  ...
# 296    Male      Single           US Citizen              No  ...
# 297  Female     Married           US Citizen              No  ...
# 298    Male      Single           US Citizen              No  ...
# 299    Male      Single          Non-Citizen              No  ...
# 300    Male      Single           US Citizen              No  ...
# 301     NaN         NaN                  NaN             NaN  ...
#
#     Date of Hire Date of Termination                   Reason For Term  \
# 0     10/27/2008                 NaN              N/A - still employed
# 1       1/6/2014                 NaN              N/A - still employed
# 2      9/29/2014                 NaN              N/A - still employed
# 3      2/16/2015           4/15/2015              N/A - still employed
# 4       5/1/2015                 NaN              N/A - still employed
# 5      9/26/2011           9/25/2013                     career change
# 6       1/5/2016                 NaN              N/A - still employed
# 7      2/21/2011           8/15/2015                     career change
# 8      2/16/2015                 NaN              N/A - still employed
# 9       1/5/2009                 NaN              N/A - still employed
# 10      7/2/2012                 NaN              N/A - still employed
# 11     4/10/2010                 NaN              N/A - still employed
# 12      7/7/2014           9/12/2015                       performance
# 13     2/16/2015           3/15/2015                  no-call, no-show
# 14     2/16/2015           2/22/2015                  no-call, no-show
# 15     3/30/2015                 NaN              N/A - still employed
# 16      1/5/2015                 NaN              N/A - still employed
# 17    11/10/2014                 NaN              N/A - still employed
# 18     12/1/2014            5/1/2016                       performance
# 19    11/10/2014                 NaN              N/A - still employed
# 20     2/16/2015                 NaN              N/A - still employed
# 21     3/30/2015                 NaN              N/A - still employed
# 22      1/5/2015          10/31/2015                             hours
# 23      1/5/2015                 NaN              N/A - still employed
# 24     3/30/2015                 NaN              N/A - still employed
# 25     4/15/2011                 NaN              N/A - still employed
# 26     1/20/2013                 NaN              N/A - still employed
# 27      1/9/2012           11/4/2015                             hours
# 28     2/15/2012                 NaN              N/A - still employed
# 29      1/5/2014                 NaN              N/A - still employed
# ..           ...                 ...                               ...
# 272    5/12/2014                 NaN              N/A - still employed
# 273    8/19/2013                 NaN              N/A - still employed
# 274    4/30/2012                 NaN              N/A - still employed
# 275    5/14/2012                 NaN              N/A - still employed
# 276     7/6/2016                 NaN         N/A - Has not started yet
# 277    9/29/2014                 NaN              N/A - still employed
# 278     7/8/2013                 NaN              N/A - still employed
# 279    9/30/2013                 NaN              N/A - still employed
# 280     1/5/2015                 NaN              N/A - still employed
# 281     1/9/2012                 NaN              N/A - still employed
# 282     1/9/2006                 NaN              N/A - still employed
# 283    9/27/2010                 NaN              N/A - still employed
# 284    9/29/2014                 NaN              N/A - still employed
# 285     7/5/2011                 NaN              N/A - still employed
# 286     3/5/2012                 NaN              N/A - still employed
# 287     5/5/2014                 NaN              N/A - still employed
# 288     5/5/2014                 NaN              N/A - still employed
# 289    11/7/2011           4/24/2014  maternity leave - did not return
# 290    5/18/2014                 NaN              N/A - still employed
# 291   11/10/2014                 NaN              N/A - still employed
# 292   11/11/2013                 NaN              N/A - still employed
# 293     1/9/2012                 NaN              N/A - still employed
# 294     5/2/2011            6/5/2013                        attendance
# 295   11/11/2013                 NaN              N/A - still employed
# 296    11/7/2011            9/7/2015                  Another position
# 297    11/5/2012                 NaN              N/A - still employed
# 298     7/7/2014                 NaN              N/A - still employed
# 299    2/18/2013           4/15/2014                    medical issues
# 300    8/15/2011                 NaN              N/A - still employed
# 301          NaN                 NaN                               NaN
#
#           Employment Status                 Department  \
# 0                    Active              Admin Offices
# 1                    Active              Admin Offices
# 2                    Active              Admin Offices
# 3                    Active              Admin Offices
# 4                    Active              Admin Offices
# 5    Voluntarily Terminated              Admin Offices
# 6                    Active              Admin Offices
# 7    Voluntarily Terminated              Admin Offices
# 8                    Active              Admin Offices
# 9                    Active              Admin Offices
# 10                   Active           Executive Office
# 11                   Active                      IT/IS
# 12     Terminated for Cause                      IT/IS
# 13     Terminated for Cause                      IT/IS
# 14     Terminated for Cause                      IT/IS
# 15                   Active                      IT/IS
# 16         Leave of Absence                      IT/IS
# 17                   Active                      IT/IS
# 18   Voluntarily Terminated                      IT/IS
# 19                   Active                      IT/IS
# 20                   Active                      IT/IS
# 21                   Active                      IT/IS
# 22   Voluntarily Terminated                      IT/IS
# 23                   Active                      IT/IS
# 24                   Active                      IT/IS
# 25                   Active                      IT/IS
# 26                   Active                      IT/IS
# 27   Voluntarily Terminated                      IT/IS
# 28                   Active                      IT/IS
# 29                   Active                      IT/IS
# ..                      ...                        ...
# 272                  Active                      Sales
# 273                  Active                      Sales
# 274                  Active                      Sales
# 275                  Active                      Sales
# 276            Future Start                      Sales
# 277                  Active                      Sales
# 278                  Active                      Sales
# 279                  Active                      Sales
# 280                  Active                      Sales
# 281                  Active                      Sales
# 282                  Active                      Sales
# 283                  Active                      Sales
# 284                  Active                      Sales
# 285                  Active                      Sales
# 286                  Active                      Sales
# 287                  Active                      Sales
# 288                  Active                      Sales
# 289  Voluntarily Terminated                      Sales
# 290                  Active                      Sales
# 291                  Active       Software Engineering
# 292                  Active       Software Engineering
# 293                  Active       Software Engineering
# 294    Terminated for Cause       Software Engineering
# 295                  Active       Software Engineering
# 296  Voluntarily Terminated       Software Engineering
# 297                  Active       Software Engineering
# 298                  Active       Software Engineering
# 299  Voluntarily Terminated       Software Engineering
# 300                  Active  Software Engineering
# 301                     NaN                        NaN
#
#                          Position Pay Rate        Manager Name  \
# 0                    Accountant I    28.50  Brandon R. LeBlanc
# 1                    Accountant I    23.00  Brandon R. LeBlanc
# 2                    Accountant I    29.00  Brandon R. LeBlanc
# 3        Administrative Assistant    21.50  Brandon R. LeBlanc
# 4        Administrative Assistant    16.56  Brandon R. LeBlanc
# 5        Administrative Assistant    20.50  Brandon R. LeBlanc
# 6         Shared Services Manager    55.00          Janet King
# 7         Shared Services Manager    55.00          Janet King
# 8                  Sr. Accountant    34.95  Brandon R. LeBlanc
# 9                  Sr. Accountant    34.95  Board of Directors
# 10                President & CEO    80.00  Board of Directors
# 11                            CIO    65.00          Janet King
# 12         Database Administrator    43.00          Simon Roup
# 13         Database Administrator    48.50          Simon Roup
# 14         Database Administrator    40.10          Simon Roup
# 15         Database Administrator    34.00          Simon Roup
# 16         Database Administrator    40.00          Simon Roup
# 17         Database Administrator    35.50          Simon Roup
# 18         Database Administrator    41.00          Simon Roup
# 19         Database Administrator    42.75          Simon Roup
# 20         Database Administrator    39.55          Simon Roup
# 21         Database Administrator    42.20          Simon Roup
# 22         Database Administrator    45.00          Simon Roup
# 23         Database Administrator    30.20          Simon Roup
# 24         Database Administrator    31.40          Simon Roup
# 25                    IT Director    65.00     Jennifer Zamora
# 26                IT Manager - DB    62.00     Jennifer Zamora
# 27                IT Manager - DB    21.00     Jennifer Zamora
# 28             IT Manager - Infra    63.00     Jennifer Zamora
# 29           IT Manager - Support    64.00     Jennifer Zamora
# ..                            ...      ...                 ...
# 272            Area Sales Manager    56.00       Lynn Daneault
# 273            Area Sales Manager    55.00       Lynn Daneault
# 274            Area Sales Manager    55.00          John Smith
# 275            Area Sales Manager    56.00       Lynn Daneault
# 276            Area Sales Manager    55.00       Lynn Daneault
# 277            Area Sales Manager    55.00          John Smith
# 278            Area Sales Manager    55.00       Lynn Daneault
# 279            Area Sales Manager    57.00       Lynn Daneault
# 280            Area Sales Manager    55.00          John Smith
# 281            Area Sales Manager    55.00       Lynn Daneault
# 282            Area Sales Manager    55.00       Lynn Daneault
# 283            Area Sales Manager    54.00          John Smith
# 284            Area Sales Manager    55.00       Lynn Daneault
# 285            Area Sales Manager    55.00          John Smith
# 286            Area Sales Manager    56.00          John Smith
# 287             Director of Sales    60.00          Janet King
# 288                 Sales Manager    54.00      Debra Houlihan
# 289                 Sales Manager    60.25      Debra Houlihan
# 290                 Sales Manager    56.00      Debra Houlihan
# 291             Software Engineer    47.60     Alex Sweetwater
# 292             Software Engineer    56.00     Alex Sweetwater
# 293             Software Engineer    57.12     Alex Sweetwater
# 294             Software Engineer    48.50     Alex Sweetwater
# 295             Software Engineer    55.51     Alex Sweetwater
# 296             Software Engineer    52.25     Alex Sweetwater
# 297             Software Engineer    49.25     Alex Sweetwater
# 298             Software Engineer    48.00     Alex Sweetwater
# 299             Software Engineer    45.42     Alex Sweetwater
# 300  Software Engineering Manager    27.00     Jennifer Zamora
# 301                           NaN      NaN                 NaN
#
#                             Employee Source         Performance Score
# 0                        Diversity Job Fair               Fully Meets
# 1                        Website Banner Ads               Fully Meets
# 2                           Internet Search               Fully Meets
# 3                    Pay Per Click - Google  N/A- too early to review
# 4                        Website Banner Ads  N/A- too early to review
# 5                        Diversity Job Fair               Fully Meets
# 6                               Monster.com               Fully Meets
# 7                        Diversity Job Fair               Fully Meets
# 8                        Diversity Job Fair              90-day meets
# 9                                     Other               Fully Meets
# 10                   Pay Per Click - Google               Fully Meets
# 11                        Employee Referral               Exceptional
# 12        Search Engine - Google Bing Yahoo               Fully Meets
# 13                                Glassdoor               Fully Meets
# 14                        Employee Referral  N/A- too early to review
# 15                                Glassdoor  N/A- too early to review
# 16                                Glassdoor              90-day meets
# 17                       Diversity Job Fair               Exceptional
# 18                        Employee Referral               Fully Meets
# 19                        Employee Referral               Exceptional
# 20                        Employee Referral               Fully Meets
# 21                   Pay Per Click - Google  N/A- too early to review
# 22                          Vendor Referral              90-day meets
# 23                        Employee Referral              90-day meets
# 24                        Employee Referral              90-day meets
# 25                     Professional Society               Exceptional
# 26                     Professional Society               Fully Meets
# 27                       Diversity Job Fair               Fully Meets
# 28                       Diversity Job Fair         Needs Improvement
# 29                     Professional Society                   Exceeds
# ..                                      ...                       ...
# 272                      Website Banner Ads                       PIP
# 273                  Pay Per Click - Google               Fully Meets
# 274                      Website Banner Ads               Fully Meets
# 275                       Employee Referral               Fully Meets
# 276                      Website Banner Ads  N/A- too early to review
# 277                         Internet Search         Needs Improvement
# 278                  Pay Per Click - Google               Fully Meets
# 279                  Pay Per Click - Google               Fully Meets
# 280                      Website Banner Ads              90-day meets
# 281                      Website Banner Ads               Fully Meets
# 282                               Billboard                   Exceeds
# 283                    Professional Society               Fully Meets
# 284                             Monster.com               Fully Meets
# 285                                   Other               Fully Meets
# 286                      Website Banner Ads               Fully Meets
# 287                                MBTA ads               Fully Meets
# 288                  Pay Per Click - Google               Fully Meets
# 289  Social Networks - Facebook Twitter etc               Fully Meets
# 290                      Diversity Job Fair         Needs Improvement
# 291                         Vendor Referral               Fully Meets
# 292                  Pay Per Click - Google              90-day meets
# 293                             Monster.com              90-day meets
# 294                               Billboard         Needs Improvement
# 295       Search Engine - Google Bing Yahoo               Fully Meets
# 296                      Diversity Job Fair                   Exceeds
# 297                  Pay Per Click - Google               Fully Meets
# 298                                MBTA ads               Exceptional
# 299                      Diversity Job Fair               Fully Meets
# 300       Search Engine - Google Bing Yahoo               Fully Meets
# 301                                     NaN                       NaN
#
# [302 rows x 21 columns]

# %%
#hr_data.columns

# %% [markdown]
# <h4>Create Unique Values Dictionary</h4>

# %%
uniq = gen_uniq_dict(hr_data)

# %%
#uniq

# %% [markdown]
# <h4>Load Entities</h4>

# %%
ent_df = load_ent('HR Manager Schema - Entities.csv')
ent_dict = parse_clean_ent(ent_df, uniq)
ent_dict['name'][1] = name_syn_update(ent_dict)
uniq = uniq_dict_update(uniq, ent_dict)
ent_dict
# Out:
# {'name': [['William LaRotonda',
#    'Tyrone Steans',
#    'Estelle Howard',
#    'Leigh Smith',
#    'Brandon LeBlanc',
#    'Sean Quinn',
#    'Bonalyn Boutwell',
#    'Amy Foster-Baker',
#    'Janet King',
#    'Jennifer Zamora',
#    'Renee Becker',
#    'Taisha Goble',
#    'Daniff Hernandez',
#    'Jayne Horton',
#    'Noelle Johnson',
#    'Thomas Murray',
#    'Randall Pearson',
#    'Thelma Petrowsky',
#    'Lori Roby',
#    'Jason Salter',
#    'Kramer Simard',
#    'Simon Roup',
#    'Ricardo Ruiz',
#    'Peter Monroe',
#    'Eric Dougall',
#    'Rick Clayton',
#    'Lisa Galia',
#    'Leonara Lindsay',
#    'Alejandro Bacong',
#    'Anthony Cisco',
#    'Linda Dolan',
#    'Maria Gonzalez',
#    'Carlos Merlos',
#    'Tanya Morway',
#    'Anita Shepard',
#    'Neville Tredinnick',
#    'Jumil Turpin',
#    'Karthikeyan Ait Sidi',
#    'Claudia Carr',
#    'Donald Favis',
#    'Bianca Roehrich',
#    'Ann Daniele',
#    'Jyoti Lajiri',
#    'Jeremiah Semizoglou',
#    'Joe South',
#    'Sarah Warfield',
#    'Elisa Bramante',
#    'Michael Albert',
#    'Charles Bozzi',
#    'Webster Butler',
#    'Elijiah Gray',
#    'Jonathan Hogland',
#    'Walter Immediato',
#    'Ketsia Liebig',
#    'Brannon Miller',
#    'Ebonee Peterson',
#    'Kelley Spirea',
#    'David Stanley',
#    'Kissy Sullivan',
#    'Courtney Wallace',
#    'Wilson Adinolfi',
#    'Trina Alagbe',
#    'Carol Anderson',
#    'Sam Athwal',
#    'Rachael Baczenski',
#    'Francesco Barone',
#    'Nader Barton',
#    'Lowan Biden',
#    'Helen Billis',
#    'Donna Brill',
#    'Josephine Bugali',
#    'Beatrice Chace',
#    'Lin Chan',
#    'Donovan Chang',
#    'Enola Chivukula',
#    'Caroline Cierpiszewski',
#    'Elijian Clukey',
#    'James Cockel',
#    'Spencer Cole',
#    'Jean Crimmings',
#    "Jene'ya Darson",
#    'Carl Desimone',
#    'Geoff Dickinson',
#    'Lily DiNocco',
#    'Denisa Dobrin',
#    'Marianne Eaton',
#    'Rex England',
#    'Miguel Estremera',
#    'April Evensen',
#    'Susan Ferguson',
#    'Nilson Fernandes',
#    'Violeta Ferreira',
#    'Libby Fidelia',
#    'Raul Garcia',
#    'Hamish Garneau',
#    'Barbara Gaul',
#    'Mildred Gentry',
#    'Melisa Gerke',
#    'Alex Gilles',
#    'Evelyn Girifalco',
#    'Shenice Gold',
#    'Roxana Goyal',
#    'Paula Gross',
#    'Joanne Handschiegl',
#    'Ludwick Harrell',
#    'Christie Harrington',
#    'Kara Harrison',
#    'Rose Ivey',
#    'Maryellen Jackson',
#    'Hannah Jacobi',
#    'Sneha Jhaveri',
#    'Judy Jung',
#    'Kathleen Kinsella',
#    'Alexandra Kirill',
#    'Bradley Knapp',
#    'John Kretschmer',
#    'Enrico Langton',
#    'Dallas Leach',
#    'Marilyn Linares',
#    'Allison Lydon',
#    'Lindsay Lynch',
#    'Samuel MacLennan',
#    'Lauren Mahoney',
#    'Debbie Mangal',
#    'Shana Maurice',
#    'Sandy Mckenna',
#    'Elizabeth Meads',
#    'Dawn Motlagh',
#    'Colombui Ndzi',
#    'Richard Newman',
#    'Shari Ngodup',
#    'Lei-Ming Nguyen',
#    "Lynn O'hare",
#    'Adeel Osturnka',
#    'Clinton Owad',
#    'Nina Panjwani',
#    'Emil Pelech',
#    'Shakira Perry',
#    'Hong Pham',
#    'Brad Pitt',
#    'Morissa Power',
#    'Louis Punjabhi',
#    'Janine Purinton',
#    'Quinn Rarrick',
#    'Haley Rivera',
#    'Alain Robinson',
#    'Ashley Rose',
#    'Bruno Rossetti',
#    'Melinda Saar-Beckles',
#    'Nore Sadki',
#    'Kamrin Sander',
#    'Nori Sewkumar',
#    'Seffi Shields',
#    'Taylor Sparks',
#    'Kristen Squatrito',
#    'Desiree Tavares',
#    'Sophia Theamstern',
#    'Theresa Tinto',
#    'Jeanette Tippett',
#    'Mei Trang',
#    'Abdellah Veera',
#    'Colleen Volk',
#    'Anna Von Massenbach',
#    'Scott Whittier',
#    'Barry Wilber',
#    'Jacquelyn Williams',
#    'Catherine Ybarra',
#    'Kimberly Beak',
#    'Dianna Blount',
#    'Betsy Bondwell',
#    'Joseph Buccheri',
#    'Joelle Burke',
#    'Benjamin Burkett',
#    'Phil Close',
#    'Daniel Davis',
#    'Carla Demita',
#    'Angela Erilus',
#    'Megan Faller',
#    'Nicole Fancett',
#    'Phylicia Gosciminski',
#    'Earnest Hankard',
#    'Adrienne Homberger',
#    'Julissa Hunts',
#    'Rosalie Hutter',
#    'Ming Huynh',
#    'Tayana Jeannite',
#    'Yen Johnston',
#    'Lindsey Langford',
#    'Mohammed Latif',
#    'Mathew Linden',
#    'Robyn Manchester',
#    'Karen Mancuso',
#    'Brigit McCarthy',
#    'Erasumus Monkfish',
#    'Luisa Monterro',
#    'Patrick Moran',
#    'Maliki Moumanil',
#    'Kristie Nowlan',
#    'Brooke Oliver',
#    'Ermine Pelletier',
#    'May Roberson',
#    'Adil Sahoo',
#    'Constance Sloan',
#    'Lenora Tejeda',
#    'Kenneth Thibaud',
#    'Cybil Trzeciak',
#    'Roger Walker',
#    'Jordan Winthrop',
#    'Hang Wolk',
#    'Edward Buck',
#    'Jessica Bunbury',
#    'Michelle Carter',
#    'Latia Costa',
#    'Jenna Dietrich',
#    'Alfred Digitale',
#    'Maruk Fraval',
#    'Gerry Friedman',
#    'Whitney Gill',
#    'Myriam Givens',
#    'Mike Guilianno',
#    'Jeremy Prater',
#    'Bartholemew Khemmich',
#    'Giovanni Leruth',
#    'Jac McKinzie',
#    'Howard Mullaney',
#    'Jasmine Onque',
#    'Travis Ozark',
#    'Xana Potts',
#    'Caitrin Strong',
#    'Sharlene Terry',
#    'Jackie Valentin',
#    'Noah Villanueva',
#    'Debra Houlihan',
#    'Donysha Kampew',
#    'Colby Andreola',
#    'Judith Carabbio',
#    'Keyla Del Bosque',
#    'Sandra Martin',
#    'Luke Patronick',
#    'Adell Saada',
#    'Andrew Szabo',
#    'Mia Brown',
#    'Ivan Rogers',
#    'Julia Soto',
#    'Nan Singh'],
#   [['william larotonda', 'William', 'william', 'LaRotonda', 'larotonda'],
#    ['tyrone steans', 'Tyrone', 'tyrone', 'Steans', 'steans'],
#    ['estelle howard', 'Estelle', 'estelle', 'Howard', 'howard'],
#    ['leigh smith', 'Leigh', 'leigh', 'Smith', 'smith'],
#    ['brandon leblanc', 'Brandon', 'brandon', 'LeBlanc', 'leblanc'],
#    ['sean quinn', 'Sean', 'sean', 'Quinn', 'quinn'],
#    ['bonalyn boutwell', 'Bonalyn', 'bonalyn', 'Boutwell', 'boutwell'],
#    ['amy foster-baker', 'Amy', 'amy', 'Foster-Baker', 'foster-baker'],
#    ['janet king', 'Janet', 'janet', 'King', 'king'],
#    ['jennifer zamora', 'Jennifer', 'jennifer', 'Zamora', 'zamora'],
#    ['renee becker', 'Renee', 'renee', 'Becker', 'becker'],
#    ['taisha goble', 'Taisha', 'taisha', 'Goble', 'goble'],
#    ['daniff hernandez', 'Daniff', 'daniff', 'Hernandez', 'hernandez'],
#    ['jayne horton', 'Jayne', 'jayne', 'Horton', 'horton'],
#    ['noelle johnson', 'Noelle', 'noelle', 'Johnson', 'johnson'],
#    ['thomas murray', 'Thomas', 'thomas', 'Murray', 'murray'],
#    ['randall pearson', 'Randall', 'randall', 'Pearson', 'pearson'],
#    ['thelma petrowsky', 'Thelma', 'thelma', 'Petrowsky', 'petrowsky'],
#    ['lori roby', 'Lori', 'lori', 'Roby', 'roby'],
#    ['jason salter', 'Jason', 'jason', 'Salter', 'salter'],
#    ['kramer simard', 'Kramer', 'kramer', 'Simard', 'simard'],
#    ['simon roup', 'Simon', 'simon', 'Roup', 'roup'],
#    ['ricardo ruiz', 'Ricardo', 'ricardo', 'Ruiz', 'ruiz'],
#    ['peter monroe', 'Peter', 'peter', 'Monroe', 'monroe'],
#    ['eric dougall', 'Eric', 'eric', 'Dougall', 'dougall'],
#    ['rick clayton', 'Rick', 'rick', 'Clayton', 'clayton'],
#    ['lisa galia', 'Lisa', 'lisa', 'Galia', 'galia'],
#    ['leonara lindsay', 'Leonara', 'leonara', 'Lindsay', 'lindsay'],
#    ['alejandro bacong', 'Alejandro', 'alejandro', 'Bacong', 'bacong'],
#    ['anthony cisco', 'Anthony', 'anthony', 'Cisco', 'cisco'],
#    ['linda dolan', 'Linda', 'linda', 'Dolan', 'dolan'],
#    ['maria gonzalez', 'Maria', 'maria', 'Gonzalez', 'gonzalez'],
#    ['carlos merlos', 'Carlos', 'carlos', 'Merlos', 'merlos'],
#    ['tanya morway', 'Tanya', 'tanya', 'Morway', 'morway'],
#    ['anita shepard', 'Anita', 'anita', 'Shepard', 'shepard'],
#    ['neville tredinnick', 'Neville', 'neville', 'Tredinnick', 'tredinnick'],
#    ['jumil turpin', 'Jumil', 'jumil', 'Turpin', 'turpin'],
#    ['karthikeyan ait sidi', 'Karthikeyan', 'karthikeyan', 'Ait', 'ait'],
#    ['claudia carr', 'Claudia', 'claudia', 'Carr', 'carr'],
#    ['donald favis', 'Donald', 'donald', 'Favis', 'favis'],
#    ['bianca roehrich', 'Bianca', 'bianca', 'Roehrich', 'roehrich'],
#    ['ann daniele', 'Ann', 'ann', 'Daniele', 'daniele'],
#    ['jyoti lajiri', 'Jyoti', 'jyoti', 'Lajiri', 'lajiri'],
#    ['jeremiah semizoglou', 'Jeremiah', 'jeremiah', 'Semizoglou', 'semizoglou'],
#    ['joe south', 'Joe', 'joe', 'South', 'south'],
#    ['sarah warfield', 'Sarah', 'sarah', 'Warfield', 'warfield'],
#    ['elisa bramante', 'Elisa', 'elisa', 'Bramante', 'bramante'],
#    ['michael albert', 'Michael', 'michael', 'Albert', 'albert'],
#    ['charles bozzi', 'Charles', 'charles', 'Bozzi', 'bozzi'],
#    ['webster butler', 'Webster', 'webster', 'Butler', 'butler'],
#    ['elijiah gray', 'Elijiah', 'elijiah', 'Gray', 'gray'],
#    ['jonathan hogland', 'Jonathan', 'jonathan', 'Hogland', 'hogland'],
#    ['walter immediato', 'Walter', 'walter', 'Immediato', 'immediato'],
#    ['ketsia liebig', 'Ketsia', 'ketsia', 'Liebig', 'liebig'],
#    ['brannon miller', 'Brannon', 'brannon', 'Miller', 'miller'],
#    ['ebonee peterson', 'Ebonee', 'ebonee', 'Peterson', 'peterson'],
#    ['kelley spirea', 'Kelley', 'kelley', 'Spirea', 'spirea'],
#    ['david stanley', 'David', 'david', 'Stanley', 'stanley'],
#    ['kissy sullivan', 'Kissy', 'kissy', 'Sullivan', 'sullivan'],
#    ['courtney wallace', 'Courtney', 'courtney', 'Wallace', 'wallace'],
#    ['wilson adinolfi', 'Wilson', 'wilson', 'Adinolfi', 'adinolfi'],
#    ['trina alagbe', 'Trina', 'trina', 'Alagbe', 'alagbe'],
#    ['carol anderson', 'Carol', 'carol', 'Anderson', 'anderson'],
#    ['sam athwal', 'Sam', 'sam', 'Athwal', 'athwal'],
#    ['rachael baczenski', 'Rachael', 'rachael', 'Baczenski', 'baczenski'],
#    ['francesco barone', 'Francesco', 'francesco', 'Barone', 'barone'],
#    ['nader barton', 'Nader', 'nader', 'Barton', 'barton'],
#    ['lowan biden', 'Lowan', 'lowan', 'Biden', 'biden'],
#    ['helen billis', 'Helen', 'helen', 'Billis', 'billis'],
#    ['donna brill', 'Donna', 'donna', 'Brill', 'brill'],
#    ['josephine bugali', 'Josephine', 'josephine', 'Bugali', 'bugali'],
#    ['beatrice chace', 'Beatrice', 'beatrice', 'Chace', 'chace'],
#    ['lin chan', 'Lin', 'lin', 'Chan', 'chan'],
#    ['donovan chang', 'Donovan', 'donovan', 'Chang', 'chang'],
#    ['enola chivukula', 'Enola', 'enola', 'Chivukula', 'chivukula'],
#    ['caroline cierpiszewski',
#     'Caroline',
#     'caroline',
#     'Cierpiszewski',
#     'cierpiszewski'],
#    ['elijian clukey', 'Elijian', 'elijian', 'Clukey', 'clukey'],
#    ['james cockel', 'James', 'james', 'Cockel', 'cockel'],
#    ['spencer cole', 'Spencer', 'spencer', 'Cole', 'cole'],
#    ['jean crimmings', 'Jean', 'jean', 'Crimmings', 'crimmings'],
#    ["jene'ya darson", "Jene'ya", "jene'ya", 'Darson', 'darson'],
#    ['carl desimone', 'Carl', 'carl', 'Desimone', 'desimone'],
#    ['geoff dickinson', 'Geoff', 'geoff', 'Dickinson', 'dickinson'],
#    ['lily dinocco', 'Lily', 'lily', 'DiNocco', 'dinocco'],
#    ['denisa dobrin', 'Denisa', 'denisa', 'Dobrin', 'dobrin'],
#    ['marianne eaton', 'Marianne', 'marianne', 'Eaton', 'eaton'],
#    ['rex england', 'Rex', 'rex', 'England', 'england'],
#    ['miguel estremera', 'Miguel', 'miguel', 'Estremera', 'estremera'],
#    ['april evensen', 'April', 'april', 'Evensen', 'evensen'],
#    ['susan ferguson', 'Susan', 'susan', 'Ferguson', 'ferguson'],
#    ['nilson fernandes', 'Nilson', 'nilson', 'Fernandes', 'fernandes'],
#    ['violeta ferreira', 'Violeta', 'violeta', 'Ferreira', 'ferreira'],
#    ['libby fidelia', 'Libby', 'libby', 'Fidelia', 'fidelia'],
#    ['raul garcia', 'Raul', 'raul', 'Garcia', 'garcia'],
#    ['hamish garneau', 'Hamish', 'hamish', 'Garneau', 'garneau'],
#    ['barbara gaul', 'Barbara', 'barbara', 'Gaul', 'gaul'],
#    ['mildred gentry', 'Mildred', 'mildred', 'Gentry', 'gentry'],
#    ['melisa gerke', 'Melisa', 'melisa', 'Gerke', 'gerke'],
#    ['alex gilles', 'Alex', 'alex', 'Gilles', 'gilles'],
#    ['evelyn girifalco', 'Evelyn', 'evelyn', 'Girifalco', 'girifalco'],
#    ['shenice gold', 'Shenice', 'shenice', 'Gold', 'gold'],
#    ['roxana goyal', 'Roxana', 'roxana', 'Goyal', 'goyal'],
#    ['paula gross', 'Paula', 'paula', 'Gross', 'gross'],
#    ['joanne handschiegl', 'Joanne', 'joanne', 'Handschiegl', 'handschiegl'],
#    ['ludwick harrell', 'Ludwick', 'ludwick', 'Harrell', 'harrell'],
#    ['christie harrington', 'Christie', 'christie', 'Harrington', 'harrington'],
#    ['kara harrison', 'Kara', 'kara', 'Harrison', 'harrison'],
#    ['rose ivey', 'Rose', 'rose', 'Ivey', 'ivey'],
#    ['maryellen jackson', 'Maryellen', 'maryellen', 'Jackson', 'jackson'],
#    ['hannah jacobi', 'Hannah', 'hannah', 'Jacobi', 'jacobi'],
#    ['sneha jhaveri', 'Sneha', 'sneha', 'Jhaveri', 'jhaveri'],
#    ['judy jung', 'Judy', 'judy', 'Jung', 'jung'],
#    ['kathleen kinsella', 'Kathleen', 'kathleen', 'Kinsella', 'kinsella'],
#    ['alexandra kirill', 'Alexandra', 'alexandra', 'Kirill', 'kirill'],
#    ['bradley knapp', 'Bradley', 'bradley', 'Knapp', 'knapp'],
#    ['john kretschmer', 'John', 'john', 'Kretschmer', 'kretschmer'],
#    ['enrico langton', 'Enrico', 'enrico', 'Langton', 'langton'],
#    ['dallas leach', 'Dallas', 'dallas', 'Leach', 'leach'],
#    ['marilyn linares', 'Marilyn', 'marilyn', 'Linares', 'linares'],
#    ['allison lydon', 'Allison', 'allison', 'Lydon', 'lydon'],
#    ['lindsay lynch', 'Lindsay', 'lindsay', 'Lynch', 'lynch'],
#    ['samuel maclennan', 'Samuel', 'samuel', 'MacLennan', 'maclennan'],
#    ['lauren mahoney', 'Lauren', 'lauren', 'Mahoney', 'mahoney'],
#    ['debbie mangal', 'Debbie', 'debbie', 'Mangal', 'mangal'],
#    ['shana maurice', 'Shana', 'shana', 'Maurice', 'maurice'],
#    ['sandy mckenna', 'Sandy', 'sandy', 'Mckenna', 'mckenna'],
#    ['elizabeth meads', 'Elizabeth', 'elizabeth', 'Meads', 'meads'],
#    ['dawn motlagh', 'Dawn', 'dawn', 'Motlagh', 'motlagh'],
#    ['colombui ndzi', 'Colombui', 'colombui', 'Ndzi', 'ndzi'],
#    ['richard newman', 'Richard', 'richard', 'Newman', 'newman'],
#    ['shari ngodup', 'Shari', 'shari', 'Ngodup', 'ngodup'],
#    ['lei-ming nguyen', 'Lei-Ming', 'lei-ming', 'Nguyen', 'nguyen'],
#    ["lynn o'hare", 'Lynn', 'lynn', "O'hare", "o'hare"],
#    ['adeel osturnka', 'Adeel', 'adeel', 'Osturnka', 'osturnka'],
#    ['clinton owad', 'Clinton', 'clinton', 'Owad', 'owad'],
#    ['nina panjwani', 'Nina', 'nina', 'Panjwani', 'panjwani'],
#    ['emil pelech', 'Emil', 'emil', 'Pelech', 'pelech'],
#    ['shakira perry', 'Shakira', 'shakira', 'Perry', 'perry'],
#    ['hong pham', 'Hong', 'hong', 'Pham', 'pham'],
#    ['brad pitt', 'Brad', 'brad', 'Pitt', 'pitt'],
#    ['morissa power', 'Morissa', 'morissa', 'Power', 'power'],
#    ['louis punjabhi', 'Louis', 'louis', 'Punjabhi', 'punjabhi'],
#    ['janine purinton', 'Janine', 'janine', 'Purinton', 'purinton'],
#    ['quinn rarrick', 'Quinn', 'quinn', 'Rarrick', 'rarrick'],
#    ['haley rivera', 'Haley', 'haley', 'Rivera', 'rivera'],
#    ['alain robinson', 'Alain', 'alain', 'Robinson', 'robinson'],
#    ['ashley rose', 'Ashley', 'ashley', 'Rose', 'rose'],
#    ['bruno rossetti', 'Bruno', 'bruno', 'Rossetti', 'rossetti'],
#    ['melinda saar-beckles',
#     'Melinda',
#     'melinda',
#     'Saar-Beckles',
#     'saar-beckles'],
#    ['nore sadki', 'Nore', 'nore', 'Sadki', 'sadki'],
#    ['kamrin sander', 'Kamrin', 'kamrin', 'Sander', 'sander'],
#    ['nori sewkumar', 'Nori', 'nori', 'Sewkumar', 'sewkumar'],
#    ['seffi shields', 'Seffi', 'seffi', 'Shields', 'shields'],
#    ['taylor sparks', 'Taylor', 'taylor', 'Sparks', 'sparks'],
#    ['kristen squatrito', 'Kristen', 'kristen', 'Squatrito', 'squatrito'],
#    ['desiree tavares', 'Desiree', 'desiree', 'Tavares', 'tavares'],
#    ['sophia theamstern', 'Sophia', 'sophia', 'Theamstern', 'theamstern'],
#    ['theresa tinto', 'Theresa', 'theresa', 'Tinto', 'tinto'],
#    ['jeanette tippett', 'Jeanette', 'jeanette', 'Tippett', 'tippett'],
#    ['mei trang', 'Mei', 'mei', 'Trang', 'trang'],
#    ['abdellah veera', 'Abdellah', 'abdellah', 'Veera', 'veera'],
#    ['colleen volk', 'Colleen', 'colleen', 'Volk', 'volk'],
#    ['anna von massenbach', 'Anna', 'anna', 'Von', 'von'],
#    ['scott whittier', 'Scott', 'scott', 'Whittier', 'whittier'],
#    ['barry wilber', 'Barry', 'barry', 'Wilber', 'wilber'],
#    ['jacquelyn williams', 'Jacquelyn', 'jacquelyn', 'Williams', 'williams'],
#    ['catherine ybarra', 'Catherine', 'catherine', 'Ybarra', 'ybarra'],
#    ['kimberly beak', 'Kimberly', 'kimberly', 'Beak', 'beak'],
#    ['dianna blount', 'Dianna', 'dianna', 'Blount', 'blount'],
#    ['betsy bondwell', 'Betsy', 'betsy', 'Bondwell', 'bondwell'],
#    ['joseph buccheri', 'Joseph', 'joseph', 'Buccheri', 'buccheri'],
#    ['joelle burke', 'Joelle', 'joelle', 'Burke', 'burke'],
#    ['benjamin burkett', 'Benjamin', 'benjamin', 'Burkett', 'burkett'],
#    ['phil close', 'Phil', 'phil', 'Close', 'close'],
#    ['daniel davis', 'Daniel', 'daniel', 'Davis', 'davis'],
#    ['carla demita', 'Carla', 'carla', 'Demita', 'demita'],
#    ['angela erilus', 'Angela', 'angela', 'Erilus', 'erilus'],
#    ['megan faller', 'Megan', 'megan', 'Faller', 'faller'],
#    ['nicole fancett', 'Nicole', 'nicole', 'Fancett', 'fancett'],
#    ['phylicia gosciminski',
#     'Phylicia',
#     'phylicia',
#     'Gosciminski',
#     'gosciminski'],
#    ['earnest hankard', 'Earnest', 'earnest', 'Hankard', 'hankard'],
#    ['adrienne homberger', 'Adrienne', 'adrienne', 'Homberger', 'homberger'],
#    ['julissa hunts', 'Julissa', 'julissa', 'Hunts', 'hunts'],
#    ['rosalie hutter', 'Rosalie', 'rosalie', 'Hutter', 'hutter'],
#    ['ming huynh', 'Ming', 'ming', 'Huynh', 'huynh'],
#    ['tayana jeannite', 'Tayana', 'tayana', 'Jeannite', 'jeannite'],
#    ['yen johnston', 'Yen', 'yen', 'Johnston', 'johnston'],
#    ['lindsey langford', 'Lindsey', 'lindsey', 'Langford', 'langford'],
#    ['mohammed latif', 'Mohammed', 'mohammed', 'Latif', 'latif'],
#    ['mathew linden', 'Mathew', 'mathew', 'Linden', 'linden'],
#    ['robyn manchester', 'Robyn', 'robyn', 'Manchester', 'manchester'],
#    ['karen mancuso', 'Karen', 'karen', 'Mancuso', 'mancuso'],
#    ['brigit mccarthy', 'Brigit', 'brigit', 'McCarthy', 'mccarthy'],
#    ['erasumus monkfish', 'Erasumus', 'erasumus', 'Monkfish', 'monkfish'],
#    ['luisa monterro', 'Luisa', 'luisa', 'Monterro', 'monterro'],
#    ['patrick moran', 'Patrick', 'patrick', 'Moran', 'moran'],
#    ['maliki moumanil', 'Maliki', 'maliki', 'Moumanil', 'moumanil'],
#    ['kristie nowlan', 'Kristie', 'kristie', 'Nowlan', 'nowlan'],
#    ['brooke oliver', 'Brooke', 'brooke', 'Oliver', 'oliver'],
#    ['ermine pelletier', 'Ermine', 'ermine', 'Pelletier', 'pelletier'],
#    ['may roberson', 'May', 'may', 'Roberson', 'roberson'],
#    ['adil sahoo', 'Adil', 'adil', 'Sahoo', 'sahoo'],
#    ['constance sloan', 'Constance', 'constance', 'Sloan', 'sloan'],
#    ['lenora tejeda', 'Lenora', 'lenora', 'Tejeda', 'tejeda'],
#    ['kenneth thibaud', 'Kenneth', 'kenneth', 'Thibaud', 'thibaud'],
#    ['cybil trzeciak', 'Cybil', 'cybil', 'Trzeciak', 'trzeciak'],
#    ['roger walker', 'Roger', 'roger', 'Walker', 'walker'],
#    ['jordan winthrop', 'Jordan', 'jordan', 'Winthrop', 'winthrop'],
#    ['hang wolk', 'Hang', 'hang', 'Wolk', 'wolk'],
#    ['edward buck', 'Edward', 'edward', 'Buck', 'buck'],
#    ['jessica bunbury', 'Jessica', 'jessica', 'Bunbury', 'bunbury'],
#    ['michelle carter', 'Michelle', 'michelle', 'Carter', 'carter'],
#    ['latia costa', 'Latia', 'latia', 'Costa', 'costa'],
#    ['jenna dietrich', 'Jenna', 'jenna', 'Dietrich', 'dietrich'],
#    ['alfred digitale', 'Alfred', 'alfred', 'Digitale', 'digitale'],
#    ['maruk fraval', 'Maruk', 'maruk', 'Fraval', 'fraval'],
#    ['gerry friedman', 'Gerry', 'gerry', 'Friedman', 'friedman'],
#    ['whitney gill', 'Whitney', 'whitney', 'Gill', 'gill'],
#    ['myriam givens', 'Myriam', 'myriam', 'Givens', 'givens'],
#    ['mike guilianno', 'Mike', 'mike', 'Guilianno', 'guilianno'],
#    ['jeremy prater', 'Jeremy', 'jeremy', 'Prater', 'prater'],
#    ['bartholemew khemmich',
#     'Bartholemew',
#     'bartholemew',
#     'Khemmich',
#     'khemmich'],
#    ['giovanni leruth', 'Giovanni', 'giovanni', 'Leruth', 'leruth'],
#    ['jac mckinzie', 'Jac', 'jac', 'McKinzie', 'mckinzie'],
#    ['howard mullaney', 'Howard', 'howard', 'Mullaney', 'mullaney'],
#    ['jasmine onque', 'Jasmine', 'jasmine', 'Onque', 'onque'],
#    ['travis ozark', 'Travis', 'travis', 'Ozark', 'ozark'],
#    ['xana potts', 'Xana', 'xana', 'Potts', 'potts'],
#    ['caitrin strong', 'Caitrin', 'caitrin', 'Strong', 'strong'],
#    ['sharlene terry', 'Sharlene', 'sharlene', 'Terry', 'terry'],
#    ['jackie valentin', 'Jackie', 'jackie', 'Valentin', 'valentin'],
#    ['noah villanueva', 'Noah', 'noah', 'Villanueva', 'villanueva'],
#    ['debra houlihan', 'Debra', 'debra', 'Houlihan', 'houlihan'],
#    ['donysha kampew', 'Donysha', 'donysha', 'Kampew', 'kampew'],
#    ['colby andreola', 'Colby', 'colby', 'Andreola', 'andreola'],
#    ['judith carabbio', 'Judith', 'judith', 'Carabbio', 'carabbio'],
#    ['keyla del bosque', 'Keyla', 'keyla', 'Del', 'del'],
#    ['sandra martin', 'Sandra', 'sandra', 'Martin', 'martin'],
#    ['luke patronick', 'Luke', 'luke', 'Patronick', 'patronick'],
#    ['adell saada', 'Adell', 'adell', 'Saada', 'saada'],
#    ['andrew szabo', 'Andrew', 'andrew', 'Szabo', 'szabo'],
#    ['mia brown', 'Mia', 'mia', 'Brown', 'brown'],
#    ['ivan rogers', 'Ivan', 'ivan', 'Rogers', 'rogers'],
#    ['julia soto', 'Julia', 'julia', 'Soto', 'soto'],
#    ['nan singh', 'Nan', 'nan', 'Singh', 'singh']],
#   []],
#  'state': [array(['MA', 'TX', 'CT', 'VA', 'VT', 'CA', 'WA', 'NH', 'NY', 'OH', 'IN',
#          'ID', 'TN', 'NV', 'CO', 'UT', 'AL', 'GA', 'FL', 'NC', 'KY', 'ND',
#          'MT', 'OR', 'AZ', 'ME', 'RI', 'PA'], dtype=object),
#   [['Massachussets'],
#    ['Texas'],
#    ['Connecticut'],
#    ['Virginia'],
#    ['Vermony'],
#    ['California'],
#    ['Washington'],
#    ['New Hampshire'],
#    ['New York'],
#    ['Ohio'],
#    ['Indiana'],
#    ['Idaho'],
#    ['Tennessee'],
#    ['Nevada'],
#    ['Colarado'],
#    ['Utah'],
#    ['Alabama'],
#    ['Georgia'],
#    ['Florida'],
#    ['North Carolina'],
#    ['Kentucky'],
#    ['North Dakota'],
#    ['Montana'],
#    ['Oregon'],
#    ['Arizona'],
#    ['Maine'],
#    ['Rhode Island'],
#    ['Pennsylvania']],
#   ['state',
#    'state of birth',
#    'state of residence',
#    'office location',
#    'location',
#    'out of state',
#    'live',
#    'lives',
#    'live in',
#    'based in',
#    'lives in',
#    'where',
#    'works in',
#    'works at',
#    'where is',
#    'cali']],
#  'age': [['32',
#    '33',
#    '31',
#    '29',
#    '30',
#    '38',
#    '63',
#    '46',
#    '36',
#    '47',
#    '37',
#    '44',
#    '54',
#    '49',
#    '28',
#    '48',
#    '42',
#    '53',
#    '66',
#    '34',
#    '52',
#    '39',
#    '45',
#    '41',
#    '40',
#    '62',
#    '43',
#    '59',
#    '27',
#    '67',
#    '50',
#    '35',
#    '26',
#    '25',
#    '65',
#    '51',
#    '58',
#    '56',
#    '64'],
#   [['old', 'years old', 'age of', 'ages of']],
#   ['age']],
#  'sex': [['male', 'female'],
#   [['men', 'males', 'guys', 'dudes', 'gents', 'gentlemen', 'boys', 'boy'],
#    ['women',
#     'females',
#     'ladies',
#     'lady',
#     'ladys',
#     'girls',
#     'gals',
#     'woman',
#     'girl']],
#   ['sex',
#    'gender',
#    'masculine',
#    'feminine',
#    'male person',
#    'm/f',
#    'male/female',
#    'M/F',
#    'Male/Female']],
#  'maritaldesc': [['married', 'divorced', 'single', 'separated', 'widowed'],
#   [['wed',
#     'legally married',
#     'espoused',
#     'joined in holy matrimony',
#     'hitched'],
#    nan,
#    ['unmarried', 'bachelor', 'bachelorette'],
#    nan,
#    nan],
#   ['husbandless',
#    'without a partner',
#    'unwedded',
#    'wifeless',
#    'no longer married',
#    'without a husband',
#    'without a wife',
#    'maritaldesc',
#    'marital status',
#    'spouse',
#    'husband',
#    'wife']],
#  'citizendesc': [['us citizen', 'eligible noncitizen', 'non-citizen'],
#   [['citizen',
#     'usa citizen',
#     'american citizen',
#     'citizen of the us',
#     'citizen of America',
#     'citizen of the usa',
#     'citizens'],
#    ['non citizen', 'not a citizen', 'non us citizen', 'not citizens'],
#    ['non citizen', 'not a citizen', 'non us citizen', 'not citizens']],
#   ['immigrant',
#    'illegal immigrant',
#    'h1 visa',
#    'foreigner',
#    'foreign',
#    'imported',
#    'out of country',
#    'from abroad',
#    'citizenship status',
#    'citizenship']],
#  'racedesc': [['black or african american',
#    'asian',
#    'two or more races',
#    'white',
#    'hispanic',
#    'american indian or alaska native'],
#   [['black', 'african american', 'african-american'],
#    ['from asia'],
#    ['multiracial',
#     'multi-racial',
#     'mixed',
#     'mixed race',
#     'biracial',
#     'interracial'],
#    ['caucasian'],
#    ['latino'],
#    ['native',
#     'natives',
#     'indians',
#     'indian',
#     'american indian',
#     'alaska native']],
#   ['ethnicity',
#    'race',
#    'racial background',
#    'ethnic group',
#    'ethnic type',
#    'racial indentity',
#    'community',
#    'minorities']],
#  'reason_for_termination': [['return to school',
#    'another position',
#    'unhappy',
#    'military',
#    'gross misconduct',
#    'hours',
#    'medical issues',
#    'relocation out of area',
#    'more money',
#    'career change',
#    'n/a - has not started yet',
#    'retiring',
#    'n/a - still employed',
#    'attendance',
#    'no-call no-show',
#    'maternity leave - did not return',
#    'performance'],
#   [['went back to school',
#     'had to go to school again',
#     'needed to go back to school',
#     'went back to college'],
#    ['took on another job',
#     'landed a new position',
#     'changed positions',
#     'got a new position',
#     'found a new position'],
#    ["wasn't happy",
#     "didn't like his job",
#     "didn't like her job",
#     'hated the job',
#     'disliked the job',
#     "didn't enjoy the job",
#     "didn't like his work",
#     "didn't like her work"],
#    ['joined the military',
#     'went to the military',
#     'left for the military',
#     'enlisted in the military',
#     'was drafted into the military'],
#    nan,
#    nan,
#    ['got sick', 'fell sick', 'medical problems', 'sick'],
#    ['was relocated',
#     'had to relocated',
#     'was assigned to a new location',
#     'was assigned to a different location'],
#    nan,
#    ['changed careers'],
#    nan,
#    ['retired', 'went into retirement'],
#    nan,
#    ['poor attendance', 'bad attendance'],
#    nan,
#    ['did not come back from maternity leave', 'had a kid and dissapeared'],
#    ['poor performance', 'performed below expectations']],
#   []],
#  'employment_status': [['terminated for cause',
#    'leave of absence',
#    'active',
#    'voluntarily terminated',
#    'future start'],
#   [['fired', 'let go', 'evicted', 'kicked out', 'removed', 'dismissed'],
#    ['on absence leave'],
#    ['currently employed',
#     'currently working',
#     'currently works',
#     'still works at',
#     'still working at',
#     'still work at',
#     'actively employed'],
#    ['quit', 'quitted', 'resigned', 'sent in a resignation'],
#    ['will start at a future time',
#     'will start later',
#     'will start some time in the future']],
#   ['renounce', 'employment status', 'current job status']],
#  'department': [['executive office',
#    'admin offices',
#    'production',
#    'it/is',
#    'software engineering',
#    'sales'],
#   [nan,
#    ['administration',
#     'office of admin',
#     'office of administration',
#     'admin office',
#     'administration office'],
#    nan,
#    ['IT',
#     'IS',
#     'Information Technology',
#     'Information Systems',
#     'Info Tech',
#     'Info Sys'],
#    ['programming', 'coding', 'software development'],
#    nan],
#   ['department',
#    'team',
#    'group',
#    'section',
#    'division',
#    'sector',
#    'office',
#    'office group',
#    'dpt',
#    'dept',
#    'dept.',
#    'branch']],
#  'position': [['it manager - infra',
#    'cio',
#    'sales manager',
#    'president & ceo',
#    'administrative assistant',
#    'database administrator',
#    'area sales manager',
#    'it director',
#    'sr. accountant',
#    'it manager - support',
#    'production technician ii',
#    'network engineer',
#    'sr. network engineer',
#    'shared services manager',
#    'accountant i',
#    'it support',
#    'software engineering manager',
#    'production technician i',
#    'director of operations',
#    'director of sales',
#    'sr. dba',
#    'it manager - db',
#    'software engineer',
#    'production manager'],
#   [nan,
#    ['chief information officer'],
#    nan,
#    ['chief executive officer', 'ceo', 'prez', 'president', 'executive', 'e'],
#    nan,
#    ['db admin', 'db administrator', 'database admin'],
#    nan,
#    ['director of it'],
#    ['senior accountant'],
#    nan,
#    ['production technician 2', 'production technician two'],
#    nan,
#    ['senior network engineer'],
#    nan,
#    ['accountant 1', 'accountant one'],
#    ['tech support'],
#    nan,
#    ['production technician 1', 'production technician one'],
#    ['operations director'],
#    ['sales director'],
#    ['senior database administrator',
#     'senior db admin',
#     'senior db administrator'],
#    nan,
#    ['software developer', 'programmer'],
#    nan],
#   ['title',
#    'job title',
#    'role',
#    'position',
#    'level in the organization',
#    'level',
#    'job',
#    'occupation']],
#  'manager': [['manager'],
#   [['manager name',
#     'manager',
#     'incharge',
#     'supervisor',
#     'mentor',
#     'leadership',
#     'boss',
#     'management',
#     'head',
#     'lead',
#     'chairman',
#     'working for',
#     'works for',
#     'work for',
#     'manage',
#     'managed by',
#     'managing',
#     'manages',
#     'reports to',
#     'report to',
#     'reporting to',
#     'reporting',
#     'working under',
#     'is under',
#     'leads']],
#   []],
#  'employee_source': [['information session',
#    'company intranet - partner',
#    'social networks - facebook twitter etc',
#    'newspager/magazine',
#    'internet search',
#    'billboard',
#    'pay per click',
#    'on-line web application',
#    'glassdoor',
#    'professional society',
#    'monster.com',
#    'diversity job fair',
#    'careerbuilder',
#    'mbta ads',
#    'word of mouth',
#    'other',
#    'vendor referral',
#    'on-campus recruiting',
#    'website banner ads',
#    'employee referral'],
#   [['info session'],
#    nan,
#    ['social media',
#     'social media apps',
#     'facebook',
#     'instagram',
#     'twitter',
#     'snapchat',
#     'social network'],
#    ['newspaper', 'magazine'],
#    ['google',
#     'bing',
#     'yahoo',
#     "search engine - google bing yahoo'",
#     'search engine'],
#    ['poster'],
#    ['ppc', 'google ads', 'google ppc', 'ppc google'],
#    ['application potal', 'job portal'],
#    ['glass door'],
#    ['professional group'],
#    ['monster'],
#    nan,
#    nan,
#    ['advertisement', 'ads'],
#    ['verbal mention'],
#    nan,
#    ['referred by vendor', 'vendor referred'],
#    ['on-campus job fair', 'career fair'],
#    nan,
#    ['referred by employee']],
#   ['how did you learn about this position',
#    'how did you find out about this job',
#    'how did you find out about this position',
#    'how did you learn about this job. how did you hear about this',
#    'heard about us',
#    'hear about us',
#    'how you heard about us',
#    'how did you hear of us',
#    'hear of us']],
#  'performance_score': [['exceptional',
#    'fully meets',
#    'n/a- too early to review',
#    'pip',
#    'needs improvement',
#    'exceeds',
#    '90-day meets'],
#   [['extraordinary'],
#    ['up to the mark', 'meet expectations', 'meet', 'meets'],
#    nan,
#    nan,
#    ['performing badly',
#     'performing below expectations',
#     'not meeting standards',
#     'not meeting expectations',
#     'poor performance',
#     'performing poorly',
#     'poorly performing',
#     'does not meet',
#     'do not meet'],
#    ['beyond expectations',
#     'more than expected',
#     'better than expected',
#     'higher than excpected',
#     'exceed expectations'],
#    nan],
#   ['performance rating',
#    'performance score',
#    'performance evaluation',
#    'performance eval',
#    'evalation',
#    'eval',
#    'performance evaluation history',
#    'performance eval history',
#    'performance',
#    'performance history',
#    'how well']],
#  'money': [['pay rate'],
#   [['salary',
#     'income',
#     'pay',
#     'earn',
#     'earnings',
#     'make',
#     'dollars',
#     '$',
#     'paycheck',
#     'earns',
#     'earning',
#     'earners',
#     'earner',
#     'incomes',
#     'paycheck',
#     'compensation']],
#   ['earns', 'makes', 'amount']],
#  'comparator': [['more than', 'equals to', 'less than', 'between'],
#   [['greater than', 'higher than', 'longer', 'over', 'older than'],
#    ['is exactly', 'is equal to', 'equates to', 'equal to'],
#    ['lower than', 'below', 'under', 'fewer than', 'younger than'],
#    ['between', 'in between']],
#   []],
#  'dob': [['dob'],
#   [['birthday',
#     'birthdate',
#     'birth date',
#     'date of birth',
#     'day of birth',
#     'born on',
#     'born on the',
#     'born in',
#     'born after',
#     'born before',
#     'DOB']],
#   []],
#  'time_interval': [['2000s',
#    '2010s',
#    '1920s',
#    '1930s',
#    '1940s',
#    '1950s',
#    '1960s',
#    '1970s',
#    '1980s',
#    '1990s'],
#   [["00's", "2000's", 'two thousands'],
#    ["10's", 'two thousand tens', 'tens', "2010's"],
#    ["20's", 'nineteen twenties', 'twenties', "1920's"],
#    ["30's", 'nineteen thirties', 'thirties', "1930's"],
#    ["40's", 'nineteen forties', 'forties', "1940's"],
#    ["50's", 'nineteen fifties', 'fifties', "1950's"],
#    ["60's", 'nineteen sixties', 'sixties', "1960's"],
#    ["70's", 'nineteen seventies', 'seventies', "1970's"],
#    ["80's", 'nineteen eighties', 'eighties', "1980's"],
#    ["90's", 'nineteen nineties', 'nineties', "1990's"]],
#   []],
#  'time_recur': [['yearly', 'monthly', 'weekly', 'daily', 'hourly'],
#   [['by the year',
#     'every year',
#     'each year',
#     'annually',
#     'on a yearly basis',
#     'per year',
#     'annual',
#     'in a year',
#     'in the year'],
#    ['by the month',
#     'every month',
#     'each month',
#     'month to month',
#     'month-to-month',
#     'on a monthly basis',
#     'per month',
#     'in a month',
#     'in the month'],
#    ['by the week',
#     'every week',
#     'each week',
#     'week by week',
#     'on a weekly basis',
#     'per week',
#     'in a week',
#     'in the week'],
#    ['daily',
#     'every day',
#     'day by day',
#     'each day',
#     'on a daily basis',
#     'per day',
#     'in a day',
#     'in the day'],
#    ['every hour',
#     'each hour',
#     'on an hourly basis',
#     'on the hour',
#     'per hour',
#     'in an hour',
#     'in  a hour',
#     'hour',
#     'in the hour']],
#   []],
#  'function': [['percent', 'sum', 'average', 'count'],
#   [['fraction',
#     'portion',
#     'proportion',
#     'percentage',
#     '%',
#     'ratio',
#     'ratios',
#     'pct'],
#    ['total',
#     'cumulative',
#     'added up',
#     'summed up',
#     'totalled',
#     'summed',
#     'combined',
#     'aggregate'],
#    ['mean', 'typical', 'typically', 'median', 'avg', 'range'],
#    ['how many', 'total number', 'number of', 'num of. headcount']],
#   ['distribution', 'turn over rate', 'pct']],
#  'extreme': [['highest', 'lowest'],
#   [['top', 'maximum', 'most', 'greatest', 'max', 'oldest', 'eldest'],
#    ['least', 'minimum', 'bottom', 'lowest', 'min', 'youngest']],
#   []],
#  'employment_action': [['hired', 'fired'],
#   [['employed',
#     'recruited',
#     'start date',
#     'date of starting employment',
#     'hiring date',
#     'date of hire',
#     'join',
#     'joined',
#     'date of hiring',
#     'began her employment',
#     'began his employment',
#     'started working',
#     'join date',
#     'worked here',
#     'started',
#     'been with us',
#     'began working for',
#     'started her experience',
#     'started his experience'],
#    ['terminated',
#     'let go',
#     'end date',
#     'date of leaving job',
#     'date of ending employment',
#     'date of termination',
#     'firing date',
#     'end employment',
#     'end his employment',
#     'end her employment']],
#   ['been with the company',
#    'been here',
#    'long has worked here',
#    'been working here',
#    'years of experience',
#    'of experience',
#    'employees that have been here',
#    'working here for']],
#  'date_compare': [['prev', 'post'],
#   [['before', 'pre', 'prior to'],
#    ['after',
#     'last',
#     'post',
#     'this year',
#     'this month',
#     'this week',
#     'atleast',
#     'since']],
#   []]}

# %%
ent_dict['name'][1][240]
# Out:
# ['andrew szabo', 'Andrew', 'andrew', 'Szabo', 'szabo']

# %% [markdown]
# <h4>Labelling Check</h4>

# %%
intent_txt = pd.read_csv('HR Manager Schema - intent_master.csv')
intent_txt = intent_txt.iloc[2:, :]
intent_txt
# Out:
#                                               get_info  \
# 2        what is {Phylicia Gosciminski|name}s org role
# 3                     What position is {ivan|name} in?
# 4    Why did {Megan|name} get {fired|employment_act...
# 5    Which department is {adrienne homberger|name} in?
# 6    is {abdellah veera|name} a {cio|position} or not?
# 7        Is {Mohammed Latif|name} a citizen of the us?
# 8                  Where does {ivan rogers|name} live?
# 9                 I want {sarah warfield|name}'s state
# 10      how did {dawn|name} hear about our corporation
# 11   Does {Michael|name} {still work at|employment_...
# 12   is {Ivan Rogers|name} {currently active|employ...
# 13   Is the {software engineering|department} the d...
# 14                    {Adell Saada|name}'s occupation?
# 15    what's {Shakira|name}'s role at the organization
# 16                        What is {Julia|name}'s race?
# 17            how did {Ivan Rogers|name} hear about us
# 18                what is {thomas murray|name}'s race?
# 19   tell me what is {nan singh|name}'s citizenship...
# 20   which branch is the one that {Brannon Miller|n...
# 21              What does {sophia theamstern|name} do?
# 22   tell me, is {Julissa Hunts|name} a {widowed|ma...
# 23     is Mr.{julia soto|name} based in {Oregon|state}
# 24   what {department|department} does {nan singh|n...
# 25   how {old|age} is {Michael|name} and is he a bo...
# 26              whats {Daniff HerIvandez|name}'s race?
# 27   What is {Hakim|name}'s level in the organization?
# 28   the reason for {paula gross|name}'s sudden {en...
# 29   how {old|age} is {hogland|name} and is he a {b...
# 30       Is {28|age} the age of {lauren mahoney|name}?
# 31               What is Mrs.{Nowlan|name}'s position?
# ..                                                 ...
# 271                                                NaN
# 272                                                NaN
# 273                                                NaN
# 274                                                NaN
# 275                                                NaN
# 276                                                NaN
# 277                                                NaN
# 278                                                NaN
# 279                                                NaN
# 280                                                NaN
# 281                                                NaN
# 282                                                NaN
# 283                                                NaN
# 284                                                NaN
# 285                                                NaN
# 286                                                NaN
# 287                                                NaN
# 288                                                NaN
# 289                                                NaN
# 290                                                NaN
# 291                                                NaN
# 292                                                NaN
# 293                                                NaN
# 294                                                NaN
# 295                                                NaN
# 296                                                NaN
# 297                                                NaN
# 298                                                NaN
# 299                                                NaN
# 300                                                NaN
#
#                                          get_aggregate  \
# 2    {percent|function} employees {below|comparator...
# 3    {count|function} of workers are {less than|com...
# 4    {How many|function} employees are {C-levels|po...
# 5    Gimme the {percent|function} of {50|age} year ...
# 6    {How many|function} people are {performing bad...
# 7    {cumulative|function} {count|function} of empl...
# 8    {average|function} age of the employees that a...
# 9    What's the {summed|function} {num of|function}...
# 10   What is the {total|function} {number of|functi...
# 11   {average|function} age of workers who are {old...
# 12   What {count|function} of employees {meet 90-da...
# 13   whats the {added up|function} number of employ...
# 14   Fetch me the {count|function} of managers in t...
# 15   What is the {percentage|function} of {engineer...
# 16   {distribution|function} in department with pri...
# 17       {ratio|function} employees work in {OH|state}
# 18   What is the {average|function} {performance sc...
# 19   {How many|function} people are {over|comparato...
# 20        {sum|function} employees live in {UT|state}?
# 21   What is the {combined|function} number of empl...
# 22   what is the {summed|function} tenure of employ...
# 23     {percent|function} employees work in {IN|state}
# 24   {total|function} employees are that {female|sex}?
# 25   {percentage|function} working here that r {mal...
# 26   {How many|function} employees work for {Michae...
# 27   {cumulative|function} {num of|function} employ...
# 28   {How many|function} employees are {above|compa...
# 29   {cumulative|function} of Employees in departme...
# 30   {Number of|function} {Married|maritaldesc} emp...
# 31   Calculate the {total|function} of employees th...
# ..                                                 ...
# 271                                                NaN
# 272                                                NaN
# 273                                                NaN
# 274                                                NaN
# 275                                                NaN
# 276                                                NaN
# 277                                                NaN
# 278                                                NaN
# 279                                                NaN
# 280                                                NaN
# 281                                                NaN
# 282                                                NaN
# 283                                                NaN
# 284                                                NaN
# 285                                                NaN
# 286                                                NaN
# 287                                                NaN
# 288                                                NaN
# 289                                                NaN
# 290                                                NaN
# 291                                                NaN
# 292                                                NaN
# 293                                                NaN
# 294                                                NaN
# 295                                                NaN
# 296                                                NaN
# 297                                                NaN
# 298                                                NaN
# 299                                                NaN
# 300                                                NaN
#
#                                          get_employees  \
# 2                               {female|sex} employees
# 3                       employees {hispanic|racedesc}?
# 4    get me the {youngest|extreme} {five|sys_number...
# 5    give me a list of {separated employees|marital...
# 6            employees that live in {california|state}
# 7    Which employees have been {terminated|employme...
# 8    Who {has worked here|employment_action} based ...
# 9    give me a list of employees that are based in ...
# 10   Which employees have been with the company lon...
# 11   employees are {under|comparator} {45|sys_numbe...
# 12   who is {working for|manager} {IT support|posit...
# 13         {eligible noncitizen|citizendesc} employees
# 14   Tell me Which employees who are not {us citize...
# 15            All employees from {Alabama|state} state
# 16               show me {multi-racial|race} employees
# 17                     {widowed|maritaldesc} employees
# 18                        employee {managers|position}
# 19              Who is our {maximum|extreme} employee?
# 20                 Show {single|maritaldesc} employees
# 21   provide me a list of {it manager - infra|posit...
# 22     employees that are {director of sales|position}
# 23               get me a list of {cio|position} staff
# 24       employee with the {highest|extreme} {age|age}
# 25                   {accountant i|position} employees
# 26   Which employees were {join date|employment_act...
# 27   employees have a {start date|employment_action...
# 28                 which staff work in {IT|department}
# 29   employees between the {age of|age} {20|sys_num...
# 30   who are the {top|extreme} {10|sys_number}{perc...
# 31   Which employees {quit working|employment_statu...
# ..                                                 ...
# 271    employees have been {let go|employment_action}?
# 272                   {divorced|maritaldesc} employees
# 273      workers doing {it manager - support|position}
# 274                   who is not {married|maritaldesc}
# 275         employees that are {separated|maritaldesc}
# 276                        {ID|state} employees listed
# 277                  employees that live in {VT|state}
# 278  Which employees are not {US citizens|citizende...
# 279                        list of {managers|position}
# 280                         {it support|position} list
# 281    Which employees are {active|employment_status}?
# 282           Which employees are {managers|position}?
# 283              {network engineer|position} employees
# 284               Show {married|maritaldesc} employees
# 285                       {network engineers|position}
# 286                {non citizen|citizendesc} employees
# 287  employees that work as an {sales manager|posit...
# 288  Show me the employees who are {widowed|marital...
# 289  who is {working for|manager} {director of sale...
# 290  i want the {maximum|extreme} {third|sys_ordina...
# 291            Which employees are {sr. dba|position}?
# 292          employees that are {divorced|maritaldesc}
# 293                       {manager|position} employees
# 294  Which employees have been {terminated|employme...
# 295            {us citizen|citizendesc}s employee list
# 296     provide me a list of {sr. accountant|position}
# 297         Which employees are {married|maritaldesc}?
# 298              Who is our {oldest|extreme} employee?
# 299     Which employees are {US citizens|citizendesc}?
# 300  employees {younger than|comparator} {54 years|...
#
#                                             get_salary  \
# 2           Amount that {Julia|name} gets {paid|money}
# 3    {joanne handschiegl|name} {each month|time_rec...
# 4    {Mia|name} {earns|money} what amount {each day...
# 5    What does {mia|name}'s {paycheck|money} look l...
# 6    {webster|name} is {earning|money} what amount ...
# 7    Does {54,000|sys_number} exceed what {jessica|...
# 8       {ivan|name} {Salary|money} {Yearly|time_recur}
# 9    What does {Rose Ivey|name} get for {income|mon...
# 10   According to the {payroll|money}, how much doe...
# 11   What is {Brooke oliver|name}'s {each year|time...
# 12                {april Evensen|name} {incomes|money}
# 13   {Ivan Rogers|name} {Salary|money} {Daily|time_...
# 14   When we let {ivan rogers|name} go {fired|emplo...
# 15   What does {Rose Ivey|name}'s {make|money} look...
# 16                    {Payrate|money} {Mia Brown|name}
# 17   Tell me how much {Robyn Manchester|name} {earn...
# 18   What does {Maliki|name}'s {salary|money} look ...
# 19   Does {Brad Pitt|name} {income|money} {more tha...
# 20   how much {$|money} does {Carl Desimone|name} m...
# 21   Does {Howard Mullaney|name}'s {$|money} {less ...
# 22   What is {julia soto|name}'s exact {salary|mone...
# 23   {jeanette|name} {earns|money} {every year|time...
# 24   How much is {nan|name} {making|money} on {Payr...
# 25   How much does Cisco give {nan|name} in {$|mone...
# 26   Is {50k|sys_number} {more than|comparator} wha...
# 27   {melisa|name} {each day|time_recur} {earnings|...
# 28   What does {Eric Dougall|name} {earnings|money}...
# 29   What does {thelma petrowsky|name} {earner|mone...
# 30   {dianna blount|name} {earns|money} how much {b...
# 31   What is {Brannon|name}'s {daily basis|time_rec...
# ..                                                 ...
# 271  What does {Phylicia Gosciminski|name} get for ...
# 272               {money|money} {Judith Carabbio|name}
# 273  Does {23,240|sys_number} exceed what {webster|...
# 274  {Mei Trang|name}'s {every month|time_recur} {e...
# 275  Tell me who earned the {most|extreme} that has...
# 276       What is Mrs.{Williams|name}'s {money|money}?
# 277  What is {Constance Sloan|name} {paycheck|money...
# 278            Describe {Ivan|name}'s {paycheck|money}
# 279              {earn|money} of  {Taylor sparks|name}
# 280  {Gerry|name} {income|money} {each hour|time_re...
# 281                                                NaN
# 282                                                NaN
# 283                                                NaN
# 284                                                NaN
# 285                                                NaN
# 286                                                NaN
# 287                                                NaN
# 288                                                NaN
# 289                                                NaN
# 290                                                NaN
# 291                                                NaN
# 292                                                NaN
# 293                                                NaN
# 294                                                NaN
# 295                                                NaN
# 296                                                NaN
# 297                                                NaN
# 298                                                NaN
# 299                                                NaN
# 300                                                NaN
#
#                                   get_salary_aggregate  \
# 2    among all of the employees that found their jo...
# 3         {sum|function} {pay|money} for {female|sex}?
# 4    give me the {mean|function} {salary|money} for...
# 5    what is the {highest|extreme} {amount|money} t...
# 6    What is the {total|function} {earnings|money} ...
# 7    what are {women|sex} {making|money} on {averag...
# 8    of all the {sales manager|position}s, what is ...
# 9    get me the {average|function} amount that the ...
# 10   {number of|function} people {earning|money} {f...
# 11   give me the {typical|function} take home {sala...
# 12   What is the {sum|function} of {earnings|money}...
# 13   of all the {network engineer|position}s, what ...
# 14   What's the {ratios|function} {earnings|money} ...
# 15   {sr. accountant|position} {total|function} {sa...
# 16   {total|function} {number of|function} employee...
# 17   fetch me the {min|extreme} {paycheck|money} fo...
# 18   {avg|function} {income|money} for {on-line web...
# 19   {How many|function} people are {paid|money} {l...
# 20   amount of {money|money} {earned|money} by {fem...
# 21   what is the {typical|function} {earning|money}...
# 22   what is the {average|function} {salary|money} ...
# 23   what {portion|function} of employees that {wor...
# 24   what is the {min|extreme} {earning|money} in t...
# 25   what is the {fraction|function} of {female|sex...
# 26   what is the {total|function} amount of {money|...
# 27   {Mean|function} {pay|money} of workers {hired|...
# 28   Describe the {salary|money} {range|function} f...
# 29   what do {men|sex} {make|money} here on {averag...
# 30   what is the {lowest|extreme} {income|money} th...
# 31   what is the {average|function} {income|money} ...
# ..                                                 ...
# 271                                                NaN
# 272                                                NaN
# 273                                                NaN
# 274                                                NaN
# 275                                                NaN
# 276                                                NaN
# 277                                                NaN
# 278                                                NaN
# 279                                                NaN
# 280                                                NaN
# 281                                                NaN
# 282                                                NaN
# 283                                                NaN
# 284                                                NaN
# 285                                                NaN
# 286                                                NaN
# 287                                                NaN
# 288                                                NaN
# 289                                                NaN
# 290                                                NaN
# 291                                                NaN
# 292                                                NaN
# 293                                                NaN
# 294                                                NaN
# 295                                                NaN
# 296                                                NaN
# 297                                                NaN
# 298                                                NaN
# 299                                                NaN
# 300                                                NaN
#
#                                   get_salary_employees  \
# 2    Which {Sr. DBA|position} {earns|money} the {mo...
# 3    Which employee(s) have {lowest|extreme} {incom...
# 4    give me the {earners|money} for all of the emp...
# 5    give me the {earnings|money} for all of the em...
# 6    what are {network engineers|position} {making|...
# 7    all the {earnings|money} of {female|sex} in th...
# 8    who {makes|money} the {minimum|extreme} {incom...
# 9    Get me the {lowest|extreme} {six|sys_number} {...
# 10   which employees are {making|money} {less than|...
# 11         {non-citizen|citizendesc} {paycheck|money}s
# 12   what are {accountant i|position} {paid|money} ...
# 13   who {make|money} a {salary|money} {more than|c...
# 14                       {earnings|money} {female|sex}
# 15   Of the employees {hired|employment_action} {af...
# 16                         {paycheck|money} {male|sex}
# 17   Who {earns|money} the {most|extreme} in the {p...
# 18   get the {salaries|money} of employees in the {...
# 19   who are the company's {lowest|extreme} {7|sys_...
# 20           {income|money} of {female|sex} in the org
# 21   show me the {min|extreme} {earners|money} that...
# 22       {software engineering|department} {pay|money}
# 23   I want a list with {pay|money} of employees th...
# 24   what are {it director|position} {making|money}...
# 25   Tell me the employee that {works under|manager...
# 26   Which employee(s) have {highest|extreme} {payc...
# 27   list employees {making|money} {more than|compa...
# 28   give me the {salaries|money} of {interracial|r...
# 29   For employees {hired|employment_action} {betwe...
# 30   {earnings|money} for people working in the {it...
# 31   Of all the {area sales manager|position}, whic...
# ..                                                 ...
# 271                                                NaN
# 272                                                NaN
# 273                                                NaN
# 274                                                NaN
# 275                                                NaN
# 276                                                NaN
# 277                                                NaN
# 278                                                NaN
# 279                                                NaN
# 280                                                NaN
# 281                                                NaN
# 282                                                NaN
# 283                                                NaN
# 284                                                NaN
# 285                                                NaN
# 286                                                NaN
# 287                                                NaN
# 288                                                NaN
# 289                                                NaN
# 290                                                NaN
# 291                                                NaN
# 292                                                NaN
# 293                                                NaN
# 294                                                NaN
# 295                                                NaN
# 296                                                NaN
# 297                                                NaN
# 298                                                NaN
# 299                                                NaN
# 300                                                NaN
#
#                                               get_date  \
# 2    What year was {Lily DiNocco|name} {let go|empl...
# 3    Has {Sarah Warfield|name} been working here fo...
# 4    What was the exact date when {desiree|name} wa...
# 5            How long has Mr.{Knapp|name} worked here?
# 6    Has {Nicole|name} been working here for {4 yea...
# 7    What was the date when {ivan rogers|name} was ...
# 8    When {Sophia Theamstern|name} was {hired|emplo...
# 9        Fetch me {Francesco Barone|name}'s {Bday|dob}
# 10              {Leigh Smith|name} {date of birth|dob}
# 11                   {Ashley Rose|name} {birthday|dob}
# 12   When was {Francesco Barone|name}'s {hiring dat...
# 13   The date was what when {Allison Lydon|name} be...
# 14   Please get me {DOB|dob} of {Ludwick Harrell|name}
# 15                         {nan|name} {birth date|dob}
# 16   What was {Estelle|name}s {start date|employmen...
# 17             When was {ivan rogers|name} {born|dob}?
# 18     Please Get me {Kelley Spirea|name}'s {Bday|dob}
# 19     What is {nan singh|name}'s {date of birth|dob}?
# 20   When did {Seffi Shields|name} get {fired|emplo...
# 21   When was {Charles Bozzi|name} {hired|employmen...
# 22   I want the date when {julia soto|name} {starti...
# 23   When was {Carla Demita|name}'s {join|employmen...
# 24   What was {nan|name}'s {date of hiring|employme...
# 25   tell me {birth date|dob} of {Lei-Ming Nguyen|n...
# 26   When {Amy|name} was {born|dob}, what was the m...
# 27   When was it that {Barry Wilber|name} {started ...
# 28   What was day when {nan singh|name} was {born|dob}
# 29   Has {Kristen Squatrito|name} been working here...
# 30   When {Alexandra Kirill|name} was {joining|empl...
# 31   {Violeta Ferreira|name} {started|employment_ac...
# ..                                                 ...
# 271                                                NaN
# 272                                                NaN
# 273                                                NaN
# 274                                                NaN
# 275                                                NaN
# 276                                                NaN
# 277                                                NaN
# 278                                                NaN
# 279                                                NaN
# 280                                                NaN
# 281                                                NaN
# 282                                                NaN
# 283                                                NaN
# 284                                                NaN
# 285                                                NaN
# 286                                                NaN
# 287                                                NaN
# 288                                                NaN
# 289                                                NaN
# 290                                                NaN
# 291                                                NaN
# 292                                                NaN
# 293                                                NaN
# 294                                                NaN
# 295                                                NaN
# 296                                                NaN
# 297                                                NaN
# 298                                                NaN
# 299                                                NaN
# 300                                                NaN
#
#                               get_date_range_aggregate  \
# 2    {percent|function} of employees {born|dob} in ...
# 3    {1974|sys_time} {born|dob} employees {percent|...
# 4    What {percentage|function} of employees were {...
# 5    {1945|sys_time} {born|dob} employees {percent|...
# 6    What {percent|function} of employees were {hir...
# 7    What {percentage|function} of employees have b...
# 8    can you please tell me what {fraction|function...
# 9    What {pct|function} of our staff have a {bday|...
# 10   What {percentage|function} of employees were {...
# 11   I want the {total|function} {number of|functio...
# 12   Tell me the {pct|function} of staff that have ...
# 13   {1980|sys_time} {born|dob} employees {total|fu...
# 14   Fetch me {percent|function} that {started work...
# 15   {ratio|function} out of all of the employees t...
# 16   what is the {fraction|function} of employees t...
# 17   {count|function} employees {born|dob} {before|...
# 18   For all of those that {joined|employment_actio...
# 19   how many {joined|employment_action} {prior to|...
# 20   Is there anyone who {joined|employment_action}...
# 21   {count|function} of employees {born|dob} {befo...
# 22   {total|function} employees that have {been wit...
# 23   {How many|function} employees were {born|dob} ...
# 24   what is the {total|function} {number of|functi...
# 25   Can you {count|function} the number of people ...
# 26   i want the {count|function} of employees that ...
# 27   {last|date_compare} {three months|sys_duration...
# 28   Were there more {men|sex} with {birthdays|dob}...
# 29   {how many|function} new employees based out of...
# 30   {total|function} of workers {DOB|dob} {prior t...
# 31   {started employment|employment_action} {less t...
# ..                                                 ...
# 271                                                NaN
# 272                                                NaN
# 273                                                NaN
# 274                                                NaN
# 275                                                NaN
# 276                                                NaN
# 277                                                NaN
# 278                                                NaN
# 279                                                NaN
# 280                                                NaN
# 281                                                NaN
# 282                                                NaN
# 283                                                NaN
# 284                                                NaN
# 285                                                NaN
# 286                                                NaN
# 287                                                NaN
# 288                                                NaN
# 289                                                NaN
# 290                                                NaN
# 291                                                NaN
# 292                                                NaN
# 293                                                NaN
# 294                                                NaN
# 295                                                NaN
# 296                                                NaN
# 297                                                NaN
# 298                                                NaN
# 299                                                NaN
# 300                                                NaN
#
#                               get_date_range_employees  \
# 2    I want {male|sex} {born|dob} in the {1930s|tim...
# 3    Which employees did we {get rid of|employment_...
# 4    {forties|time_interval} {born|dob} employees w...
# 5    Which are the employees such that in {2005|sys...
# 6    i want the employees that have been {hired |em...
# 7    Give me the employees that have a {join date|e...
# 8    Fetch me a list of workers that have their {bi...
# 9    get me {senior database admins|position} {born...
# 10   I want all of the employees in the {sales depa...
# 11   Can you tell me whether there are any {June|sy...
# 12            {November|sys_time} {born|dob} employees
# 13   who are our {1940's|time_interval} {born|dob} ...
# 14   {hispanic|racedesc} employees {born|dob} {afte...
# 15   Which workers at the company have a {birthday|...
# 16   {seventies|time_interval} {born|dob} employees...
# 17   Get me list of employees that have a {DOB|dob}...
# 18   Give me a list of employees that were {hired|e...
# 19   Tell me about employees who were {hired|employ...
# 20   Which employees are {DOB|dob} in the second we...
# 21   {2011|sys_time} {started working here|employme...
# 22   find me the {black or african american|racedes...
# 23   Which employees are {born|dob} in the second w...
# 24   Show me {female|sex}s {born|dob} in the {ninet...
# 25   Which employees were not yet {born|dob} when {...
# 26   Which people weren't yet {born|dob} when {9/11...
# 27           {June|sys_time} {born|dob} in - employees
# 28   {2013|sys_time} {hired|employment_action} empl...
# 29   {fifteen|sys_number} {most|extreme} recently {...
# 30   have there been any employees that have been w...
# 31   {1960's|time_interval} {born|dob} {asian|raced...
# ..                                                 ...
# 271                                                NaN
# 272                                                NaN
# 273                                                NaN
# 274                                                NaN
# 275                                                NaN
# 276                                                NaN
# 277                                                NaN
# 278                                                NaN
# 279                                                NaN
# 280                                                NaN
# 281                                                NaN
# 282                                                NaN
# 283                                                NaN
# 284                                                NaN
# 285                                                NaN
# 286                                                NaN
# 287                                                NaN
# 288                                                NaN
# 289                                                NaN
# 290                                                NaN
# 291                                                NaN
# 292                                                NaN
# 293                                                NaN
# 294                                                NaN
# 295                                                NaN
# 296                                                NaN
# 297                                                NaN
# 298                                                NaN
# 299                                                NaN
# 300                                                NaN
#
#                                          get_hierarchy
# 2    can i have the names of employees who report t...
# 3    is {Charles Bozzi|name} the {mentor|manager} f...
# 4    is {Peter Monroe|name} {managing|manager} {Amy...
# 5    who is {helen billis|name}s {managing|manager}...
# 6    which employees is {Ivan singh|name} the {mana...
# 7    Who are those employees that are {under|compar...
# 8    I want to know if {Amy Dunn|name} is a {manger...
# 9    who is the {manager|manager} assigned to {luis...
# 10   I want to know if {Sam Athwal|name} {works for...
# 11   {Jenna Dietrich|name} is the {supervisor|manag...
# 12   who is {Thelma Petrowsky|name}'s {managing|man...
# 13   does {Dianna Blount|name} {report|manager} to ...
# 14   employees that directly {manage|manager} {Jere...
# 15   get me a list of all of the employees who {sup...
# 16   list employees who {leads|manager} {Adrienne H...
# 17              {amy dunn|name} {manager|manager} name
# 18   Which are all of the employees who are having ...
# 19   so who is {Rose Ivey|name}'s reporting {manage...
# 20   who all is {management|manager} of {Estelle Ho...
# 21   Tell me which employees have {Patrick Moran|na...
# 22   Tell me who is Mr.{Enrico Langton|name}'s {man...
# 23   Who are those employees that right now have {C...
# 24   is {Andrew Szabo|name} {head|manager} of {Patr...
# 25   does {Peter Monroe|name} {manage|manager} {Amy...
# 26   i want the name of everyone that is {working f...
# 27   which employees that have a {manager name|mana...
# 28   {Janine Purinton|name} is the {mentor|manager}...
# 29   I want an employee list with all of the folks ...
# 30   Give me all of the employees hv {Karen Mancuso...
# 31   is {Amy Dunn|name} {managed by|manager} {Peter...
# ..                                                 ...
# 271                                                NaN
# 272                                                NaN
# 273                                                NaN
# 274                                                NaN
# 275                                                NaN
# 276                                                NaN
# 277                                                NaN
# 278                                                NaN
# 279                                                NaN
# 280                                                NaN
# 281                                                NaN
# 282                                                NaN
# 283                                                NaN
# 284                                                NaN
# 285                                                NaN
# 286                                                NaN
# 287                                                NaN
# 288                                                NaN
# 289                                                NaN
# 290                                                NaN
# 291                                                NaN
# 292                                                NaN
# 293                                                NaN
# 294                                                NaN
# 295                                                NaN
# 296                                                NaN
# 297                                                NaN
# 298                                                NaN
# 299                                                NaN
# 300                                                NaN
#
# [299 rows x 10 columns]

# %%
label_chk(intent_txt, ent_dict)
# Out:
# GET_INFO=============================================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: what is {Phylicia Gosciminski|name}s org role
# Column: get_info
# Index: 4
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What position is {ivan|name} in?
# Column: get_info
# Index: 5
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Which department is {adrienne homberger|name} in?
# Column: get_info
# Index: 7
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: is {abdellah veera|name} a {cio|position} or not?
# Column: get_info
# Index: 8
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: citizen
# ENTITY: citizendesc
# SENTENCE: Is {Mohammed Latif|name} a citizen of the us?
# Column: get_info
# Index: 9
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Is {Mohammed Latif|name} a citizen of the us?
# Column: get_info
# Index: 9
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: is {Ivan Rogers|name} {currently active|employment_status} or not
# Column: get_info
# Index: 14
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Is the {software engineering|department} the dept that {Jeremiah Semizoglou|name} currently work in
# Column: get_info
# Index: 15
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is {Julia|name}'s race?
# Column: get_info
# Index: 18
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: what is {thomas murray|name}'s race?
# Column: get_info
# Index: 20
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: tell me what is {nan singh|name}'s citizenship status
# Column: get_info
# Index: 21
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: which branch is the one that {Brannon Miller|name} works in
# Column: get_info
# Index: 22
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: tell me, is {Julissa Hunts|name} a {widowed|maritaldesc} {lady|sex}?
# Column: get_info
# Index: 24
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: is Mr.{julia soto|name} based in {Oregon|state}
# Column: get_info
# Index: 25
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: boy
# ENTITY: sex
# SENTENCE: how {old|age} is {Michael|name} and is he a boy or a girl?
# Column: get_info
# Index: 27
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: how {old|age} is {Michael|name} and is he a boy or a girl?
# Column: get_info
# Index: 27
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is {Hakim|name}'s level in the organization?
# Column: get_info
# Index: 29
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: how {old|age} is {hogland|name} and is he a {boy|sex} or a {girl|sex}?
# Column: get_info
# Index: 31
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Is {28|age} the age of {lauren mahoney|name}?
# Column: get_info
# Index: 32
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is Mrs.{Nowlan|name}'s position?
# Column: get_info
# Index: 33
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IT
# ENTITY: department
# SENTENCE: which branch is it that {Melisa Gerke|name} is working in
# Column: get_info
# Index: 34
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: which branch is it that {Melisa Gerke|name} is working in
# Column: get_info
# Index: 34
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: tell me what is {Nader Barton|name}'s citizenship status
# Column: get_info
# Index: 36
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: which state is {Melisa|name} from
# Column: get_info
# Index: 39
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: where is {wilson adinolfi|name} from
# Column: get_info
# Index: 41
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: is {Alex|name} in the {admin offices|department} department
# Column: get_info
# Index: 46
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: is {francesco barone|name} a {non-citizen|citizendesc}
# Column: get_info
# Index: 47
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: tell me, is {Bartholemew Khemmich|name} {single|maritaldesc}?
# Column: get_info
# Index: 48
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IT
# ENTITY: department
# SENTENCE: What's {Ashley Rose|name}'s {performance score|performance_score} is it {too early to review|performance_score} it?
# Column: get_info
# Index: 50
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What's {Ashley Rose|name}'s {performance score|performance_score} is it {too early to review|performance_score} it?
# Column: get_info
# Index: 50
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: get me that state that {Nan|name} is from
# Column: get_info
# Index: 51
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Where is {judy jung|name} from?
# Column: get_info
# Index: 52
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: is {Julia|name} based in {MA|state}
# Column: get_info
# Index: 53
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is {Ivan|name}'s last name?
# Column: get_info
# Index: 55
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: last
# ENTITY: date_compare
# SENTENCE: What is {Ivan|name}'s last name?
# Column: get_info
# Index: 55
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: where is {Mia Brown|name} from
# Column: get_info
# Index: 56
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Is {Jyoti|name} {widowed|maritaldesc} or {single|maritaldesc}?
# Column: get_info
# Index: 60
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: is {Maria Gonzalez|name} {widowed|maritaldesc} or nah
# Column: get_info
# Index: 64
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Is {Lynn|name} {active|employment_status}?
# Column: get_info
# Index: 65
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: is the job title of {adeel osturnka|name} a {shared services manager|position}
# Column: get_info
# Index: 66
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Is {james|name} {single|maritaldesc}?
# Column: get_info
# Index: 67
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: is {Abdellah Veera|name} {terminated|employment_status} or not
# Column: get_info
# Index: 68
# ==========================================
# POTENTIAL MISMATCH for: terminated
# CURRENT LABEL: employment_status
# IN DICT: employment_action
# SENTENCE: is {Abdellah Veera|name} {terminated|employment_status} or not
# Column: get_info
# Index: 68
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Is {hong pham|name} {on a leave of absence|employment_status}?
# Column: get_info
# Index: 70
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: last
# ENTITY: date_compare
# SENTENCE: Whats {cybil|name}'s last name?
# Column: get_info
# Index: 73
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: which state is {Geoff|name} from
# Column: get_info
# Index: 74
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: is {Shana maurice|name} a {network engineer|position}
# Column: get_info
# Index: 75
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: is {nan|name} in the {software engineering|department} department
# Column: get_info
# Index: 76
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: what is {Denisa dobrin|name}'s employment status
# Column: get_info
# Index: 77
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Tell me the position is {kamrin sander|name} in?
# Column: get_info
# Index: 78
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is {adrienne homberger|name}'s last name?
# Column: get_info
# Index: 80
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: last
# ENTITY: date_compare
# SENTENCE: What is {adrienne homberger|name}'s last name?
# Column: get_info
# Index: 80
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: is {Lowan Biden|name} based in {TN|state}
# Column: get_info
# Index: 81
# ==========================================
# POTENTIAL MISMATCH for: terminated
# CURRENT LABEL: employment_status
# IN DICT: employment_action
# SENTENCE: What was {elijiah gray|name} {terminated|employment_status} for?
# Column: get_info
# Index: 83
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is {Caroline|name}'s position?
# Column: get_info
# Index: 87
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is {Mia|name}'s employment status?
# Column: get_info
# Index: 89
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: where is {Eric|name} from
# Column: get_info
# Index: 91
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: how {old|age} is {Howard|name} and is he a {boy|sex} or a {girl|sex}?
# Column: get_info
# Index: 93
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: is {ricardo ruiz|name} based in {Rhode Island|state}
# Column: get_info
# Index: 96
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What ethnicity is {Catherine|name}'s?
# Column: get_info
# Index: 97
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: is {Joanne Handschiegl|name} {active|employment_status} or not so
# Column: get_info
# Index: 98
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: tell me, is {nan singh|name} {separated|maritaldesc}?
# Column: get_info
# Index: 99
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: department {lindsay lynch|name} is in?
# Column: get_info
# Index: 100
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What race is {Nan|name}'s?
# Column: get_info
# Index: 102
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Is {Lauren mahoney|name} {active|employment_status} at Mcdonalds?
# Column: get_info
# Index: 105
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: Von
# ENTITY: name
# SENTENCE: Is {Anna Von Massenbach|name}'s race {asian|racedesc}?
# Column: get_info
# Index: 107
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: von
# ENTITY: name
# SENTENCE: Is {Anna Von Massenbach|name}'s race {asian|racedesc}?
# Column: get_info
# Index: 107
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Is {Anna Von Massenbach|name}'s race {asian|racedesc}?
# Column: get_info
# Index: 107
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Is {Nan|name}'s race {Asian|racedesc}?
# Column: get_info
# Index: 108
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Which department is the one that {thomas|name} works for?
# Column: get_info
# Index: 110
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Is Mr.{Murray|name} working from out of state?
# Column: get_info
# Index: 113
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: tell me what is the citizenship status for {Jennifer|name}'s
# Column: get_info
# Index: 114
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: what is {Donysha|name}'s {performance score|performance_score} history?
# Column: get_info
# Index: 115
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: is {Bonalyn|name} {terminated|employment_status} from the company or not
# Column: get_info
# Index: 116
# ==========================================
# POTENTIAL MISMATCH for: terminated
# CURRENT LABEL: employment_status
# IN DICT: employment_action
# SENTENCE: is {Bonalyn|name} {terminated|employment_status} from the company or not
# Column: get_info
# Index: 116
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What race is {rick clayton|name}'s?
# Column: get_info
# Index: 117
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: Ait
# ENTITY: name
# SENTENCE: Find me that state that {Karthikeyan Ait Sidi|name} is from
# Column: get_info
# Index: 119
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: ait
# ENTITY: name
# SENTENCE: Find me that state that {Karthikeyan Ait Sidi|name} is from
# Column: get_info
# Index: 119
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Find me that state that {Karthikeyan Ait Sidi|name} is from
# Column: get_info
# Index: 119
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: is {Nan|name} a {network engineer|position}
# Column: get_info
# Index: 122
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IT
# ENTITY: department
# SENTENCE: What is {brooke oliver|name}'s score, is it {meeting 90-day expectations|performance_score}?
# Column: get_info
# Index: 124
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is {brooke oliver|name}'s score, is it {meeting 90-day expectations|performance_score}?
# Column: get_info
# Index: 124
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: is the job title of {ludwick harrell|name} an {it support|position} techie
# Column: get_info
# Index: 125
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: citizen
# ENTITY: citizendesc
# SENTENCE: Is {karen mancuso|name} a citizen of America?
# Column: get_info
# Index: 127
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Is {karen mancuso|name} a citizen of America?
# Column: get_info
# Index: 127
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Is {Michael|name} {married|maritaldesc} or {single|maritaldesc}?
# Column: get_info
# Index: 128
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: which is the branch that {Bradley Knapp|name} working in
# Column: get_info
# Index: 130
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Is {earnest|name} {divorced|maritaldesc} or {widowed|maritaldesc}?
# Column: get_info
# Index: 131
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: which state is {Joelle Burke|name} from
# Column: get_info
# Index: 132
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: How well is the employee doing?
# Column: get_info
# Index: 136
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Please tell me, is {morissa power|name} {separated|maritaldesc} or not?
# Column: get_info
# Index: 137
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Is {Lindsay|name} an American citizen?
# Column: get_info
# Index: 138
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is {Nan Singh|name}'s {performance score|performance_score}?
# Column: get_info
# Index: 139
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: is {Nan|name} in the {Admin Offices department|department}
# Column: get_info
# Index: 141
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Is {Sarah Warfield|name}'s {exceeding expectations|performance_score}?
# Column: get_info
# Index: 144
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: find me the position that {Jasmine Onque|name} is in?
# Column: get_info
# Index: 148
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: is {janet king|name} a {production technician|position}
# Column: get_info
# Index: 150
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Which department is {Jenna|name} a part of?
# Column: get_info
# Index: 151
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: is {Tanya|name} in the {software engineering|department} dept
# Column: get_info
# Index: 155
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Where is {francesco barone|name} from?
# Column: get_info
# Index: 161
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: is {Quinn|name} {divorced|maritaldesc}?
# Column: get_info
# Index: 163
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Is {Roxana|name} currently {divorced|maritaldesc}?
# Column: get_info
# Index: 164
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: how {old|age} is {abdellah|name} and is he a {boy|sex} or a {girl|sex}?
# Column: get_info
# Index: 165
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is {Nan|name}'s position?
# Column: get_info
# Index: 167
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Is {Nan|name} {married|maritaldesc}?
# Column: get_info
# Index: 168
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Is {it/is|department} the department that {Phil Close|name} currently works in
# Column: get_info
# Index: 171
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Is mr.{Louis Punjabhi|name} located from out of state?
# Column: get_info
# Index: 172
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: tell me, is {Michael|name} a {bachelor|maritaldesc}?
# Column: get_info
# Index: 173
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: is the job title of {julia soto|name} a {network engineer|position}
# Column: get_info
# Index: 175
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: what is {Adell|name}'s official position?
# Column: get_info
# Index: 176
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: How {old|age} is the {mia|name}?
# Column: get_info
# Index: 177
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: citizen
# ENTITY: citizendesc
# SENTENCE: tell me what is {Marianne Eaton|name}'s citizen status
# Column: get_info
# Index: 178
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: tell me what is {Marianne Eaton|name}'s citizen status
# Column: get_info
# Index: 178
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: where is {david stanley|name} from
# Column: get_info
# Index: 181
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is {ivan rogers|name}'s job?
# Column: get_info
# Index: 182
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is {phil close|name}'s race?
# Column: get_info
# Index: 186
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Is {Sarah|name}'s race {white|racedesc}?
# Column: get_info
# Index: 187
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Is {barry|name} {widowed|maritaldesc} or {separated|maritaldesc}?
# Column: get_info
# Index: 188
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Is {julia|name} a citizen?
# Column: get_info
# Index: 189
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: is {marilyn|name} a {us citizen|citizendesc}
# Column: get_info
# Index: 194
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Is {sales|department} the department that {william larotonda|name} currently is working in
# Column: get_info
# Index: 195
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is {janet king|name}'s level in the organization?
# Column: get_info
# Index: 198
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Where is {Sarah|name} from?
# Column: get_info
# Index: 200
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: is {sophia theamstern|name} a {eligible noncitizen|citizendesc}
# Column: get_info
# Index: 202
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is {Alexandra Kirill|name}'s official position?
# Column: get_info
# Index: 203
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Whats {Emil|name}'s {performance score|performance_score} is it: {exceed expectations|performance_score}?
# Column: get_info
# Index: 204
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: which state is {ivan rogers|name} from
# Column: get_info
# Index: 206
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Is {mia brown|name} {on a leave of absence|employment_status}?
# Column: get_info
# Index: 207
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Is {julia soto|name} {actively employed|employment_status}?
# Column: get_info
# Index: 209
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Is {Julia|name} from out of state?
# Column: get_info
# Index: 210
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Is {42|age} the age {lori|name}?
# Column: get_info
# Index: 212
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Show the state that {Rosalie Hutter|name} is from
# Column: get_info
# Index: 213
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Is Ms.{dolan|name}'s race {asian|racedesc}?
# Column: get_info
# Index: 214
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is {brooke oliver|name}'s last name?
# Column: get_info
# Index: 218
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: last
# ENTITY: date_compare
# SENTENCE: What is {brooke oliver|name}'s last name?
# Column: get_info
# Index: 218
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Please tell, is {barbara gaul|name} {widowed|maritaldesc} or not?
# Column: get_info
# Index: 219
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: position that {shari ngodup|name} is in?
# Column: get_info
# Index: 221
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: which branch is {Mia|name} working in
# Column: get_info
# Index: 222
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Where is {julia soto|name} from?
# Column: get_info
# Index: 223
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Is {Elijian|name} {widowed|maritaldesc} or not?
# Column: get_info
# Index: 226
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Show me that state that {Josephine Bugali|name} is from
# Column: get_info
# Index: 227
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: is {Nan|name} a {citizen|citizendesc}
# Column: get_info
# Index: 228
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: is the job title of {elijian clukey|name} a {production manager|position}
# Column: get_info
# Index: 229
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Which department is {Michael|name} in?
# Column: get_info
# Index: 231
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is {Julia Soto|name}'s {performance evaluation|performance_score} history?
# Column: get_info
# Index: 238
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Please tell me, is {Michael|name} {married|maritaldesc} or not?
# Column: get_info
# Index: 239
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Is {Michael|name} {married|maritaldesc}?
# Column: get_info
# Index: 240
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Is ms.{Carter|name} a {married|maritaldesc} {woman|sex}?
# Column: get_info
# Index: 243
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is {ivan rogers|name}'s official position?
# Column: get_info
# Index: 245
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: How {old|age} is {Christie|name}?
# Column: get_info
# Index: 247
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is {colleen|name}'s job?
# Column: get_info
# Index: 248
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Is {Raul|name} based from out of state?
# Column: get_info
# Index: 249
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Is Mr.{Cockel|name} {married|maritaldesc}?
# Column: get_info
# Index: 251
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: what is {Jason Salter|name}'s official position?
# Column: get_info
# Index: 252
# ==========================================
# GET_AGGREGATE=============================================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: old
# ENTITY: age
# SENTENCE: What's the {summed|function} {num of|function} {43|age} yr old employees?
# Column: get_aggregate
# Index: 11
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is the {total|function} {number of|function} {Black or African American|racedesc} folks that currently work in the US?
# Column: get_aggregate
# Index: 12
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is the {percentage|function} of {engineers|position} who are promoted to {manager|manager}
# Column: get_aggregate
# Index: 17
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is the {average|function} {performance score|performance_score} of all employees?
# Column: get_aggregate
# Index: 20
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is the {combined|function} number of employees the are of the age of {40|age}?
# Column: get_aggregate
# Index: 23
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: what is the {summed|function} tenure of employees in {Ohio|state}?
# Column: get_aggregate
# Index: 24
# ==========================================
# POTENTIAL MISMATCH for: 35
# CURRENT LABEL: sys_number
# IN DICT: age
# SENTENCE: {How many|function} employees are {above|comparator} {35|sys_number}?
# Column: get_aggregate
# Index: 30
# ==========================================
# POTENTIAL MISMATCH for: 35
# CURRENT LABEL: sys_number
# IN DICT: age
# SENTENCE: {How many|function} employees are {older than|comparator} {35|sys_number}?
# Column: get_aggregate
# Index: 35
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is the {percent|function} of {production manager|position}s in the organization
# Column: get_aggregate
# Index: 36
# ==========================================
# POTENTIAL OPTION-MISSING LABEL
# OPTION: performance
# ENTITY: reason_for_termination
# SENTENCE: What {typically|function} is the age of employees who {are too early to review|performance_score} or currently {fully meet performance expectations|performance_score}?
# Column: get_aggregate
# Index: 38
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What {typically|function} is the age of employees who {are too early to review|performance_score} or currently {fully meet performance expectations|performance_score}?
# Column: get_aggregate
# Index: 38
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: meet
# ENTITY: performance_score
# SENTENCE: What {typically|function} is the age of employees who {are too early to review|performance_score} or currently {fully meet performance expectations|performance_score}?
# Column: get_aggregate
# Index: 38
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is the {distribution|function} of employees from different states?
# Column: get_aggregate
# Index: 40
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is the {total|function} {number of|function} {us citizens|citizendesc}?
# Column: get_aggregate
# Index: 41
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is the {percentage|function} of employees that {exceeds expectations|performance_score} on his or her {performance score|performance_score}?
# Column: get_aggregate
# Index: 57
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is the {average|function} tenure of employees in {California|state}?
# Column: get_aggregate
# Index: 67
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: what is the {total|function} {number of|function} employees were {hired|employment_action} through a {newspager/magazine|employee_source}?
# Column: get_aggregate
# Index: 73
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: joined
# ENTITY: employment_action
# SENTENCE: {proportion|function} breakdown of employees that joined via {billboard|employee_source} and {on-campus recruiting|employee_source}?
# Column: get_aggregate
# Index: 76
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is the {average|function} {age|age}?
# Column: get_aggregate
# Index: 81
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is the {distribution|function} {ratio|function} of {non-citizen|citizendesc}?
# Column: get_aggregate
# Index: 105
# ==========================================
# POTENTIAL OPTION-MISSING LABEL
# OPTION: performance
# ENTITY: reason_for_termination
# SENTENCE: {proportion|function} {fully meet performance expecations|performance_score} when looking at all employees.
# Column: get_aggregate
# Index: 106
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: meet
# ENTITY: performance_score
# SENTENCE: {proportion|function} {fully meet performance expecations|performance_score} when looking at all employees.
# Column: get_aggregate
# Index: 106
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is the {percentage|function} of new grads in {engineering|department}
# Column: get_aggregate
# Index: 116
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is the {percentage|function} breakdown of employees that joined via {referrals|employee_source}, {social media|employee_source} and {university career fairs|employee_source}?
# Column: get_aggregate
# Index: 120
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: joined
# ENTITY: employment_action
# SENTENCE: What is the {percentage|function} breakdown of employees that joined via {referrals|employee_source}, {social media|employee_source} and {university career fairs|employee_source}?
# Column: get_aggregate
# Index: 120
# ==========================================
# POTENTIAL OPTION-MISSING LABEL
# OPTION: performance
# ENTITY: reason_for_termination
# SENTENCE: {average|function} {fully meet performance expectations|performance_score} of all employees?
# Column: get_aggregate
# Index: 129
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: meet
# ENTITY: performance_score
# SENTENCE: {average|function} {fully meet performance expectations|performance_score} of all employees?
# Column: get_aggregate
# Index: 129
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: old
# ENTITY: age
# SENTENCE: what's the {pct|function} of {29|age} year old employees that work with us?
# Column: get_aggregate
# Index: 132
# ==========================================
# POTENTIAL OPTION-MISSING LABEL
# OPTION: performance
# ENTITY: reason_for_termination
# SENTENCE: Get me the {summed up|function} {count|function} of employees that {fully meet performance expections|performance_score} or {need improvement|performance_score}?
# Column: get_aggregate
# Index: 134
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: meet
# ENTITY: performance_score
# SENTENCE: Get me the {summed up|function} {count|function} of employees that {fully meet performance expections|performance_score} or {need improvement|performance_score}?
# Column: get_aggregate
# Index: 134
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is the {total|function} {count|function} of {production technician|position}s in the company
# Column: get_aggregate
# Index: 140
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is the {combined|function} final {number of|function} employees are that {are exceptional|performance_score} in their performance?
# Column: get_aggregate
# Index: 146
# ==========================================
# POTENTIAL MISMATCH for: 50
# CURRENT LABEL: sys_number
# IN DICT: age
# SENTENCE: {How many|function} employees are {over|comparator} {50|sys_number} {years old|age}?
# Column: get_aggregate
# Index: 148
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is the {number of|function} {married|maritaldesc} employees?
# Column: get_aggregate
# Index: 154
# ==========================================
# POTENTIAL OPTION-MISSING LABEL
# OPTION: performance
# ENTITY: reason_for_termination
# SENTENCE: What is the {percentage|function} of employees that {fully meet performance expectations|performance_score}
# Column: get_aggregate
# Index: 155
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is the {percentage|function} of employees that {fully meet performance expectations|performance_score}
# Column: get_aggregate
# Index: 155
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: meet
# ENTITY: performance_score
# SENTENCE: What is the {percentage|function} of employees that {fully meet performance expectations|performance_score}
# Column: get_aggregate
# Index: 155
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is the employee's race?
# Column: get_aggregate
# Index: 156
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: joined
# ENTITY: employment_action
# SENTENCE: calculate the {ratio|function} breakdown of employees that joined via {information session|employee_source}, {professional society|employee_source} and {on-line web application|employee_source}?
# Column: get_aggregate
# Index: 168
# ==========================================
# POTENTIAL OPTION-MISSING LABEL
# OPTION: between
# ENTITY: comparator
# SENTENCE: {How many|function} employees are between {20|sys_number} and {30|sys_number} {years old|age}?
# Column: get_aggregate
# Index: 172
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: between
# ENTITY: comparator
# SENTENCE: {How many|function} employees are between {20|sys_number} and {30|sys_number} {years old|age}?
# Column: get_aggregate
# Index: 172
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is the {median|function} {age of|age} employees in the {sales|department} and {marketing departments|department}?
# Column: get_aggregate
# Index: 177
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is the {percentage|function} of {senior engineers|position} in the company
# Column: get_aggregate
# Index: 183
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is the {head count|function} trend within the {Sales department|department}?
# Column: get_aggregate
# Index: 184
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: google
# ENTITY: employee_source
# SENTENCE: {percent|function} employees {joined|employment_action} us through a {search engine - google bing yahoo|employee_source}?
# Column: get_aggregate
# Index: 185
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: bing
# ENTITY: employee_source
# SENTENCE: {percent|function} employees {joined|employment_action} us through a {search engine - google bing yahoo|employee_source}?
# Column: get_aggregate
# Index: 185
# ==========================================
# POTENTIAL OPTION-MISSING LABEL
# OPTION: performance
# ENTITY: reason_for_termination
# SENTENCE: Calc the {ratio|function} that {fully meet performance expecations|performance_score}
# Column: get_aggregate
# Index: 187
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: meet
# ENTITY: performance_score
# SENTENCE: Calc the {ratio|function} that {fully meet performance expecations|performance_score}
# Column: get_aggregate
# Index: 187
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is the {voluntary attrition rate|function}  among managers in the {operations department|department}?
# Column: get_aggregate
# Index: 190
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: since
# ENTITY: date_compare
# SENTENCE: {How many|function} people have {worked here|employment_action} since {2015|sys_time}?
# Column: get_aggregate
# Index: 191
# ==========================================
# POTENTIAL MISMATCH for: terminated
# CURRENT LABEL: employment_status
# IN DICT: employment_action
# SENTENCE: {percent|function} of {terminated|employment_status} as a result of {lack of innovation|reason_for_termination}
# Column: get_aggregate
# Index: 193
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: joined
# ENTITY: employment_action
# SENTENCE: {percent|function} break down of employees that joined via {on-campus recruiting|employee_source}, {careerbuilder|employee_source} and {word of mouth|employee_source}?
# Column: get_aggregate
# Index: 206
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: old
# ENTITY: age
# SENTENCE: {distribution|function} of {47|age} year old employees?
# Column: get_aggregate
# Index: 220
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is the {typical|function} age of new grads in {it/is|department}
# Column: get_aggregate
# Index: 224
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is the {ratio|function} of races in our company?
# Column: get_aggregate
# Index: 226
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is the {total|function} {number of|function} of employees are managers?
# Column: get_aggregate
# Index: 228
# ==========================================
# POTENTIAL OPTION-MISSING LABEL
# OPTION: male
# ENTITY: sex
# SENTENCE: Male {headcount|function}
# Column: get_aggregate
# Index: 229
# ==========================================
# GET_EMPLOYEES=============================================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: who is {working for|manager} {IT support|position}?
# Column: get_employees
# Index: 14
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Who is our {maximum|extreme} employee?
# Column: get_employees
# Index: 21
# ==========================================
# POTENTIAL OPTION-MISSING LABEL
# OPTION: manager
# ENTITY: manager
# SENTENCE: provide me a list of {it manager - infra|position}
# Column: get_employees
# Index: 23
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: manager
# ENTITY: manager
# SENTENCE: provide me a list of {it manager - infra|position}
# Column: get_employees
# Index: 23
# ==========================================
# POTENTIAL OPTION-MISSING LABEL
# OPTION: between
# ENTITY: comparator
# SENTENCE: employees between the {age of|age} {20|sys_number} and {40|sys_number}
# Column: get_employees
# Index: 31
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: between
# ENTITY: comparator
# SENTENCE: employees between the {age of|age} {20|sys_number} and {40|sys_number}
# Column: get_employees
# Index: 31
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: who is doing {it director|position} at this company?
# Column: get_employees
# Index: 40
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Who is {single|maritaldesc} in {it/is|department} dept
# Column: get_employees
# Index: 46
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: who is not {divorced|maritaldesc}
# Column: get_employees
# Index: 66
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: who is {divorced|maritaldesc}
# Column: get_employees
# Index: 77
# ==========================================
# POTENTIAL OPTION-MISSING LABEL
# OPTION: manager
# ENTITY: manager
# SENTENCE: {it manager - db|position}
# Column: get_employees
# Index: 78
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: manager
# ENTITY: manager
# SENTENCE: {it manager - db|position}
# Column: get_employees
# Index: 78
# ==========================================
# POTENTIAL OPTION-MISSING LABEL
# OPTION: manager
# ENTITY: manager
# SENTENCE: {it manager - db|position} list
# Column: get_employees
# Index: 88
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: manager
# ENTITY: manager
# SENTENCE: {it manager - db|position} list
# Column: get_employees
# Index: 88
# ==========================================
# POTENTIAL OPTION-MISSING LABEL
# OPTION: sales
# ENTITY: department
# SENTENCE: employees that are {area sales manager|position}
# Column: get_employees
# Index: 93
# ...
# SYNONYM: IS
# ENTITY: department
# SENTENCE: who is Ms. {Myriam Givens|name} {manager name|manager}
# Column: get_hierarchy
# Index: 89
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: as of today Ms. {Dunn|name} is {managing|manager} which employees
# Column: get_hierarchy
# Index: 90
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: {Beatrice Chace|name}, who is the person that she {reports to|manager}?
# Column: get_hierarchy
# Index: 91
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: {Lindsay Lynch|name} is the {lead|manager} for which employees
# Column: get_hierarchy
# Index: 92
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Who is {Michael|name}'s {manager|manager}?
# Column: get_hierarchy
# Index: 94
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Who is {mia brown|name}'s {manager|manager}?
# Column: get_hierarchy
# Index: 98
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: tell me the {supervisor|manager} that is {reponsible for|manager} {Nan|name} as well as the {supervisor|manager} reponsible for {Julia Soto|name}
# Column: get_hierarchy
# Index: 100
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: I would like you to tell what the name is of {kelley|name}'s {managing|manager} employee?
# Column: get_hierarchy
# Index: 102
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Who is the {manager|manager} for {Bob|name}
# Column: get_hierarchy
# Index: 103
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: who all is {working for|manager} {Rose Ivey|name}
# Column: get_hierarchy
# Index: 104
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: who is {Benjamin Burkett|name}'s {manager|manager} that {Benjamin|name} currently {is under|manager}?
# Column: get_hierarchy
# Index: 105
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: me who is the {head|manager} that {works for|manager} Ms. {shakira perry|name}
# Column: get_hierarchy
# Index: 109
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: {Kissy SullMia|name} is the {mentor|manager} for which of our employees
# Column: get_hierarchy
# Index: 111
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: is {mia|name} the manager of {julia|name}?
# Column: get_hierarchy
# Index: 112
# ==========================================
# POTENTIAL OPTION-MISSING LABEL
# OPTION: manager
# ENTITY: manager
# SENTENCE: is {mia|name} the manager of {julia|name}?
# Column: get_hierarchy
# Index: 112
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: manager
# ENTITY: manager
# SENTENCE: is {mia|name} the manager of {julia|name}?
# Column: get_hierarchy
# Index: 112
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Find me the names of everyone that is {managing|manager} mr.{salter|name}
# Column: get_hierarchy
# Index: 113
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: {amy|name} is a {boss|manager}, right?
# Column: get_hierarchy
# Index: 115
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: is {Anthony Cisco|name} {management|manager} {Desiree Tavares|name}
# Column: get_hierarchy
# Index: 119
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Who is {Mia Brown|name}'s {manager|manager}?
# Column: get_hierarchy
# Index: 120
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Is anyone {reporting|manager} to {Lauren Mahoney|name} or is she not a boss
# Column: get_hierarchy
# Index: 121
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: boss
# ENTITY: manager
# SENTENCE: Is anyone {reporting|manager} to {Lauren Mahoney|name} or is she not a boss
# Column: get_hierarchy
# Index: 121
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: who all is {manager|manager} for {Brooke Oliver|name}
# Column: get_hierarchy
# Index: 122
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: name of everyone that is {reporting|manager} {jenna Dietrich|name}
# Column: get_hierarchy
# Index: 123
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: for which of our employees is {jacquelyn|name} the {manager name|manager}
# Column: get_hierarchy
# Index: 126
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: Del
# ENTITY: name
# SENTENCE: get me ms. {Keyla Del Bosque|name}'s {supervisor|manager} full name
# Column: get_hierarchy
# Index: 127
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: del
# ENTITY: name
# SENTENCE: get me ms. {Keyla Del Bosque|name}'s {supervisor|manager} full name
# Column: get_hierarchy
# Index: 127
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: is {Erasumus Monkfish|name} the {manage|manager} for {Bartholemew Khemmich|name}
# Column: get_hierarchy
# Index: 130
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IT
# ENTITY: department
# SENTENCE: is {Lowan Biden|name} the {manager|manager} for {Enrico Langton|name} or is it the other way around?
# Column: get_hierarchy
# Index: 131
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: is {Lowan Biden|name} the {manager|manager} for {Enrico Langton|name} or is it the other way around?
# Column: get_hierarchy
# Index: 131
# ==========================================
# POTENTIAL OPTION-MISSING LABEL
# OPTION: other
# ENTITY: employee_source
# SENTENCE: is {Lowan Biden|name} the {manager|manager} for {Enrico Langton|name} or is it the other way around?
# Column: get_hierarchy
# Index: 131
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Please give me which employees is {Mia Brown|name} is working {under|manager}
# Column: get_hierarchy
# Index: 135
# ==========================================
# POTENTIAL MISMATCH for: under
# CURRENT LABEL: manager
# IN DICT: comparator
# SENTENCE: Please give me which employees is {Mia Brown|name} is working {under|manager}
# Column: get_hierarchy
# Index: 135
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: Rogers
# ENTITY: name
# SENTENCE: for which employees is {Ivan Rogers singh|name} the {supervisor|manager}
# Column: get_hierarchy
# Index: 136
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: rogers
# ENTITY: name
# SENTENCE: for which employees is {Ivan Rogers singh|name} the {supervisor|manager}
# Column: get_hierarchy
# Index: 136
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: for which employees is {Ivan Rogers singh|name} the {supervisor|manager}
# Column: get_hierarchy
# Index: 136
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is {Mia|name}'s {manager|manager}'s name?
# Column: get_hierarchy
# Index: 138
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Does {Amy Dunn|name} have a {manager|manager}, if so who is it?
# Column: get_hierarchy
# Index: 143
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: last
# ENTITY: date_compare
# SENTENCE: whats the first and last name of {Lei-Ming Nguyen|name}'s {reporting|manager} {manager|manager}?
# Column: get_hierarchy
# Index: 144
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: who is Mr. {Neville Tredinnick|name} {reporting to|manager} to
# Column: get_hierarchy
# Index: 145
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: {Giovanni Leruth|name} is the {manager name|manager} of which employees
# Column: get_hierarchy
# Index: 148
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: is there anyone {incharge|manager} of Ms. {Tayana Jeannite|name}, if so who are those people?
# Column: get_hierarchy
# Index: 150
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IT
# ENTITY: department
# SENTENCE: is it correct to say that {Amy|name} is a {boss|manager}?
# Column: get_hierarchy
# Index: 152
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: is it correct to say that {Amy|name} is a {boss|manager}?
# Column: get_hierarchy
# Index: 152
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: which employees is {May Roberson|name} the {reporting|manager} authority for
# Column: get_hierarchy
# Index: 154
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: is {Travis Ozark|name} {management|manager} {Jeanette Tippett|name}
# Column: get_hierarchy
# Index: 159
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: Mia
# ENTITY: name
# SENTENCE: is mia the manager of julia?
# Column: get_hierarchy
# Index: 163
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: mia
# ENTITY: name
# SENTENCE: is mia the manager of julia?
# Column: get_hierarchy
# Index: 163
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: is mia the manager of julia?
# Column: get_hierarchy
# Index: 163
# ==========================================
# POTENTIAL OPTION-MISSING LABEL
# OPTION: manager
# ENTITY: manager
# SENTENCE: is mia the manager of julia?
# Column: get_hierarchy
# Index: 163
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: manager
# ENTITY: manager
# SENTENCE: is mia the manager of julia?
# Column: get_hierarchy
# Index: 163
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: Del
# ENTITY: name
# SENTENCE: Who are those employees that directly {report|manager} to {keyla del bosque|name}
# Column: get_hierarchy
# Index: 164
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: del
# ENTITY: name
# SENTENCE: Who are those employees that directly {report|manager} to {keyla del bosque|name}
# Column: get_hierarchy
# Index: 164
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: Singh
# ENTITY: name
# SENTENCE: {nan singh singh|name} is the {manager|manager} for which of our employees
# Column: get_hierarchy
# Index: 165
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: singh
# ENTITY: name
# SENTENCE: {nan singh singh|name} is the {manager|manager} for which of our employees
# Column: get_hierarchy
# Index: 165
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: {nan singh singh|name} is the {manager|manager} for which of our employees
# Column: get_hierarchy
# Index: 165
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: What is the name of {Nan|name}'s {manager|manager}?
# Column: get_hierarchy
# Index: 169
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: who is Ms. {Debra Houlihan|name} {supervisor|manager}
# Column: get_hierarchy
# Index: 173
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: i want the name of everyone that is {is under|manager} Mr.{albert|name}
# Column: get_hierarchy
# Index: 175
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: who is the {boss|manager} of {James Cockel|name} that {leads|manager} him?
# Column: get_hierarchy
# Index: 176
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: is {Amy|name} a {manager|manager} in our company
# Column: get_hierarchy
# Index: 177
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Get me the person who is {managing|manager} {ermine pelletier|name}
# Column: get_hierarchy
# Index: 178
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: which employees is {Brad Pitt|name} the {management|manager} employee for
# Column: get_hierarchy
# Index: 180
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: who is the {management|manager} individual for {Adeel Osturnka|name}
# Column: get_hierarchy
# Index: 184
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: {Ivan singh|name} is the {manager|manager} of which employees
# Column: get_hierarchy
# Index: 185
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Tell who is {working under|manager} {Mr. Singh|name}
# Column: get_hierarchy
# Index: 187
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: does {mohammed latif|name} have a {boss|manager}, if so who is the guy or girl?
# Column: get_hierarchy
# Index: 193
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: lady
# ENTITY: sex
# SENTENCE: Who is the lady or guy that {Colby Andreola|name} is {incharge|manager} of?
# Column: get_hierarchy
# Index: 194
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Who is the lady or guy that {Colby Andreola|name} is {incharge|manager} of?
# Column: get_hierarchy
# Index: 194
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: {Nori Sewkumar|name} is the {reporting|manager} authority of which employees
# Column: get_hierarchy
# Index: 196
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Find me who is the person {Jackie|name} is {reporting to|manager}, her full name is {Jackie Valentin|name}
# Column: get_hierarchy
# Index: 197
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: who is the person that is being {worked for|manager} for by {Bartholemew Khemmich|name}
# Column: get_hierarchy
# Index: 198
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: Who is {John Reeder|name}'s {manager|manager}?
# Column: get_hierarchy
# Index: 199
# ==========================================
# POTENTIAL SYNONYM-MISSING LABEL
# SYNONYM: IS
# ENTITY: department
# SENTENCE: is the {manager|manager} for {Nan|name} the same as the {manager|manager} for {Nan|name}?
# Column: get_hierarchy
# Index: 202
# ==========================================

# %%
#get_labels("What is the {manager|manager} name of {Julia|name}?")

# %%
ent_dict
# Out:
# {'name': [['William LaRotonda',
#    'Tyrone Steans',
#    'Estelle Howard',
#    'Leigh Smith',
#    'Brandon LeBlanc',
#    'Sean Quinn',
#    'Bonalyn Boutwell',
#    'Amy Foster-Baker',
#    'Janet King',
#    'Jennifer Zamora',
#    'Renee Becker',
#    'Taisha Goble',
#    'Daniff Hernandez',
#    'Jayne Horton',
#    'Noelle Johnson',
#    'Thomas Murray',
#    'Randall Pearson',
#    'Thelma Petrowsky',
#    'Lori Roby',
#    'Jason Salter',
#    'Kramer Simard',
#    'Simon Roup',
#    'Ricardo Ruiz',
#    'Peter Monroe',
#    'Eric Dougall',
#    'Rick Clayton',
#    'Lisa Galia',
#    'Leonara Lindsay',
#    'Alejandro Bacong',
#    'Anthony Cisco',
#    'Linda Dolan',
#    'Maria Gonzalez',
#    'Carlos Merlos',
#    'Tanya Morway',
#    'Anita Shepard',
#    'Neville Tredinnick',
#    'Jumil Turpin',
#    'Karthikeyan Ait Sidi',
#    'Claudia Carr',
#    'Donald Favis',
#    'Bianca Roehrich',
#    'Ann Daniele',
#    'Jyoti Lajiri',
#    'Jeremiah Semizoglou',
#    'Joe South',
#    'Sarah Warfield',
#    'Elisa Bramante',
#    'Michael Albert',
#    'Charles Bozzi',
#    'Webster Butler',
#    'Elijiah Gray',
#    'Jonathan Hogland',
#    'Walter Immediato',
#    'Ketsia Liebig',
#    'Brannon Miller',
#    'Ebonee Peterson',
#    'Kelley Spirea',
#    'David Stanley',
#    'Kissy Sullivan',
#    'Courtney Wallace',
#    'Wilson Adinolfi',
#    'Trina Alagbe',
#    'Carol Anderson',
#    'Sam Athwal',
#    'Rachael Baczenski',
#    'Francesco Barone',
#    'Nader Barton',
#    'Lowan Biden',
#    'Helen Billis',
#    'Donna Brill',
#    'Josephine Bugali',
#    'Beatrice Chace',
#    'Lin Chan',
#    'Donovan Chang',
#    'Enola Chivukula',
#    'Caroline Cierpiszewski',
#    'Elijian Clukey',
#    'James Cockel',
#    'Spencer Cole',
#    'Jean Crimmings',
#    "Jene'ya Darson",
#    'Carl Desimone',
#    'Geoff Dickinson',
#    'Lily DiNocco',
#    'Denisa Dobrin',
#    'Marianne Eaton',
#    'Rex England',
#    'Miguel Estremera',
#    'April Evensen',
#    'Susan Ferguson',
#    'Nilson Fernandes',
#    'Violeta Ferreira',
#    'Libby Fidelia',
#    'Raul Garcia',
#    'Hamish Garneau',
#    'Barbara Gaul',
#    'Mildred Gentry',
#    'Melisa Gerke',
#    'Alex Gilles',
#    'Evelyn Girifalco',
#    'Shenice Gold',
#    'Roxana Goyal',
#    'Paula Gross',
#    'Joanne Handschiegl',
#    'Ludwick Harrell',
#    'Christie Harrington',
#    'Kara Harrison',
#    'Rose Ivey',
#    'Maryellen Jackson',
#    'Hannah Jacobi',
#    'Sneha Jhaveri',
#    'Judy Jung',
#    'Kathleen Kinsella',
#    'Alexandra Kirill',
#    'Bradley Knapp',
#    'John Kretschmer',
#    'Enrico Langton',
#    'Dallas Leach',
#    'Marilyn Linares',
#    'Allison Lydon',
#    'Lindsay Lynch',
#    'Samuel MacLennan',
#    'Lauren Mahoney',
#    'Debbie Mangal',
#    'Shana Maurice',
#    'Sandy Mckenna',
#    'Elizabeth Meads',
#    'Dawn Motlagh',
#    'Colombui Ndzi',
#    'Richard Newman',
#    'Shari Ngodup',
#    'Lei-Ming Nguyen',
#    "Lynn O'hare",
#    'Adeel Osturnka',
#    'Clinton Owad',
#    'Nina Panjwani',
#    'Emil Pelech',
#    'Shakira Perry',
#    'Hong Pham',
#    'Brad Pitt',
#    'Morissa Power',
#    'Louis Punjabhi',
#    'Janine Purinton',
#    'Quinn Rarrick',
#    'Haley Rivera',
#    'Alain Robinson',
#    'Ashley Rose',
#    'Bruno Rossetti',
#    'Melinda Saar-Beckles',
#    'Nore Sadki',
#    'Kamrin Sander',
#    'Nori Sewkumar',
#    'Seffi Shields',
#    'Taylor Sparks',
#    'Kristen Squatrito',
#    'Desiree Tavares',
#    'Sophia Theamstern',
#    'Theresa Tinto',
#    'Jeanette Tippett',
#    'Mei Trang',
#    'Abdellah Veera',
#    'Colleen Volk',
#    'Anna Von Massenbach',
#    'Scott Whittier',
#    'Barry Wilber',
#    'Jacquelyn Williams',
#    'Catherine Ybarra',
#    'Kimberly Beak',
#    'Dianna Blount',
#    'Betsy Bondwell',
#    'Joseph Buccheri',
#    'Joelle Burke',
#    'Benjamin Burkett',
#    'Phil Close',
#    'Daniel Davis',
#    'Carla Demita',
#    'Angela Erilus',
#    'Megan Faller',
#    'Nicole Fancett',
#    'Phylicia Gosciminski',
#    'Earnest Hankard',
#    'Adrienne Homberger',
#    'Julissa Hunts',
#    'Rosalie Hutter',
#    'Ming Huynh',
#    'Tayana Jeannite',
#    'Yen Johnston',
#    'Lindsey Langford',
#    'Mohammed Latif',
#    'Mathew Linden',
#    'Robyn Manchester',
#    'Karen Mancuso',
#    'Brigit McCarthy',
#    'Erasumus Monkfish',
#    'Luisa Monterro',
#    'Patrick Moran',
#    'Maliki Moumanil',
#    'Kristie Nowlan',
#    'Brooke Oliver',
#    'Ermine Pelletier',
#    'May Roberson',
#    'Adil Sahoo',
#    'Constance Sloan',
#    'Lenora Tejeda',
#    'Kenneth Thibaud',
#    'Cybil Trzeciak',
#    'Roger Walker',
#    'Jordan Winthrop',
#    'Hang Wolk',
#    'Edward Buck',
#    'Jessica Bunbury',
#    'Michelle Carter',
#    'Latia Costa',
#    'Jenna Dietrich',
#    'Alfred Digitale',
#    'Maruk Fraval',
#    'Gerry Friedman',
#    'Whitney Gill',
#    'Myriam Givens',
#    'Mike Guilianno',
#    'Jeremy Prater',
#    'Bartholemew Khemmich',
#    'Giovanni Leruth',
#    'Jac McKinzie',
#    'Howard Mullaney',
#    'Jasmine Onque',
#    'Travis Ozark',
#    'Xana Potts',
#    'Caitrin Strong',
#    'Sharlene Terry',
#    'Jackie Valentin',
#    'Noah Villanueva',
#    'Debra Houlihan',
#    'Donysha Kampew',
#    'Colby Andreola',
#    'Judith Carabbio',
#    'Keyla Del Bosque',
#    'Sandra Martin',
#    'Luke Patronick',
#    'Adell Saada',
#    'Andrew Szabo',
#    'Mia Brown',
#    'Ivan Rogers',
#    'Julia Soto',
#    'Nan Singh'],
#   [['william larotonda', 'William', 'william', 'LaRotonda', 'larotonda'],
#    ['tyrone steans', 'Tyrone', 'tyrone', 'Steans', 'steans'],
#    ['estelle howard', 'Estelle', 'estelle', 'Howard', 'howard'],
#    ['leigh smith', 'Leigh', 'leigh', 'Smith', 'smith'],
#    ['brandon leblanc', 'Brandon', 'brandon', 'LeBlanc', 'leblanc'],
#    ['sean quinn', 'Sean', 'sean', 'Quinn', 'quinn'],
#    ['bonalyn boutwell', 'Bonalyn', 'bonalyn', 'Boutwell', 'boutwell'],
#    ['amy foster-baker', 'Amy', 'amy', 'Foster-Baker', 'foster-baker'],
#    ['janet king', 'Janet', 'janet', 'King', 'king'],
#    ['jennifer zamora', 'Jennifer', 'jennifer', 'Zamora', 'zamora'],
#    ['renee becker', 'Renee', 'renee', 'Becker', 'becker'],
#    ['taisha goble', 'Taisha', 'taisha', 'Goble', 'goble'],
#    ['daniff hernandez', 'Daniff', 'daniff', 'Hernandez', 'hernandez'],
#    ['jayne horton', 'Jayne', 'jayne', 'Horton', 'horton'],
#    ['noelle johnson', 'Noelle', 'noelle', 'Johnson', 'johnson'],
#    ['thomas murray', 'Thomas', 'thomas', 'Murray', 'murray'],
#    ['randall pearson', 'Randall', 'randall', 'Pearson', 'pearson'],
#    ['thelma petrowsky', 'Thelma', 'thelma', 'Petrowsky', 'petrowsky'],
#    ['lori roby', 'Lori', 'lori', 'Roby', 'roby'],
#    ['jason salter', 'Jason', 'jason', 'Salter', 'salter'],
#    ['kramer simard', 'Kramer', 'kramer', 'Simard', 'simard'],
#    ['simon roup', 'Simon', 'simon', 'Roup', 'roup'],
#    ['ricardo ruiz', 'Ricardo', 'ricardo', 'Ruiz', 'ruiz'],
#    ['peter monroe', 'Peter', 'peter', 'Monroe', 'monroe'],
#    ['eric dougall', 'Eric', 'eric', 'Dougall', 'dougall'],
#    ['rick clayton', 'Rick', 'rick', 'Clayton', 'clayton'],
#    ['lisa galia', 'Lisa', 'lisa', 'Galia', 'galia'],
#    ['leonara lindsay', 'Leonara', 'leonara', 'Lindsay', 'lindsay'],
#    ['alejandro bacong', 'Alejandro', 'alejandro', 'Bacong', 'bacong'],
#    ['anthony cisco', 'Anthony', 'anthony', 'Cisco', 'cisco'],
#    ['linda dolan', 'Linda', 'linda', 'Dolan', 'dolan'],
#    ['maria gonzalez', 'Maria', 'maria', 'Gonzalez', 'gonzalez'],
#    ['carlos merlos', 'Carlos', 'carlos', 'Merlos', 'merlos'],
#    ['tanya morway', 'Tanya', 'tanya', 'Morway', 'morway'],
#    ['anita shepard', 'Anita', 'anita', 'Shepard', 'shepard'],
#    ['neville tredinnick', 'Neville', 'neville', 'Tredinnick', 'tredinnick'],
#    ['jumil turpin', 'Jumil', 'jumil', 'Turpin', 'turpin'],
#    ['karthikeyan ait sidi', 'Karthikeyan', 'karthikeyan', 'Ait', 'ait'],
#    ['claudia carr', 'Claudia', 'claudia', 'Carr', 'carr'],
#    ['donald favis', 'Donald', 'donald', 'Favis', 'favis'],
#    ['bianca roehrich', 'Bianca', 'bianca', 'Roehrich', 'roehrich'],
#    ['ann daniele', 'Ann', 'ann', 'Daniele', 'daniele'],
#    ['jyoti lajiri', 'Jyoti', 'jyoti', 'Lajiri', 'lajiri'],
#    ['jeremiah semizoglou', 'Jeremiah', 'jeremiah', 'Semizoglou', 'semizoglou'],
#    ['joe south', 'Joe', 'joe', 'South', 'south'],
#    ['sarah warfield', 'Sarah', 'sarah', 'Warfield', 'warfield'],
#    ['elisa bramante', 'Elisa', 'elisa', 'Bramante', 'bramante'],
#    ['michael albert', 'Michael', 'michael', 'Albert', 'albert'],
#    ['charles bozzi', 'Charles', 'charles', 'Bozzi', 'bozzi'],
#    ['webster butler', 'Webster', 'webster', 'Butler', 'butler'],
#    ['elijiah gray', 'Elijiah', 'elijiah', 'Gray', 'gray'],
#    ['jonathan hogland', 'Jonathan', 'jonathan', 'Hogland', 'hogland'],
#    ['walter immediato', 'Walter', 'walter', 'Immediato', 'immediato'],
#    ['ketsia liebig', 'Ketsia', 'ketsia', 'Liebig', 'liebig'],
#    ['brannon miller', 'Brannon', 'brannon', 'Miller', 'miller'],
#    ['ebonee peterson', 'Ebonee', 'ebonee', 'Peterson', 'peterson'],
#    ['kelley spirea', 'Kelley', 'kelley', 'Spirea', 'spirea'],
#    ['david stanley', 'David', 'david', 'Stanley', 'stanley'],
#    ['kissy sullivan', 'Kissy', 'kissy', 'Sullivan', 'sullivan'],
#    ['courtney wallace', 'Courtney', 'courtney', 'Wallace', 'wallace'],
#    ['wilson adinolfi', 'Wilson', 'wilson', 'Adinolfi', 'adinolfi'],
#    ['trina alagbe', 'Trina', 'trina', 'Alagbe', 'alagbe'],
#    ['carol anderson', 'Carol', 'carol', 'Anderson', 'anderson'],
#    ['sam athwal', 'Sam', 'sam', 'Athwal', 'athwal'],
#    ['rachael baczenski', 'Rachael', 'rachael', 'Baczenski', 'baczenski'],
#    ['francesco barone', 'Francesco', 'francesco', 'Barone', 'barone'],
#    ['nader barton', 'Nader', 'nader', 'Barton', 'barton'],
#    ['lowan biden', 'Lowan', 'lowan', 'Biden', 'biden'],
#    ['helen billis', 'Helen', 'helen', 'Billis', 'billis'],
#    ['donna brill', 'Donna', 'donna', 'Brill', 'brill'],
#    ['josephine bugali', 'Josephine', 'josephine', 'Bugali', 'bugali'],
#    ['beatrice chace', 'Beatrice', 'beatrice', 'Chace', 'chace'],
#    ['lin chan', 'Lin', 'lin', 'Chan', 'chan'],
#    ['donovan chang', 'Donovan', 'donovan', 'Chang', 'chang'],
#    ['enola chivukula', 'Enola', 'enola', 'Chivukula', 'chivukula'],
#    ['caroline cierpiszewski',
#     'Caroline',
#     'caroline',
#     'Cierpiszewski',
#     'cierpiszewski'],
#    ['elijian clukey', 'Elijian', 'elijian', 'Clukey', 'clukey'],
#    ['james cockel', 'James', 'james', 'Cockel', 'cockel'],
#    ['spencer cole', 'Spencer', 'spencer', 'Cole', 'cole'],
#    ['jean crimmings', 'Jean', 'jean', 'Crimmings', 'crimmings'],
#    ["jene'ya darson", "Jene'ya", "jene'ya", 'Darson', 'darson'],
#    ['carl desimone', 'Carl', 'carl', 'Desimone', 'desimone'],
#    ['geoff dickinson', 'Geoff', 'geoff', 'Dickinson', 'dickinson'],
#    ['lily dinocco', 'Lily', 'lily', 'DiNocco', 'dinocco'],
#    ['denisa dobrin', 'Denisa', 'denisa', 'Dobrin', 'dobrin'],
#    ['marianne eaton', 'Marianne', 'marianne', 'Eaton', 'eaton'],
#    ['rex england', 'Rex', 'rex', 'England', 'england'],
#    ['miguel estremera', 'Miguel', 'miguel', 'Estremera', 'estremera'],
#    ['april evensen', 'April', 'april', 'Evensen', 'evensen'],
#    ['susan ferguson', 'Susan', 'susan', 'Ferguson', 'ferguson'],
#    ['nilson fernandes', 'Nilson', 'nilson', 'Fernandes', 'fernandes'],
#    ['violeta ferreira', 'Violeta', 'violeta', 'Ferreira', 'ferreira'],
#    ['libby fidelia', 'Libby', 'libby', 'Fidelia', 'fidelia'],
#    ['raul garcia', 'Raul', 'raul', 'Garcia', 'garcia'],
#    ['hamish garneau', 'Hamish', 'hamish', 'Garneau', 'garneau'],
#    ['barbara gaul', 'Barbara', 'barbara', 'Gaul', 'gaul'],
#    ['mildred gentry', 'Mildred', 'mildred', 'Gentry', 'gentry'],
#    ['melisa gerke', 'Melisa', 'melisa', 'Gerke', 'gerke'],
#    ['alex gilles', 'Alex', 'alex', 'Gilles', 'gilles'],
#    ['evelyn girifalco', 'Evelyn', 'evelyn', 'Girifalco', 'girifalco'],
#    ['shenice gold', 'Shenice', 'shenice', 'Gold', 'gold'],
#    ['roxana goyal', 'Roxana', 'roxana', 'Goyal', 'goyal'],
#    ['paula gross', 'Paula', 'paula', 'Gross', 'gross'],
#    ['joanne handschiegl', 'Joanne', 'joanne', 'Handschiegl', 'handschiegl'],
#    ['ludwick harrell', 'Ludwick', 'ludwick', 'Harrell', 'harrell'],
#    ['christie harrington', 'Christie', 'christie', 'Harrington', 'harrington'],
#    ['kara harrison', 'Kara', 'kara', 'Harrison', 'harrison'],
#    ['rose ivey', 'Rose', 'rose', 'Ivey', 'ivey'],
#    ['maryellen jackson', 'Maryellen', 'maryellen', 'Jackson', 'jackson'],
#    ['hannah jacobi', 'Hannah', 'hannah', 'Jacobi', 'jacobi'],
#    ['sneha jhaveri', 'Sneha', 'sneha', 'Jhaveri', 'jhaveri'],
#    ['judy jung', 'Judy', 'judy', 'Jung', 'jung'],
#    ['kathleen kinsella', 'Kathleen', 'kathleen', 'Kinsella', 'kinsella'],
#    ['alexandra kirill', 'Alexandra', 'alexandra', 'Kirill', 'kirill'],
#    ['bradley knapp', 'Bradley', 'bradley', 'Knapp', 'knapp'],
#    ['john kretschmer', 'John', 'john', 'Kretschmer', 'kretschmer'],
#    ['enrico langton', 'Enrico', 'enrico', 'Langton', 'langton'],
#    ['dallas leach', 'Dallas', 'dallas', 'Leach', 'leach'],
#    ['marilyn linares', 'Marilyn', 'marilyn', 'Linares', 'linares'],
#    ['allison lydon', 'Allison', 'allison', 'Lydon', 'lydon'],
#    ['lindsay lynch', 'Lindsay', 'lindsay', 'Lynch', 'lynch'],
#    ['samuel maclennan', 'Samuel', 'samuel', 'MacLennan', 'maclennan'],
#    ['lauren mahoney', 'Lauren', 'lauren', 'Mahoney', 'mahoney'],
#    ['debbie mangal', 'Debbie', 'debbie', 'Mangal', 'mangal'],
#    ['shana maurice', 'Shana', 'shana', 'Maurice', 'maurice'],
#    ['sandy mckenna', 'Sandy', 'sandy', 'Mckenna', 'mckenna'],
#    ['elizabeth meads', 'Elizabeth', 'elizabeth', 'Meads', 'meads'],
#    ['dawn motlagh', 'Dawn', 'dawn', 'Motlagh', 'motlagh'],
#    ['colombui ndzi', 'Colombui', 'colombui', 'Ndzi', 'ndzi'],
#    ['richard newman', 'Richard', 'richard', 'Newman', 'newman'],
#    ['shari ngodup', 'Shari', 'shari', 'Ngodup', 'ngodup'],
#    ['lei-ming nguyen', 'Lei-Ming', 'lei-ming', 'Nguyen', 'nguyen'],
#    ["lynn o'hare", 'Lynn', 'lynn', "O'hare", "o'hare"],
#    ['adeel osturnka', 'Adeel', 'adeel', 'Osturnka', 'osturnka'],
#    ['clinton owad', 'Clinton', 'clinton', 'Owad', 'owad'],
#    ['nina panjwani', 'Nina', 'nina', 'Panjwani', 'panjwani'],
#    ['emil pelech', 'Emil', 'emil', 'Pelech', 'pelech'],
#    ['shakira perry', 'Shakira', 'shakira', 'Perry', 'perry'],
#    ['hong pham', 'Hong', 'hong', 'Pham', 'pham'],
#    ['brad pitt', 'Brad', 'brad', 'Pitt', 'pitt'],
#    ['morissa power', 'Morissa', 'morissa', 'Power', 'power'],
#    ['louis punjabhi', 'Louis', 'louis', 'Punjabhi', 'punjabhi'],
#    ['janine purinton', 'Janine', 'janine', 'Purinton', 'purinton'],
#    ['quinn rarrick', 'Quinn', 'quinn', 'Rarrick', 'rarrick'],
#    ['haley rivera', 'Haley', 'haley', 'Rivera', 'rivera'],
#    ['alain robinson', 'Alain', 'alain', 'Robinson', 'robinson'],
#    ['ashley rose', 'Ashley', 'ashley', 'Rose', 'rose'],
#    ['bruno rossetti', 'Bruno', 'bruno', 'Rossetti', 'rossetti'],
#    ['melinda saar-beckles',
#     'Melinda',
#     'melinda',
#     'Saar-Beckles',
#     'saar-beckles'],
#    ['nore sadki', 'Nore', 'nore', 'Sadki', 'sadki'],
#    ['kamrin sander', 'Kamrin', 'kamrin', 'Sander', 'sander'],
#    ['nori sewkumar', 'Nori', 'nori', 'Sewkumar', 'sewkumar'],
#    ['seffi shields', 'Seffi', 'seffi', 'Shields', 'shields'],
#    ['taylor sparks', 'Taylor', 'taylor', 'Sparks', 'sparks'],
#    ['kristen squatrito', 'Kristen', 'kristen', 'Squatrito', 'squatrito'],
#    ['desiree tavares', 'Desiree', 'desiree', 'Tavares', 'tavares'],
#    ['sophia theamstern', 'Sophia', 'sophia', 'Theamstern', 'theamstern'],
#    ['theresa tinto', 'Theresa', 'theresa', 'Tinto', 'tinto'],
#    ['jeanette tippett', 'Jeanette', 'jeanette', 'Tippett', 'tippett'],
#    ['mei trang', 'Mei', 'mei', 'Trang', 'trang'],
#    ['abdellah veera', 'Abdellah', 'abdellah', 'Veera', 'veera'],
#    ['colleen volk', 'Colleen', 'colleen', 'Volk', 'volk'],
#    ['anna von massenbach', 'Anna', 'anna', 'Von', 'von'],
#    ['scott whittier', 'Scott', 'scott', 'Whittier', 'whittier'],
#    ['barry wilber', 'Barry', 'barry', 'Wilber', 'wilber'],
#    ['jacquelyn williams', 'Jacquelyn', 'jacquelyn', 'Williams', 'williams'],
#    ['catherine ybarra', 'Catherine', 'catherine', 'Ybarra', 'ybarra'],
#    ['kimberly beak', 'Kimberly', 'kimberly', 'Beak', 'beak'],
#    ['dianna blount', 'Dianna', 'dianna', 'Blount', 'blount'],
#    ['betsy bondwell', 'Betsy', 'betsy', 'Bondwell', 'bondwell'],
#    ['joseph buccheri', 'Joseph', 'joseph', 'Buccheri', 'buccheri'],
#    ['joelle burke', 'Joelle', 'joelle', 'Burke', 'burke'],
#    ['benjamin burkett', 'Benjamin', 'benjamin', 'Burkett', 'burkett'],
#    ['phil close', 'Phil', 'phil', 'Close', 'close'],
#    ['daniel davis', 'Daniel', 'daniel', 'Davis', 'davis'],
#    ['carla demita', 'Carla', 'carla', 'Demita', 'demita'],
#    ['angela erilus', 'Angela', 'angela', 'Erilus', 'erilus'],
#    ['megan faller', 'Megan', 'megan', 'Faller', 'faller'],
#    ['nicole fancett', 'Nicole', 'nicole', 'Fancett', 'fancett'],
#    ['phylicia gosciminski',
#     'Phylicia',
#     'phylicia',
#     'Gosciminski',
#     'gosciminski'],
#    ['earnest hankard', 'Earnest', 'earnest', 'Hankard', 'hankard'],
#    ['adrienne homberger', 'Adrienne', 'adrienne', 'Homberger', 'homberger'],
#    ['julissa hunts', 'Julissa', 'julissa', 'Hunts', 'hunts'],
#    ['rosalie hutter', 'Rosalie', 'rosalie', 'Hutter', 'hutter'],
#    ['ming huynh', 'Ming', 'ming', 'Huynh', 'huynh'],
#    ['tayana jeannite', 'Tayana', 'tayana', 'Jeannite', 'jeannite'],
#    ['yen johnston', 'Yen', 'yen', 'Johnston', 'johnston'],
#    ['lindsey langford', 'Lindsey', 'lindsey', 'Langford', 'langford'],
#    ['mohammed latif', 'Mohammed', 'mohammed', 'Latif', 'latif'],
#    ['mathew linden', 'Mathew', 'mathew', 'Linden', 'linden'],
#    ['robyn manchester', 'Robyn', 'robyn', 'Manchester', 'manchester'],
#    ['karen mancuso', 'Karen', 'karen', 'Mancuso', 'mancuso'],
#    ['brigit mccarthy', 'Brigit', 'brigit', 'McCarthy', 'mccarthy'],
#    ['erasumus monkfish', 'Erasumus', 'erasumus', 'Monkfish', 'monkfish'],
#    ['luisa monterro', 'Luisa', 'luisa', 'Monterro', 'monterro'],
#    ['patrick moran', 'Patrick', 'patrick', 'Moran', 'moran'],
#    ['maliki moumanil', 'Maliki', 'maliki', 'Moumanil', 'moumanil'],
#    ['kristie nowlan', 'Kristie', 'kristie', 'Nowlan', 'nowlan'],
#    ['brooke oliver', 'Brooke', 'brooke', 'Oliver', 'oliver'],
#    ['ermine pelletier', 'Ermine', 'ermine', 'Pelletier', 'pelletier'],
#    ['may roberson', 'May', 'may', 'Roberson', 'roberson'],
#    ['adil sahoo', 'Adil', 'adil', 'Sahoo', 'sahoo'],
#    ['constance sloan', 'Constance', 'constance', 'Sloan', 'sloan'],
#    ['lenora tejeda', 'Lenora', 'lenora', 'Tejeda', 'tejeda'],
#    ['kenneth thibaud', 'Kenneth', 'kenneth', 'Thibaud', 'thibaud'],
#    ['cybil trzeciak', 'Cybil', 'cybil', 'Trzeciak', 'trzeciak'],
#    ['roger walker', 'Roger', 'roger', 'Walker', 'walker'],
#    ['jordan winthrop', 'Jordan', 'jordan', 'Winthrop', 'winthrop'],
#    ['hang wolk', 'Hang', 'hang', 'Wolk', 'wolk'],
#    ['edward buck', 'Edward', 'edward', 'Buck', 'buck'],
#    ['jessica bunbury', 'Jessica', 'jessica', 'Bunbury', 'bunbury'],
#    ['michelle carter', 'Michelle', 'michelle', 'Carter', 'carter'],
#    ['latia costa', 'Latia', 'latia', 'Costa', 'costa'],
#    ['jenna dietrich', 'Jenna', 'jenna', 'Dietrich', 'dietrich'],
#    ['alfred digitale', 'Alfred', 'alfred', 'Digitale', 'digitale'],
#    ['maruk fraval', 'Maruk', 'maruk', 'Fraval', 'fraval'],
#    ['gerry friedman', 'Gerry', 'gerry', 'Friedman', 'friedman'],
#    ['whitney gill', 'Whitney', 'whitney', 'Gill', 'gill'],
#    ['myriam givens', 'Myriam', 'myriam', 'Givens', 'givens'],
#    ['mike guilianno', 'Mike', 'mike', 'Guilianno', 'guilianno'],
#    ['jeremy prater', 'Jeremy', 'jeremy', 'Prater', 'prater'],
#    ['bartholemew khemmich',
#     'Bartholemew',
#     'bartholemew',
#     'Khemmich',
#     'khemmich'],
#    ['giovanni leruth', 'Giovanni', 'giovanni', 'Leruth', 'leruth'],
#    ['jac mckinzie', 'Jac', 'jac', 'McKinzie', 'mckinzie'],
#    ['howard mullaney', 'Howard', 'howard', 'Mullaney', 'mullaney'],
#    ['jasmine onque', 'Jasmine', 'jasmine', 'Onque', 'onque'],
#    ['travis ozark', 'Travis', 'travis', 'Ozark', 'ozark'],
#    ['xana potts', 'Xana', 'xana', 'Potts', 'potts'],
#    ['caitrin strong', 'Caitrin', 'caitrin', 'Strong', 'strong'],
#    ['sharlene terry', 'Sharlene', 'sharlene', 'Terry', 'terry'],
#    ['jackie valentin', 'Jackie', 'jackie', 'Valentin', 'valentin'],
#    ['noah villanueva', 'Noah', 'noah', 'Villanueva', 'villanueva'],
#    ['debra houlihan', 'Debra', 'debra', 'Houlihan', 'houlihan'],
#    ['donysha kampew', 'Donysha', 'donysha', 'Kampew', 'kampew'],
#    ['colby andreola', 'Colby', 'colby', 'Andreola', 'andreola'],
#    ['judith carabbio', 'Judith', 'judith', 'Carabbio', 'carabbio'],
#    ['keyla del bosque', 'Keyla', 'keyla', 'Del', 'del'],
#    ['sandra martin', 'Sandra', 'sandra', 'Martin', 'martin'],
#    ['luke patronick', 'Luke', 'luke', 'Patronick', 'patronick'],
#    ['adell saada', 'Adell', 'adell', 'Saada', 'saada'],
#    ['andrew szabo', 'Andrew', 'andrew', 'Szabo', 'szabo'],
#    ['mia brown', 'Mia', 'mia', 'Brown', 'brown'],
#    ['ivan rogers', 'Ivan', 'ivan', 'Rogers', 'rogers'],
#    ['julia soto', 'Julia', 'julia', 'Soto', 'soto'],
#    ['nan singh', 'Nan', 'nan', 'Singh', 'singh']],
#   []],
#  'state': [array(['MA', 'TX', 'CT', 'VA', 'VT', 'CA', 'WA', 'NH', 'NY', 'OH', 'IN',
#          'ID', 'TN', 'NV', 'CO', 'UT', 'AL', 'GA', 'FL', 'NC', 'KY', 'ND',
#          'MT', 'OR', 'AZ', 'ME', 'RI', 'PA'], dtype=object),
#   [['Massachussets'],
#    ['Texas'],
#    ['Connecticut'],
#    ['Virginia'],
#    ['Vermony'],
#    ['California'],
#    ['Washington'],
#    ['New Hampshire'],
#    ['New York'],
#    ['Ohio'],
#    ['Indiana'],
#    ['Idaho'],
#    ['Tennessee'],
#    ['Nevada'],
#    ['Colarado'],
#    ['Utah'],
#    ['Alabama'],
#    ['Georgia'],
#    ['Florida'],
#    ['North Carolina'],
#    ['Kentucky'],
#    ['North Dakota'],
#    ['Montana'],
#    ['Oregon'],
#    ['Arizona'],
#    ['Maine'],
#    ['Rhode Island'],
#    ['Pennsylvania']],
#   ['state',
#    'state of birth',
#    'state of residence',
#    'office location',
#    'location',
#    'out of state',
#    'live',
#    'lives',
#    'live in',
#    'based in',
#    'lives in',
#    'where',
#    'works in',
#    'works at',
#    'where is',
#    'cali']],
#  'age': [['32',
#    '33',
#    '31',
#    '29',
#    '30',
#    '38',
#    '63',
#    '46',
#    '36',
#    '47',
#    '37',
#    '44',
#    '54',
#    '49',
#    '28',
#    '48',
#    '42',
#    '53',
#    '66',
#    '34',
#    '52',
#    '39',
#    '45',
#    '41',
#    '40',
#    '62',
#    '43',
#    '59',
#    '27',
#    '67',
#    '50',
#    '35',
#    '26',
#    '25',
#    '65',
#    '51',
#    '58',
#    '56',
#    '64'],
#   [['old', 'years old', 'age of', 'ages of']],
#   ['age']],
#  'sex': [['male', 'female'],
#   [['men', 'males', 'guys', 'dudes', 'gents', 'gentlemen', 'boys', 'boy'],
#    ['women',
#     'females',
#     'ladies',
#     'lady',
#     'ladys',
#     'girls',
#     'gals',
#     'woman',
#     'girl']],
#   ['sex',
#    'gender',
#    'masculine',
#    'feminine',
#    'male person',
#    'm/f',
#    'male/female',
#    'M/F',
#    'Male/Female']],
#  'maritaldesc': [['married', 'divorced', 'single', 'separated', 'widowed'],
#   [['wed',
#     'legally married',
#     'espoused',
#     'joined in holy matrimony',
#     'hitched'],
#    nan,
#    ['unmarried', 'bachelor', 'bachelorette'],
#    nan,
#    nan],
#   ['husbandless',
#    'without a partner',
#    'unwedded',
#    'wifeless',
#    'no longer married',
#    'without a husband',
#    'without a wife',
#    'maritaldesc',
#    'marital status',
#    'spouse',
#    'husband',
#    'wife']],
#  'citizendesc': [['us citizen', 'eligible noncitizen', 'non-citizen'],
#   [['citizen',
#     'usa citizen',
#     'american citizen',
#     'citizen of the us',
#     'citizen of America',
#     'citizen of the usa',
#     'citizens'],
#    ['non citizen', 'not a citizen', 'non us citizen', 'not citizens'],
#    ['non citizen', 'not a citizen', 'non us citizen', 'not citizens']],
#   ['immigrant',
#    'illegal immigrant',
#    'h1 visa',
#    'foreigner',
#    'foreign',
#    'imported',
#    'out of country',
#    'from abroad',
#    'citizenship status',
#    'citizenship']],
#  'racedesc': [['black or african american',
#    'asian',
#    'two or more races',
#    'white',
#    'hispanic',
#    'american indian or alaska native'],
#   [['black', 'african american', 'african-american'],
#    ['from asia'],
#    ['multiracial',
#     'multi-racial',
#     'mixed',
#     'mixed race',
#     'biracial',
#     'interracial'],
#    ['caucasian'],
#    ['latino'],
#    ['native',
#     'natives',
#     'indians',
#     'indian',
#     'american indian',
#     'alaska native']],
#   ['ethnicity',
#    'race',
#    'racial background',
#    'ethnic group',
#    'ethnic type',
#    'racial indentity',
#    'community',
#    'minorities']],
#  'reason_for_termination': [['return to school',
#    'another position',
#    'unhappy',
#    'military',
#    'gross misconduct',
#    'hours',
#    'medical issues',
#    'relocation out of area',
#    'more money',
#    'career change',
#    'n/a - has not started yet',
#    'retiring',
#    'n/a - still employed',
#    'attendance',
#    'no-call no-show',
#    'maternity leave - did not return',
#    'performance'],
#   [['went back to school',
#     'had to go to school again',
#     'needed to go back to school',
#     'went back to college'],
#    ['took on another job',
#     'landed a new position',
#     'changed positions',
#     'got a new position',
#     'found a new position'],
#    ["wasn't happy",
#     "didn't like his job",
#     "didn't like her job",
#     'hated the job',
#     'disliked the job',
#     "didn't enjoy the job",
#     "didn't like his work",
#     "didn't like her work"],
#    ['joined the military',
#     'went to the military',
#     'left for the military',
#     'enlisted in the military',
#     'was drafted into the military'],
#    nan,
#    nan,
#    ['got sick', 'fell sick', 'medical problems', 'sick'],
#    ['was relocated',
#     'had to relocated',
#     'was assigned to a new location',
#     'was assigned to a different location'],
#    nan,
#    ['changed careers'],
#    nan,
#    ['retired', 'went into retirement'],
#    nan,
#    ['poor attendance', 'bad attendance'],
#    nan,
#    ['did not come back from maternity leave', 'had a kid and dissapeared'],
#    ['poor performance', 'performed below expectations']],
#   []],
#  'employment_status': [['terminated for cause',
#    'leave of absence',
#    'active',
#    'voluntarily terminated',
#    'future start'],
#   [['fired', 'let go', 'evicted', 'kicked out', 'removed', 'dismissed'],
#    ['on absence leave'],
#    ['currently employed',
#     'currently working',
#     'currently works',
#     'still works at',
#     'still working at',
#     'still work at',
#     'actively employed'],
#    ['quit', 'quitted', 'resigned', 'sent in a resignation'],
#    ['will start at a future time',
#     'will start later',
#     'will start some time in the future']],
#   ['renounce', 'employment status', 'current job status']],
#  'department': [['executive office',
#    'admin offices',
#    'production',
#    'it/is',
#    'software engineering',
#    'sales'],
#   [nan,
#    ['administration',
#     'office of admin',
#     'office of administration',
#     'admin office',
#     'administration office'],
#    nan,
#    ['IT',
#     'IS',
#     'Information Technology',
#     'Information Systems',
#     'Info Tech',
#     'Info Sys'],
#    ['programming', 'coding', 'software development'],
#    nan],
#   ['department',
#    'team',
#    'group',
#    'section',
#    'division',
#    'sector',
#    'office',
#    'office group',
#    'dpt',
#    'dept',
#    'dept.',
#    'branch']],
#  'position': [['it manager - infra',
#    'cio',
#    'sales manager',
#    'president & ceo',
#    'administrative assistant',
#    'database administrator',
#    'area sales manager',
#    'it director',
#    'sr. accountant',
#    'it manager - support',
#    'production technician ii',
#    'network engineer',
#    'sr. network engineer',
#    'shared services manager',
#    'accountant i',
#    'it support',
#    'software engineering manager',
#    'production technician i',
#    'director of operations',
#    'director of sales',
#    'sr. dba',
#    'it manager - db',
#    'software engineer',
#    'production manager'],
#   [nan,
#    ['chief information officer'],
#    nan,
#    ['chief executive officer', 'ceo', 'prez', 'president', 'executive', 'e'],
#    nan,
#    ['db admin', 'db administrator', 'database admin'],
#    nan,
#    ['director of it'],
#    ['senior accountant'],
#    nan,
#    ['production technician 2', 'production technician two'],
#    nan,
#    ['senior network engineer'],
#    nan,
#    ['accountant 1', 'accountant one'],
#    ['tech support'],
#    nan,
#    ['production technician 1', 'production technician one'],
#    ['operations director'],
#    ['sales director'],
#    ['senior database administrator',
#     'senior db admin',
#     'senior db administrator'],
#    nan,
#    ['software developer', 'programmer'],
#    nan],
#   ['title',
#    'job title',
#    'role',
#    'position',
#    'level in the organization',
#    'level',
#    'job',
#    'occupation']],
#  'manager': [['manager'],
#   [['manager name',
#     'manager',
#     'incharge',
#     'supervisor',
#     'mentor',
#     'leadership',
#     'boss',
#     'management',
#     'head',
#     'lead',
#     'chairman',
#     'working for',
#     'works for',
#     'work for',
#     'manage',
#     'managed by',
#     'managing',
#     'manages',
#     'reports to',
#     'report to',
#     'reporting to',
#     'reporting',
#     'working under',
#     'is under',
#     'leads']],
#   []],
#  'employee_source': [['information session',
#    'company intranet - partner',
#    'social networks - facebook twitter etc',
#    'newspager/magazine',
#    'internet search',
#    'billboard',
#    'pay per click',
#    'on-line web application',
#    'glassdoor',
#    'professional society',
#    'monster.com',
#    'diversity job fair',
#    'careerbuilder',
#    'mbta ads',
#    'word of mouth',
#    'other',
#    'vendor referral',
#    'on-campus recruiting',
#    'website banner ads',
#    'employee referral'],
#   [['info session'],
#    nan,
#    ['social media',
#     'social media apps',
#     'facebook',
#     'instagram',
#     'twitter',
#     'snapchat',
#     'social network'],
#    ['newspaper', 'magazine'],
#    ['google',
#     'bing',
#     'yahoo',
#     "search engine - google bing yahoo'",
#     'search engine'],
#    ['poster'],
#    ['ppc', 'google ads', 'google ppc', 'ppc google'],
#    ['application potal', 'job portal'],
#    ['glass door'],
#    ['professional group'],
#    ['monster'],
#    nan,
#    nan,
#    ['advertisement', 'ads'],
#    ['verbal mention'],
#    nan,
#    ['referred by vendor', 'vendor referred'],
#    ['on-campus job fair', 'career fair'],
#    nan,
#    ['referred by employee']],
#   ['how did you learn about this position',
#    'how did you find out about this job',
#    'how did you find out about this position',
#    'how did you learn about this job. how did you hear about this',
#    'heard about us',
#    'hear about us',
#    'how you heard about us',
#    'how did you hear of us',
#    'hear of us']],
#  'performance_score': [['exceptional',
#    'fully meets',
#    'n/a- too early to review',
#    'pip',
#    'needs improvement',
#    'exceeds',
#    '90-day meets'],
#   [['extraordinary'],
#    ['up to the mark', 'meet expectations', 'meet', 'meets'],
#    nan,
#    nan,
#    ['performing badly',
#     'performing below expectations',
#     'not meeting standards',
#     'not meeting expectations',
#     'poor performance',
#     'performing poorly',
#     'poorly performing',
#     'does not meet',
#     'do not meet'],
#    ['beyond expectations',
#     'more than expected',
#     'better than expected',
#     'higher than excpected',
#     'exceed expectations'],
#    nan],
#   ['performance rating',
#    'performance score',
#    'performance evaluation',
#    'performance eval',
#    'evalation',
#    'eval',
#    'performance evaluation history',
#    'performance eval history',
#    'performance',
#    'performance history',
#    'how well']],
#  'money': [['pay rate'],
#   [['salary',
#     'income',
#     'pay',
#     'earn',
#     'earnings',
#     'make',
#     'dollars',
#     '$',
#     'paycheck',
#     'earns',
#     'earning',
#     'earners',
#     'earner',
#     'incomes',
#     'paycheck',
#     'compensation']],
#   ['earns', 'makes', 'amount']],
#  'comparator': [['more than', 'equals to', 'less than', 'between'],
#   [['greater than', 'higher than', 'longer', 'over', 'older than'],
#    ['is exactly', 'is equal to', 'equates to', 'equal to'],
#    ['lower than', 'below', 'under', 'fewer than', 'younger than'],
#    ['between', 'in between']],
#   []],
#  'dob': [['dob'],
#   [['birthday',
#     'birthdate',
#     'birth date',
#     'date of birth',
#     'day of birth',
#     'born on',
#     'born on the',
#     'born in',
#     'born after',
#     'born before',
#     'DOB']],
#   []],
#  'time_interval': [['2000s',
#    '2010s',
#    '1920s',
#    '1930s',
#    '1940s',
#    '1950s',
#    '1960s',
#    '1970s',
#    '1980s',
#    '1990s'],
#   [["00's", "2000's", 'two thousands'],
#    ["10's", 'two thousand tens', 'tens', "2010's"],
#    ["20's", 'nineteen twenties', 'twenties', "1920's"],
#    ["30's", 'nineteen thirties', 'thirties', "1930's"],
#    ["40's", 'nineteen forties', 'forties', "1940's"],
#    ["50's", 'nineteen fifties', 'fifties', "1950's"],
#    ["60's", 'nineteen sixties', 'sixties', "1960's"],
#    ["70's", 'nineteen seventies', 'seventies', "1970's"],
#    ["80's", 'nineteen eighties', 'eighties', "1980's"],
#    ["90's", 'nineteen nineties', 'nineties', "1990's"]],
#   []],
#  'time_recur': [['yearly', 'monthly', 'weekly', 'daily', 'hourly'],
#   [['by the year',
#     'every year',
#     'each year',
#     'annually',
#     'on a yearly basis',
#     'per year',
#     'annual',
#     'in a year',
#     'in the year'],
#    ['by the month',
#     'every month',
#     'each month',
#     'month to month',
#     'month-to-month',
#     'on a monthly basis',
#     'per month',
#     'in a month',
#     'in the month'],
#    ['by the week',
#     'every week',
#     'each week',
#     'week by week',
#     'on a weekly basis',
#     'per week',
#     'in a week',
#     'in the week'],
#    ['daily',
#     'every day',
#     'day by day',
#     'each day',
#     'on a daily basis',
#     'per day',
#     'in a day',
#     'in the day'],
#    ['every hour',
#     'each hour',
#     'on an hourly basis',
#     'on the hour',
#     'per hour',
#     'in an hour',
#     'in  a hour',
#     'hour',
#     'in the hour']],
#   []],
#  'function': [['percent', 'sum', 'average', 'count'],
#   [['fraction',
#     'portion',
#     'proportion',
#     'percentage',
#     '%',
#     'ratio',
#     'ratios',
#     'pct'],
#    ['total',
#     'cumulative',
#     'added up',
#     'summed up',
#     'totalled',
#     'summed',
#     'combined',
#     'aggregate'],
#    ['mean', 'typical', 'typically', 'median', 'avg', 'range'],
#    ['how many', 'total number', 'number of', 'num of. headcount']],
#   ['distribution', 'turn over rate', 'pct']],
#  'extreme': [['highest', 'lowest'],
#   [['top', 'maximum', 'most', 'greatest', 'max', 'oldest', 'eldest'],
#    ['least', 'minimum', 'bottom', 'lowest', 'min', 'youngest']],
#   []],
#  'employment_action': [['hired', 'fired'],
#   [['employed',
#     'recruited',
#     'start date',
#     'date of starting employment',
#     'hiring date',
#     'date of hire',
#     'join',
#     'joined',
#     'date of hiring',
#     'began her employment',
#     'began his employment',
#     'started working',
#     'join date',
#     'worked here',
#     'started',
#     'been with us',
#     'began working for',
#     'started her experience',
#     'started his experience'],
#    ['terminated',
#     'let go',
#     'end date',
#     'date of leaving job',
#     'date of ending employment',
#     'date of termination',
#     'firing date',
#     'end employment',
#     'end his employment',
#     'end her employment']],
#   ['been with the company',
#    'been here',
#    'long has worked here',
#    'been working here',
#    'years of experience',
#    'of experience',
#    'employees that have been here',
#    'working here for']],
#  'date_compare': [['prev', 'post'],
#   [['before', 'pre', 'prior to'],
#    ['after',
#     'last',
#     'post',
#     'this year',
#     'this month',
#     'this week',
#     'atleast',
#     'since']],
#   []]}

# %% [markdown]
# <h4>Generate Gazetteers</h4>

# %%
gen_gazetteers(ent_dict)

# %% [markdown]
# <h4>Generate Mapping.json</h4>

# %%
gen_map_json_files(ent_dict)

# %% [markdown]
# <h4>Data Augmentation</h4>

# %%
def entity_swap(sentence, positions, uniq):
    chars = list(sentence)
    for i in reversed(range(len(positions))):
        pos = positions[i]
        ent = ''.join(chars[pos[0]:(pos[1] + 1)])
        excluded = [] #['age']
        #print("ENTITY FOUND")
        #print(ent)
        kv = get_kv([ent])
        #print(kv)       
        for i in range(len(kv[0])):
            if kv[1][i] in uniq and kv[1][i] not in excluded:
                new_ent = "{" + random.choice(uniq[kv[1][i]]) + "|" + kv[1][i] + '}'
                chars[pos[0]:(pos[1]+1)] = list(new_ent)
                #print(new_ent)
    #print("FINAL")
    return "".join(chars)

# %%
#entity_swap("What is the {manager|manager} name of {Julia|name}?", [[12, 28], [38, 49]], uniq)

# %%
#intent_txt['get_info'][6]

# %%
def data_augment(df, uniq):
    df = intent_txt
    for col in df:
        augment = []
        print(col.upper() + "=============================================================")
        idx = 2
        nan = is_nan(df[col][idx])
        l_dict = {}
        while(idx < len(df)):
                if(is_nan(df[col][idx])): break
                #print(idx)
                sentence = df[col][idx]
                labels, pos = get_labels(sentence)
                for i in range(3): augment.append(entity_swap(sentence, pos, uniq))
                idx += 1
        # Create files
        #augment = set(augment)
        #if((250 - idx) < len(augment)): augment = random.sample(augment, 250 - idx)
        print("Augmented Lines Generated: " + str(len(augment)))
        with open('data_augment/' + col + ".txt", 'w+') as filehandle:  
            filehandle.writelines("%s\n" % line for line in augment)

data_augment(intent_txt, uniq)
# Out:
# GET_INFO=============================================================
# Augmented Lines Generated: 747
# GET_AGGREGATE=============================================================
# Augmented Lines Generated: 675
# GET_EMPLOYEES=============================================================
# Augmented Lines Generated: 894
# GET_SALARY=============================================================
# Augmented Lines Generated: 216
# GET_SALARY_AGGREGATE=============================================================
# Augmented Lines Generated: 207
# GET_SALARY_EMPLOYEES=============================================================
# Augmented Lines Generated: 207
# GET_DATE=============================================================
# Augmented Lines Generated: 213
# GET_DATE_RANGE_AGGREGATE=============================================================
# Augmented Lines Generated: 69
# GET DATE_RANGE_EMPLOYEES=============================================================
# Augmented Lines Generated: 189
# GET_HIERARCHY=============================================================
# Augmented Lines Generated: 591
